# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('./1년 365일 1시간별 Ls, Ws.csv', encoding = 'cp949')
df
# Out:
#         자치구               대여소명  대여소번호     년  월   일  시간  lambda    mu     c  \
# 0       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   0     0.0   1.0  30.0
# 1       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   1     0.0   0.0  30.0
# 2       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   2     0.0   0.0  30.0
# 3       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   3     0.0   0.0  30.0
# 4       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   4     1.0   0.0  30.0
# ...     ...                ...    ...   ... ..  ..  ..     ...   ...   ...
# 262795  송파구        한성백제역 2번 출구   2621  2021  5  31  19    14.0  16.0  19.0
# 262796  송파구        한성백제역 2번 출구   2621  2021  5  31  20    24.0  17.0  19.0
# 262797  송파구        한성백제역 2번 출구   2621  2021  5  31  21    20.0  19.0  19.0
# 262798  송파구        한성백제역 2번 출구   2621  2021  5  31  22    14.0  18.0  19.0
# 262799  송파구        한성백제역 2번 출구   2621  2021  5  31  23     5.0   1.0  19.0
#
#              rho           p_0      p_1+        L_s
# 0       0.000000  1.000000e+00  0.000000   0.000000
# 1       0.000000  1.000000e+00  0.000000   0.000000
# 2       0.000000  1.000000e+00  0.000000   0.000000
# 3       0.000000  1.000000e+00  0.000000   0.000000
# 4       0.000000  1.000000e+00  0.000000   0.000000
# ...          ...           ...       ...        ...
# 262795  0.875000  1.342943e-01  0.865706   5.512905
# 262796  1.411765  4.167178e-04  0.999583  16.591669
# 262797  1.052632  2.941117e-02  0.970589  11.176245
# 262798  0.777778  2.236903e-01  0.776310   3.367870
# 262799  5.000000  4.194304e-14  1.000000  18.750000
#
# [262800 rows x 14 columns]

# %%
df = df[df['대여소명'] == '송파나루역 4번 출구옆']
df
# Out:
#         자치구          대여소명  대여소번호     년  월   일  시간  lambda    mu     c  \
# 140160  송파구  송파나루역 4번 출구옆   2620  2020  6   1   0     2.0   0.0  17.0
# 140161  송파구  송파나루역 4번 출구옆   2620  2020  6   1   1     1.0   2.0  17.0
# 140162  송파구  송파나루역 4번 출구옆   2620  2020  6   1   2     3.0   3.0  17.0
# 140163  송파구  송파나루역 4번 출구옆   2620  2020  6   1   3     0.0   0.0  17.0
# 140164  송파구  송파나루역 4번 출구옆   2620  2020  6   1   4     2.0   1.0  17.0
# ...     ...           ...    ...   ... ..  ..  ..     ...   ...   ...
# 148915  송파구  송파나루역 4번 출구옆   2620  2021  5  31  19    23.0  11.0  17.0
# 148916  송파구  송파나루역 4번 출구옆   2620  2021  5  31  20    17.0  12.0  17.0
# 148917  송파구  송파나루역 4번 출구옆   2620  2021  5  31  21    11.0  17.0  17.0
# 148918  송파구  송파나루역 4번 출구옆   2620  2021  5  31  22     8.0  13.0  17.0
# 148919  송파구  송파나루역 4번 출구옆   2620  2021  5  31  23     5.0   2.0  17.0
#
#              rho           p_0      p_1+        L_s
# 140160  0.000000  1.000000e+00  0.000000   0.000000
# 140161  0.500000  5.000019e-01  0.499998   0.999931
# 140162  1.000000  5.555556e-02  0.944444   8.500000
# 140163  0.000000  1.000000e+00  0.000000   0.000000
# 140164  2.000000  3.814712e-06  0.999996  16.000069
# ...          ...           ...       ...        ...
# 148915  2.090909  1.869634e-06  0.999998  16.083364
# 148916  1.416667  7.903029e-04  0.999210  14.634141
# 148917  0.647059  3.530808e-01  0.646919   1.826214
# 148918  0.615385  3.846770e-01  0.615323   1.597116
# 148919  2.500000  1.030792e-07  1.000000  16.333335
#
# [8760 rows x 14 columns]

# %%
df = df.drop(['대여소번호', 'c', 'rho', 'p_0'], axis = 1)
df
# Out:
#         자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s
# 140160  송파구  송파나루역 4번 출구옆  2020  6   1   0     2.0   0.0  0.000000   0.000000
# 140161  송파구  송파나루역 4번 출구옆  2020  6   1   1     1.0   2.0  0.499998   0.999931
# 140162  송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 140163  송파구  송파나루역 4번 출구옆  2020  6   1   3     0.0   0.0  0.000000   0.000000
# 140164  송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# ...     ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 148915  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 148916  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 148917  송파구  송파나루역 4번 출구옆  2021  5  31  21    11.0  17.0  0.646919   1.826214
# 148918  송파구  송파나루역 4번 출구옆  2021  5  31  22     8.0  13.0  0.615323   1.597116
# 148919  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
# [8760 rows x 10 columns]

# %%
data = pd.read_csv('./송파나루역 4번 출구옆 365일 균형, 불균형.csv', encoding = 'cp949')
data
# Out:
#       자치구          대여소명     년  월   일  시간   재고량  3사분위수  2사분위수  1사분위수   균형
# 0     송파구  송파나루역 4번 출구옆  2020  6   1   0   2.0   19.0   10.0    4.0  불균형
# 1     송파구  송파나루역 4번 출구옆  2020  6   1   1   1.0   19.0   10.0    4.0  불균형
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2   1.0   19.0   10.0    4.0  불균형
# 3     송파구  송파나루역 4번 출구옆  2020  6   1   3   1.0   19.0   10.0    4.0  불균형
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4   2.0   19.0   10.0    4.0  불균형
# ...   ...           ...   ... ..  ..  ..   ...    ...    ...    ...  ...
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19  39.0   19.0   10.0    4.0  불균형
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20  44.0   19.0   10.0    4.0  불균형
# 8757  송파구  송파나루역 4번 출구옆  2021  5  31  21  38.0   19.0   10.0    4.0  불균형
# 8758  송파구  송파나루역 4번 출구옆  2021  5  31  22  33.0   19.0   10.0    4.0  불균형
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23  36.0   19.0   10.0    4.0  불균형
#
# [8760 rows x 11 columns]

# %%
df_new = pd.merge(df,data, on = ['자치구', '대여소명','년', '월', '일', '시간'],how='outer')
df_new
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s  \
# 0     송파구  송파나루역 4번 출구옆  2020  6   1   0     2.0   0.0  0.000000   0.000000
# 1     송파구  송파나루역 4번 출구옆  2020  6   1   1     1.0   2.0  0.499998   0.999931
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 3     송파구  송파나루역 4번 출구옆  2020  6   1   3     0.0   0.0  0.000000   0.000000
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 8757  송파구  송파나루역 4번 출구옆  2021  5  31  21    11.0  17.0  0.646919   1.826214
# 8758  송파구  송파나루역 4번 출구옆  2021  5  31  22     8.0  13.0  0.615323   1.597116
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
#        재고량  3사분위수  2사분위수  1사분위수   균형
# 0      2.0   19.0   10.0    4.0  불균형
# 1      1.0   19.0   10.0    4.0  불균형
# 2      1.0   19.0   10.0    4.0  불균형
# 3      1.0   19.0   10.0    4.0  불균형
# 4      2.0   19.0   10.0    4.0  불균형
# ...    ...    ...    ...    ...  ...
# 8755  39.0   19.0   10.0    4.0  불균형
# 8756  44.0   19.0   10.0    4.0  불균형
# 8757  38.0   19.0   10.0    4.0  불균형
# 8758  33.0   19.0   10.0    4.0  불균형
# 8759  36.0   19.0   10.0    4.0  불균형
#
# [8760 rows x 15 columns]

# %%
df_new['내 균형'] = '균형'
df_new
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s  \
# 0     송파구  송파나루역 4번 출구옆  2020  6   1   0     2.0   0.0  0.000000   0.000000
# 1     송파구  송파나루역 4번 출구옆  2020  6   1   1     1.0   2.0  0.499998   0.999931
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 3     송파구  송파나루역 4번 출구옆  2020  6   1   3     0.0   0.0  0.000000   0.000000
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 8757  송파구  송파나루역 4번 출구옆  2021  5  31  21    11.0  17.0  0.646919   1.826214
# 8758  송파구  송파나루역 4번 출구옆  2021  5  31  22     8.0  13.0  0.615323   1.597116
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
#        재고량  3사분위수  2사분위수  1사분위수   균형 내 균형
# 0      2.0   19.0   10.0    4.0  불균형   균형
# 1      1.0   19.0   10.0    4.0  불균형   균형
# 2      1.0   19.0   10.0    4.0  불균형   균형
# 3      1.0   19.0   10.0    4.0  불균형   균형
# 4      2.0   19.0   10.0    4.0  불균형   균형
# ...    ...    ...    ...    ...  ...  ...
# 8755  39.0   19.0   10.0    4.0  불균형   균형
# 8756  44.0   19.0   10.0    4.0  불균형   균형
# 8757  38.0   19.0   10.0    4.0  불균형   균형
# 8758  33.0   19.0   10.0    4.0  불균형   균형
# 8759  36.0   19.0   10.0    4.0  불균형   균형
#
# [8760 rows x 16 columns]

# %% [markdown]
# # 일단 L_s, 기존균형 비교

# %% [markdown]
# ## L_s가 Q1보다 작거나, Q3보다 크면 불균형

# %% [markdown]
# ### L_s가 q1보다 작지만 이때 p_1+이 충분히 크다면 균형
# - ls가 q1보다 작고 p_1+가 0.5보다 작으면 불균형

# %%
# ls가 q1보다 작으므로 불균형

e = df_new[(df_new['L_s'] < df_new['1사분위수']) & (df_new['p_1+'] < 0.6)]
e
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+       L_s  \
# 0     송파구  송파나루역 4번 출구옆  2020  6   1   0     2.0   0.0  0.000000  0.000000
# 1     송파구  송파나루역 4번 출구옆  2020  6   1   1     1.0   2.0  0.499998  0.999931
# 3     송파구  송파나루역 4번 출구옆  2020  6   1   3     0.0   0.0  0.000000  0.000000
# 5     송파구  송파나루역 4번 출구옆  2020  6   1   5     0.0   0.0  0.000000  0.000000
# 6     송파구  송파나루역 4번 출구옆  2020  6   1   6     0.0   1.0  0.000000  0.000000
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...       ...
# 8741  송파구  송파나루역 4번 출구옆  2021  5  31   5     0.0   1.0  0.000000  0.000000
# 8742  송파구  송파나루역 4번 출구옆  2021  5  31   6     0.0   2.0  0.000000  0.000000
# 8745  송파구  송파나루역 4번 출구옆  2021  5  31   9     1.0   5.0  0.200000  0.250000
# 8746  송파구  송파나루역 4번 출구옆  2021  5  31  10     4.0   9.0  0.444444  0.799992
# 8752  송파구  송파나루역 4번 출구옆  2021  5  31  16     8.0  15.0  0.533328  1.142638
#
#        재고량  3사분위수  2사분위수  1사분위수   균형 내 균형
# 0      2.0   19.0   10.0    4.0  불균형   균형
# 1      1.0   19.0   10.0    4.0  불균형   균형
# 3      1.0   19.0   10.0    4.0  불균형   균형
# 5      2.0   19.0   10.0    4.0  불균형   균형
# 6      2.0   19.0   10.0    4.0  불균형   균형
# ...    ...    ...    ...    ...  ...  ...
# 8741  25.0   19.0   10.0    4.0  불균형   균형
# 8742  25.0   19.0   10.0    4.0  불균형   균형
# 8745  13.0   19.0   10.0    4.0   균형   균형
# 8746   8.0   19.0   10.0    4.0   균형   균형
# 8752  11.0   19.0   10.0    4.0   균형   균형
#
# [3680 rows x 16 columns]

# %%
for i in range(len(df_new)):
    if (df_new['L_s'][i] < df_new['1사분위수'][i]) & (df_new['p_1+'][i] < 0.6):
        df_new['내 균형'][i] = '불균형'

# %%
# ls가 q3보다 크므로 불균형

r = df_new[(df_new['L_s'] > df_new['3사분위수']) & (df_new['L_s'] > (15*0.7))]
r
# Out:
# Empty DataFrame
# Columns: [자치구, 대여소명, 년, 월, 일, 시간, lambda, mu, p_1+, L_s, 재고량, 3사분위수, 2사분위수, 1사분위수, 균형, 내 균형]
# Index: []

# %%
for i in range(len(df_new)):
    if (df_new['L_s'][i] > df_new['3사분위수'][i]) & (df_new['L_s'][i] > (15*0.7)):
        df_new['내 균형'][i] = '불균형'

# %% [markdown]
# # L_s가 Q1~Q3사이이더라도 이때 p_1+가 너무 작으면(50%이하) 불균형
# - 따릉이 목표 거치율이 60~70%이므로 한대라도 있을 확률인 p_1+도 유사하게 잡기 위해

# %%
t = df_new[(df_new['3사분위수']>=df_new['L_s']) & (df_new['L_s'] >= df_new['1사분위수'])]
t
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s  \
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# 7     송파구  송파나루역 4번 출구옆  2020  6   1   7     3.0   2.0  0.999661  15.012188
# 10    송파구  송파나루역 4번 출구옆  2020  6   1  10     5.0   2.0  1.000000  16.333335
# 13    송파구  송파나루역 4번 출구옆  2020  6   1  13     9.0   7.0  0.996866  13.697428
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 8753  송파구  송파나루역 4번 출구옆  2021  5  31  17    19.0  10.0  0.999991  15.889062
# 8754  송파구  송파나루역 4번 출구옆  2021  5  31  18    23.0  16.0  0.999362  14.740526
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
#        재고량  3사분위수  2사분위수  1사분위수   균형 내 균형
# 2      1.0   19.0   10.0    4.0  불균형   균형
# 4      2.0   19.0   10.0    4.0  불균형   균형
# 7      3.0   19.0   10.0    4.0  불균형   균형
# 10    15.0   19.0   10.0    4.0   균형   균형
# 13    12.0   19.0   10.0    4.0   균형   균형
# ...    ...    ...    ...    ...  ...  ...
# 8753  20.0   19.0   10.0    4.0  불균형   균형
# 8754  27.0   19.0   10.0    4.0  불균형   균형
# 8755  39.0   19.0   10.0    4.0  불균형   균형
# 8756  44.0   19.0   10.0    4.0  불균형   균형
# 8759  36.0   19.0   10.0    4.0  불균형   균형
#
# [4317 rows x 16 columns]

# %%
t[t['p_1+']< 0.6]
# Out:
# Empty DataFrame
# Columns: [자치구, 대여소명, 년, 월, 일, 시간, lambda, mu, p_1+, L_s, 재고량, 3사분위수, 2사분위수, 1사분위수, 균형, 내 균형]
# Index: []

# %% [markdown]
# - 위 결과를 보면 l_s가 q1~q3사이에 있지만 자전거가 한대라도 있을 확률이 0.5이하이므로 불균형이다
# - 특히 19시, 20시의 경우 퇴근시간이므로 이시간에 불균형이면 이용에 불편을 초래함
# - 또한 21년 1월 19시의 경우 불균형인데도 불구하고 기존연구방법에서는 이를 균형으로 판단

# %%
for i in range(len(df_new)):
    if (df_new['3사분위수'][i]>=df_new['L_s'][i]) & (df_new['L_s'][i] >= df_new['1사분위수'][i]) & (df_new['p_1+'][i] < 0.6):
        df_new['내 균형'][i] = '불균형'

# %%
df_new
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s  \
# 0     송파구  송파나루역 4번 출구옆  2020  6   1   0     2.0   0.0  0.000000   0.000000
# 1     송파구  송파나루역 4번 출구옆  2020  6   1   1     1.0   2.0  0.499998   0.999931
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 3     송파구  송파나루역 4번 출구옆  2020  6   1   3     0.0   0.0  0.000000   0.000000
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 8757  송파구  송파나루역 4번 출구옆  2021  5  31  21    11.0  17.0  0.646919   1.826214
# 8758  송파구  송파나루역 4번 출구옆  2021  5  31  22     8.0  13.0  0.615323   1.597116
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
#        재고량  3사분위수  2사분위수  1사분위수   균형 내 균형
# 0      2.0   19.0   10.0    4.0  불균형  불균형
# 1      1.0   19.0   10.0    4.0  불균형  불균형
# 2      1.0   19.0   10.0    4.0  불균형   균형
# 3      1.0   19.0   10.0    4.0  불균형  불균형
# 4      2.0   19.0   10.0    4.0  불균형   균형
# ...    ...    ...    ...    ...  ...  ...
# 8755  39.0   19.0   10.0    4.0  불균형   균형
# 8756  44.0   19.0   10.0    4.0  불균형   균형
# 8757  38.0   19.0   10.0    4.0  불균형   균형
# 8758  33.0   19.0   10.0    4.0  불균형   균형
# 8759  36.0   19.0   10.0    4.0  불균형   균형
#
# [8760 rows x 16 columns]

# %%
len(df_new[df_new['균형'] == '불균형'])
# Out:
# 3833

# %%
len(df_new[df_new['내 균형'] == '불균형'])
# Out:
# 3680

# %%
len(df_new)
# Out:
# 8760

# %%
# TN

len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '불균형')])
# Out:
# 1603

# %%
# TP

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')])
# Out:
# 2850

# %%
# FN

len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '균형')])
# Out:
# 2230

# %%
# FP

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '불균형')])
# Out:
# 2077

# %%
# 정확도(기존방법과 내 방법의 일치율)

(len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) + len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '불균형')])) / len(df_new)
# Out:
# 0.5083333333333333

# %%
# 정밀도(기존 방법에서 균형으로 판단한 데이터 중 내가 균형이라고 판단한 비율)

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) / (len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) + len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '불균형')]))
# Out:
# 0.5784453014004465

# %%
# 재현율(내 방법에서 균형으로 판단한 것 중 기존 방법에서도 균형으로 판단한 비율)

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) / (len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) + len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '균형')]))
# Out:
# 0.5610236220472441

# %%
a = df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '균형')]
a
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s  \
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# 7     송파구  송파나루역 4번 출구옆  2020  6   1   7     3.0   2.0  0.999661  15.012188
# 15    송파구  송파나루역 4번 출구옆  2020  6   1  15    11.0   1.0  1.000000  16.900000
# 23    송파구  송파나루역 4번 출구옆  2020  6   1  23    13.0  10.0  0.997308  13.828166
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 8757  송파구  송파나루역 4번 출구옆  2021  5  31  21    11.0  17.0  0.646919   1.826214
# 8758  송파구  송파나루역 4번 출구옆  2021  5  31  22     8.0  13.0  0.615323   1.597116
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
#        재고량  3사분위수  2사분위수  1사분위수   균형 내 균형
# 2      1.0   19.0   10.0    4.0  불균형   균형
# 4      2.0   19.0   10.0    4.0  불균형   균형
# 7      3.0   19.0   10.0    4.0  불균형   균형
# 15    23.0   19.0   10.0    4.0  불균형   균형
# 23    20.0   19.0   10.0    4.0  불균형   균형
# ...    ...    ...    ...    ...  ...  ...
# 8755  39.0   19.0   10.0    4.0  불균형   균형
# 8756  44.0   19.0   10.0    4.0  불균형   균형
# 8757  38.0   19.0   10.0    4.0  불균형   균형
# 8758  33.0   19.0   10.0    4.0  불균형   균형
# 8759  36.0   19.0   10.0    4.0  불균형   균형
#
# [2230 rows x 16 columns]

# %%
len(a)
# Out:
# 2230

# %%
len(a[a['p_1+'] > 0.9])
# Out:
# 1685

# %%
len(a[a['p_1+'] > 0.8])
# Out:
# 1860

# %%
len(a[a['p_1+'] > 0.7])
# Out:
# 2036

# %%
len(a[a['p_1+'] > 0.6])
# Out:
# 2230

# %% [markdown]
# - 기존방법이 불균형으로 판단한 데이터 중 본 연구에서 균형으로 판단한 데이터는 76개이지만
# - 이 중 대여소에 적어도 자전거가 1대 있을 확률이 70%가 넘는 데이터가 70개로 무려 92%이상의 경우에 이용자가 대여소에 도착했을 때 자전거를 빌릴 수 있는 확률이 70%이상이었다.
# - 따라서 이러한 경우에는 자전거 재배치를 위한 대여소 내 재고의 균형/ 불균형을 판단할 경우에는 재배치를 할 필요가 없다고 판단하여 균형으로 판단할 수 있다.

# %%
b = df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '불균형')]
b
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+       L_s  \
# 11    송파구  송파나루역 4번 출구옆  2020  6   1  11     2.0   4.0  0.499998  0.999931
# 12    송파구  송파나루역 4번 출구옆  2020  6   1  12     3.0   6.0  0.499998  0.999931
# 16    송파구  송파나루역 4번 출구옆  2020  6   1  16     6.0  14.0  0.428571  0.749996
# 26    송파구  송파나루역 4번 출구옆  2020  6   2   2     1.0   3.0  0.333333  0.500000
# 29    송파구  송파나루역 4번 출구옆  2020  6   2   5     0.0   0.0  0.000000  0.000000
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...       ...
# 8718  송파구  송파나루역 4번 출구옆  2021  5  30   6     0.0   3.0  0.000000  0.000000
# 8719  송파구  송파나루역 4번 출구옆  2021  5  30   7     1.0   2.0  0.499998  0.999931
# 8745  송파구  송파나루역 4번 출구옆  2021  5  31   9     1.0   5.0  0.200000  0.250000
# 8746  송파구  송파나루역 4번 출구옆  2021  5  31  10     4.0   9.0  0.444444  0.799992
# 8752  송파구  송파나루역 4번 출구옆  2021  5  31  16     8.0  15.0  0.533328  1.142638
#
#        재고량  3사분위수  2사분위수  1사분위수  균형 내 균형
# 11    13.0   19.0   10.0    4.0  균형  불균형
# 12    10.0   19.0   10.0    4.0  균형  불균형
# 16    15.0   19.0   10.0    4.0  균형  불균형
# 26    18.0   19.0   10.0    4.0  균형  불균형
# 29    18.0   19.0   10.0    4.0  균형  불균형
# ...    ...    ...    ...    ...  ..  ...
# 8718  17.0   19.0   10.0    4.0  균형  불균형
# 8719  16.0   19.0   10.0    4.0  균형  불균형
# 8745  13.0   19.0   10.0    4.0  균형  불균형
# 8746   8.0   19.0   10.0    4.0  균형  불균형
# 8752  11.0   19.0   10.0    4.0  균형  불균형
#
# [2077 rows x 16 columns]

# %%
len(b)
# Out:
# 2077

# %%
len(b[(b['lambda'] > b['mu']) & (b['L_s'] > (15*0.7))])
# Out:
# 0

# %% [markdown]
# - 기존방법이 균형으로 판단한 데이터 중 본 연구에서 불균형으로 판단한 데이터는 68개이지만
# - 이 중 반납이 대여보다 많고 대여소 내 평균 자전거수(L_s)가 서울시 거치대율의 목표인 거치대수의 60~70%를 초과하는 경우가 63개로 90%이상의 경우에 불필요하게 자전거의 재고가 많다고 판단된다.
# - 따라서 이러한 경우에는 이용자들의 자전거 이용에는 문제가 없지만 주변 대여소의 재고가 부족하다면 자전거 재배치의 측면에서는 재배치를 할 필요가 있다고 판단하여 불균형으로 판단할 수 있다.

# %%
df_new
# Out:
#       자치구          대여소명     년  월   일  시간  lambda    mu      p_1+        L_s  \
# 0     송파구  송파나루역 4번 출구옆  2020  6   1   0     2.0   0.0  0.000000   0.000000
# 1     송파구  송파나루역 4번 출구옆  2020  6   1   1     1.0   2.0  0.499998   0.999931
# 2     송파구  송파나루역 4번 출구옆  2020  6   1   2     3.0   3.0  0.944444   8.500000
# 3     송파구  송파나루역 4번 출구옆  2020  6   1   3     0.0   0.0  0.000000   0.000000
# 4     송파구  송파나루역 4번 출구옆  2020  6   1   4     2.0   1.0  0.999996  16.000069
# ...   ...           ...   ... ..  ..  ..     ...   ...       ...        ...
# 8755  송파구  송파나루역 4번 출구옆  2021  5  31  19    23.0  11.0  0.999998  16.083364
# 8756  송파구  송파나루역 4번 출구옆  2021  5  31  20    17.0  12.0  0.999210  14.634141
# 8757  송파구  송파나루역 4번 출구옆  2021  5  31  21    11.0  17.0  0.646919   1.826214
# 8758  송파구  송파나루역 4번 출구옆  2021  5  31  22     8.0  13.0  0.615323   1.597116
# 8759  송파구  송파나루역 4번 출구옆  2021  5  31  23     5.0   2.0  1.000000  16.333335
#
#        재고량  3사분위수  2사분위수  1사분위수   균형 내 균형
# 0      2.0   19.0   10.0    4.0  불균형  불균형
# 1      1.0   19.0   10.0    4.0  불균형  불균형
# 2      1.0   19.0   10.0    4.0  불균형   균형
# 3      1.0   19.0   10.0    4.0  불균형  불균형
# 4      2.0   19.0   10.0    4.0  불균형   균형
# ...    ...    ...    ...    ...  ...  ...
# 8755  39.0   19.0   10.0    4.0  불균형   균형
# 8756  44.0   19.0   10.0    4.0  불균형   균형
# 8757  38.0   19.0   10.0    4.0  불균형   균형
# 8758  33.0   19.0   10.0    4.0  불균형   균형
# 8759  36.0   19.0   10.0    4.0  불균형   균형
#
# [8760 rows x 16 columns]

# %%
df_new.to_csv('./송파나루역 4번 출구옆 365일.csv', index = False, encoding = 'cp949')

# %% [markdown]
# # confusion matrix
#
# 0 |균형|불균형
# -|-|-
# 균형|TP|FP
# 불균형|FN|TN
#
#
# 1. 정확도 accuracy = 실제(내) 데이터와 예측(기존방법)데이터가 얼마나 같은지를 평가하는 지표 = TP + TN / TP+TN+FP+FN
# 2. 정밀도 precision = 균형으로 예측한 데이터 중 실제로 균형인 데이터 비율 = TP / TP+FP
# 3. 재현율 recall = 실제 균형 중 균형으로 예측한 비율 = TP / TP+FN
#
# => 정밀도에 초점. (불균형을 균형으로 예측하여 재배치하지 않으면 서비스에 차질)
