# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_excel('./1년 365일 8시 재고량.xlsx')
df
# Out:
#         자치구         대여소명  대여소번호     년  월   일  시간  거치대수  초기재고량
# 0       마포구   망원역 1번출구 앞    102  2020  6   1   8    20      5
# 1       마포구   망원역 1번출구 앞    102  2020  6   2   8    20      2
# 2       마포구   망원역 1번출구 앞    102  2020  6   3   8    20      1
# 3       마포구   망원역 1번출구 앞    102  2020  6   4   8    20     10
# 4       마포구   망원역 1번출구 앞    102  2020  6   5   8    20      1
# ...     ...          ...    ...   ... ..  ..  ..   ...    ...
# 731470  중랑구   중랑데시앙플렉스 앞   4815  2021  5  31   8     8      2
# 731471  강서구  이랜드글로벌R&D센터   3801  2021  5  28   8    10      0
# 731472  강서구  이랜드글로벌R&D센터   3801  2021  5  29   8    10      0
# 731473  강서구  이랜드글로벌R&D센터   3801  2021  5  30   8    10      1
# 731474  강서구  이랜드글로벌R&D센터   3801  2021  5  31   8    10      0
#
# [731475 rows x 9 columns]

# %%
df = df[(df['대여소명'] == '고속터미널역 8-1번, 8-2번 출구 사이')].reset_index(drop = True)
df
# Out:
#      자치구                     대여소명  대여소번호     년   월   일  시간  거치대수  초기재고량
# 0    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   1   8    20     12
# 1    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   2   8    20     11
# 2    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   3   8    20      5
# 3    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   4   8    20      9
# 4    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   5   8    20     17
# 5    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   6   8    20     10
# 6    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   7   8    20     13
# 7    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   8   8    20     25
# 8    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   9   8    20     20
# 9    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  10   8    20     15
# 10   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  11   8    20     21
# 11   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  12   8    20     14
# ...

# %%
data = pd.read_csv('./1년 1시간별 대여량, 반납량.csv', encoding = 'cp949')
data
# Out:
#           자치구           대여소명  대여소번호     년  월   일  시간    c  return_count  \
# 0         중랑구  (구)신한은행 중랑교지점   1442  2020  6   1   0  8.0           1.0
# 1         중랑구  (구)신한은행 중랑교지점   1442  2020  6   1   1  8.0           1.0
# 2         중랑구  (구)신한은행 중랑교지점   1442  2020  6   1   2  8.0           3.0
# 3         중랑구  (구)신한은행 중랑교지점   1442  2020  6   1   3  8.0           0.0
# 4         중랑구  (구)신한은행 중랑교지점   1442  2020  6   1   4  8.0           1.0
# ...       ...            ...    ...   ... ..  ..  ..  ...           ...
# 21137875  강서구        힐스테이트에코   2720  2021  5  31  19  9.0           7.0
# 21137876  강서구        힐스테이트에코   2720  2021  5  31  20  9.0           8.0
# 21137877  강서구        힐스테이트에코   2720  2021  5  31  21  9.0           4.0
# 21137878  강서구        힐스테이트에코   2720  2021  5  31  22  9.0           7.0
# 21137879  강서구        힐스테이트에코   2720  2021  5  31  23  9.0           0.0
#
#           rent_count
# 0                1.0
# 1                0.0
# 2                1.0
# ...

# %%
data = data[(data['대여소명'] == '고속터미널역 8-1번, 8-2번 출구 사이')].reset_index(drop = True)
data
# Out:
#       자치구                     대여소명  대여소번호     년  월   일  시간     c  \
# 0     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   0  24.0
# 1     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   1  24.0
# 2     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   2  24.0
# 3     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   3  24.0
# 4     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   4  24.0
# ...   ...                      ...    ...   ... ..  ..  ..   ...
# 8755  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  19  24.0
# 8756  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  20  24.0
# 8757  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  21  24.0
# 8758  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  22  24.0
# 8759  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  23  24.0
#
#       return_count  rent_count
# 0              0.0         0.0
# 1              2.0         3.0
# 2              0.0         0.0
# 3              0.0         0.0
# ...

# %%
df_new = pd.merge(data, df, on = ['자치구', '대여소명', '대여소번호', '년', '월', '일'], how = 'outer')
df_new.head()
# Out:
#    자치구                     대여소명  대여소번호     년  월  일  시간_x     c  return_count  \
# 0  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1     0  24.0           0.0
# 1  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1     1  24.0           2.0
# 2  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1     2  24.0           0.0
# 3  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1     3  24.0           0.0
# 4  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1     4  24.0           0.0
#
#    rent_count  시간_y  거치대수  초기재고량
# 0         0.0   8.0  20.0   12.0
# 1         3.0   8.0  20.0   12.0
# 2         0.0   8.0  20.0   12.0
# 3         0.0   8.0  20.0   12.0
# 4         0.0   8.0  20.0   12.0

# %%
df_new = df_new.drop(['시간_y'], axis = 1)
df_new = df_new.rename(columns = {'시간_x' : '시간'})
df_new
# Out:
#       자치구                     대여소명  대여소번호     년  월   일  시간     c  \
# 0     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   0  24.0
# 1     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   1  24.0
# 2     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   2  24.0
# 3     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   3  24.0
# 4     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   4  24.0
# ...   ...                      ...    ...   ... ..  ..  ..   ...
# 8755  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  19  24.0
# 8756  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  20  24.0
# 8757  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  21  24.0
# 8758  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  22  24.0
# 8759  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  23  24.0
#
#       return_count  rent_count  거치대수  초기재고량
# 0              0.0         0.0  20.0   12.0
# 1              2.0         3.0  20.0   12.0
# 2              0.0         0.0  20.0   12.0
# ...

# %%
df_new.fillna(0, inplace = True)
df_new
# Out:
#       자치구                     대여소명  대여소번호     년  월   일  시간     c  \
# 0     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   0  24.0
# 1     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   1  24.0
# 2     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   2  24.0
# 3     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   3  24.0
# 4     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   4  24.0
# ...   ...                      ...    ...   ... ..  ..  ..   ...
# 8755  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  19  24.0
# 8756  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  20  24.0
# 8757  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  21  24.0
# 8758  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  22  24.0
# 8759  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  23  24.0
#
#       return_count  rent_count  거치대수  초기재고량
# 0              0.0         0.0  20.0   12.0
# 1              2.0         3.0  20.0   12.0
# 2              0.0         0.0  20.0   12.0
# ...

# %%
a = df_new[df_new['시간'] == 8]
a
# Out:
#       자치구                     대여소명  대여소번호     년   월   일  시간     c  \
# 8     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   1   8  24.0
# 32    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   2   8  24.0
# 56    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   3   8  24.0
# 80    서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   4   8  24.0
# 104   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   5   8  24.0
# 128   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   6   8  24.0
# 152   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   7   8  24.0
# 176   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   8   8  24.0
# 200   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6   9   8  24.0
# 224   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  10   8  24.0
# 248   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  11   8  24.0
# 272   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  12   8  24.0
# 296   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020   6  13   8  24.0
# ...

# %%
b = df_new[df_new['시간'] != 8]
b['초기재고량'] = 0
b
# Out:
#       자치구                     대여소명  대여소번호     년  월   일  시간     c  \
# 0     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   0  24.0
# 1     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   1  24.0
# 2     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   2  24.0
# 3     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   3  24.0
# 4     서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6   1   4  24.0
# ...   ...                      ...    ...   ... ..  ..  ..   ...
# 8755  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  19  24.0
# 8756  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  20  24.0
# 8757  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  21  24.0
# 8758  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  22  24.0
# 8759  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2021  5  31  23  24.0
#
#       return_count  rent_count  거치대수  초기재고량
# 0              0.0         0.0  20.0      0
# 1              2.0         3.0  20.0      0
# 2              0.0         0.0  20.0      0
# ...

# %%
df_new_z = pd.merge(b, a, on = ['자치구', '대여소명', '대여소번호', '년', '월', '일','시간', 'c', 'return_count', 'rent_count', '거치대수', '초기재고량'], how = 'outer')
df_new_z.head()
# Out:
#    자치구                     대여소명  대여소번호     년  월  일  시간     c  return_count  \
# 0  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   0  24.0           0.0
# 1  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   1  24.0           2.0
# 2  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   2  24.0           0.0
# 3  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   3  24.0           0.0
# 4  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   4  24.0           0.0
#
#    rent_count  거치대수  초기재고량
# 0         0.0  20.0    0.0
# 1         3.0  20.0    0.0
# 2         0.0  20.0    0.0
# 3         0.0  20.0    0.0
# 4         0.0  20.0    0.0

# %%
df_new_z = df_new_z.sort_values(['자치구', '대여소명', '년', '월', '일', '시간'], ignore_index = True)
df_new_z = df_new_z.astype({'시간' : 'int64', 'c' : 'int64'})
df_new_z.head()
# Out:
#    자치구                     대여소명  대여소번호     년  월  일  시간   c  return_count  \
# 0  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   0  24           0.0
# 1  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   1  24           2.0
# 2  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   2  24           0.0
# 3  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   3  24           0.0
# 4  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   4  24           0.0
#
#    rent_count  거치대수  초기재고량
# 0         0.0  20.0    0.0
# 1         3.0  20.0    0.0
# 2         0.0  20.0    0.0
# 3         0.0  20.0    0.0
# 4         0.0  20.0    0.0

# %%
df_new_z['재고량'] = df_new_z['초기재고량'] + df_new_z['return_count'] - df_new_z['rent_count']
df_new_z.head(100)
# Out:
#     자치구                     대여소명  대여소번호     년  월  일  시간   c  return_count  \
# 0   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   0  24           0.0
# 1   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   1  24           2.0
# 2   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   2  24           0.0
# 3   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   3  24           0.0
# 4   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   4  24           0.0
# 5   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   5  24           3.0
# 6   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   6  24           5.0
# 7   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   7  24           1.0
# 8   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   8  24           4.0
# 9   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   9  24           6.0
# 10  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1  10  24           6.0
# 11  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1  11  24           4.0
# ...

# %%
for i in range(1, len(df_new_z)):
    if df_new_z['시간'][i] == 8:
        df_new_z['재고량'][i] = df_new_z['초기재고량'][i]
    else:
        df_new_z['재고량'][i] += df_new_z['재고량'][i - 1]
df_new_z.head(100)
# Out:
#     자치구                     대여소명  대여소번호     년  월  일  시간   c  return_count  \
# 0   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   0  24           0.0
# 1   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   1  24           2.0
# 2   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   2  24           0.0
# 3   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   3  24           0.0
# 4   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   4  24           0.0
# 5   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   5  24           3.0
# 6   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   6  24           5.0
# 7   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   7  24           1.0
# 8   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   8  24           4.0
# 9   서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1   9  24           6.0
# 10  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1  10  24           6.0
# 11  서초구  고속터미널역 8-1번, 8-2번 출구 사이   2219  2020  6  1  11  24           4.0
# ...

# %%
df_new_z = df_new_z.drop(['대여소번호', 'c', 'return_count', 'rent_count', '거치대수', '초기재고량'], axis = 1)
df_new_z
# Out:
#       자치구                     대여소명     년  월   일  시간   재고량
# 0     서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020  6   1   0   0.0
# 1     서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020  6   1   1  -1.0
# 2     서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020  6   1   2  -1.0
# 3     서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020  6   1   3  -1.0
# 4     서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020  6   1   4  -1.0
# ...   ...                      ...   ... ..  ..  ..   ...
# 8755  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2021  5  31  19  31.0
# 8756  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2021  5  31  20  25.0
# 8757  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2021  5  31  21  21.0
# 8758  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2021  5  31  22  21.0
# 8759  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2021  5  31  23  19.0
#
# [8760 rows x 7 columns]

# %%
sol = df_new_z.groupby(['자치구', '대여소명', '년', '월', '시간'])['재고량'].sum().reset_index()
sol
# Out:
#      자치구                     대여소명     년   월  시간    재고량
# 0    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   0  877.0
# 1    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   1  858.0
# 2    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   2  856.0
# 3    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   3  869.0
# 4    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   4  881.0
# 5    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   5  916.0
# 6    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   6  944.0
# 7    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   7  948.0
# 8    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   8  619.0
# 9    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   9  654.0
# 10   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  10  683.0
# 11   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  11  677.0
# 12   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  12  716.0
# 13   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  13  726.0
# 14   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  14  744.0
# 15   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  15  721.0
# ...

# %%
sol['재고량'] = sol['재고량'] / 30
sol
# Out:
#      자치구                     대여소명     년   월  시간        재고량
# 0    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   0  29.233333
# 1    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   1  28.600000
# 2    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   2  28.533333
# 3    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   3  28.966667
# 4    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   4  29.366667
# 5    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   5  30.533333
# 6    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   6  31.466667
# 7    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   7  31.600000
# 8    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   8  20.633333
# 9    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   9  21.800000
# 10   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  10  22.766667
# 11   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  11  22.566667
# 12   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  12  23.866667
# 13   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  13  24.200000
# 14   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  14  24.800000
# ...

# %%
answer = sol.copy()

# %%
answer['3사분위수'] = np.percentile(answer['재고량'],75)
answer['2사분위수'] = np.percentile(answer['재고량'],50)
answer['1사분위수'] = np.percentile(answer['재고량'],25)
answer
# Out:
#      자치구                     대여소명     년   월  시간        재고량      3사분위수  \
# 0    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   0  29.233333  20.316667
# 1    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   1  28.600000  20.316667
# 2    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   2  28.533333  20.316667
# 3    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   3  28.966667  20.316667
# 4    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   4  29.366667  20.316667
# 5    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   5  30.533333  20.316667
# 6    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   6  31.466667  20.316667
# 7    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   7  31.600000  20.316667
# 8    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   8  20.633333  20.316667
# 9    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   9  21.800000  20.316667
# 10   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  10  22.766667  20.316667
# 11   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  11  22.566667  20.316667
# ...

# %%
answer['균형'] = '균형'
for i in range(len(answer)):
    if answer['3사분위수'][i]>=answer['재고량'][i] >= answer['1사분위수'][i]:
        answer['균형'][i] = '균형'
    else:
        answer['균형'][i] = '불균형'
answer
# Out:
#      자치구                     대여소명     년   월  시간        재고량      3사분위수  \
# 0    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   0  29.233333  20.316667
# 1    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   1  28.600000  20.316667
# 2    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   2  28.533333  20.316667
# 3    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   3  28.966667  20.316667
# 4    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   4  29.366667  20.316667
# 5    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   5  30.533333  20.316667
# 6    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   6  31.466667  20.316667
# 7    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   7  31.600000  20.316667
# 8    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   8  20.633333  20.316667
# 9    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6   9  21.800000  20.316667
# 10   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  10  22.766667  20.316667
# 11   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2020   6  11  22.566667  20.316667
# ...

# %%
answer.to_csv('./고속터미널역 8-1번, 8-2번 출구 사이 균형, 불균형.csv', index = False, encoding = 'cp949')
