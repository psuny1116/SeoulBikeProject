# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df_new1 = pd.read_csv('./data/file/공공자전거 대여이력_2020.06.csv', encoding='cp949')
df_new2 = pd.read_csv('./data/file/공공자전거 대여이력_2020.07.csv', encoding='cp949')
df_new3 = pd.read_csv('./data/file/공공자전거 대여이력_2020.08.csv', encoding='cp949')
df_new4 = pd.read_csv('./data/file/공공자전거 대여이력_2020.09.csv', encoding='cp949')
df_new5 = pd.read_csv('./data/file/공공자전거 대여이력_2020.10.csv', encoding='cp949')
df_new6 = pd.read_csv('./data/file/공공자전거 대여이력_2020.11.csv', encoding='cp949')
df_new7 = pd.read_csv('./data/file/공공자전거 대여이력_2020.12.csv', encoding='cp949')
df_new8 = pd.read_csv('./data/file/공공자전거 대여이력_2021.01.csv', encoding='cp949')
df_new9 = pd.read_csv('./data/file/공공자전거 대여이력_2021.02.csv', encoding='cp949')
df_new10 = pd.read_csv('./data/file/공공자전거 대여이력_2021.03.csv', encoding='cp949')
df_new11 = pd.read_csv('./data/file/공공자전거 대여이력_2021.04.csv', encoding='cp949')
df_new12 = pd.read_csv('./data/file/공공자전거 대여이력_2021.05.csv', encoding='cp949')

# %%
df_new = pd.merge(df_new1, df_new2, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new3, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new4, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new5, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new6, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new7, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new8, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new9, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new10, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new11, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new12, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new
# Out:
#               자전거번호                 대여일시  대여대여소번호           대여대여소명  대여거치대  \
# 0         SPB-36260  2020-06-01 00:00:35     1681         현대6차 아파트      0
# 1         SPB-36146  2020-06-01 00:01:47      816      신용산역 6번출구 앞      0
# 2         SPB-33273  2020-06-01 00:03:05     1050       둔촌역 3번 출입구      0
# 3         SPB-35969  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)      0
# 4         SPB-30703  2020-06-01 00:00:46     1132         등촌역 7번출구      0
# ...             ...                  ...      ...              ...    ...
# 25968004  SPB-31282  2021-05-31 23:48:22     2190             도원맨션      0
# 25968005  SPB-50316  2021-05-31 23:55:04     1106           신방화사거리      0
# 25968006  SPB-44035  2021-05-31 23:51:12     1627        수락산역 4번출구      0
# 25968007  SPB-50409  2021-05-31 23:31:37     1008  암사역 3번출구(국민은행앞)      0
# 25968008  SPB-55881  2021-05-31 23:51:36     2377       수서역 5번출구 뒤      0
#
#                          반납일시  반납대여소번호           반납대여소명  반납거치대  이용시간     이용거리
# ...

# %%
df = df_new[~df_new['대여대여소명'].str.contains('\?')]
df
# Out:
#               자전거번호                 대여일시  대여대여소번호           대여대여소명  대여거치대  \
# 0         SPB-36260  2020-06-01 00:00:35     1681         현대6차 아파트      0
# 1         SPB-36146  2020-06-01 00:01:47      816      신용산역 6번출구 앞      0
# 2         SPB-33273  2020-06-01 00:03:05     1050       둔촌역 3번 출입구      0
# 3         SPB-35969  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)      0
# 4         SPB-30703  2020-06-01 00:00:46     1132         등촌역 7번출구      0
# ...             ...                  ...      ...              ...    ...
# 25968004  SPB-31282  2021-05-31 23:48:22     2190             도원맨션      0
# 25968005  SPB-50316  2021-05-31 23:55:04     1106           신방화사거리      0
# 25968006  SPB-44035  2021-05-31 23:51:12     1627        수락산역 4번출구      0
# 25968007  SPB-50409  2021-05-31 23:31:37     1008  암사역 3번출구(국민은행앞)      0
# 25968008  SPB-55881  2021-05-31 23:51:36     2377       수서역 5번출구 뒤      0
#
#                          반납일시  반납대여소번호           반납대여소명  반납거치대  이용시간     이용거리
# ...

# %%
df_new = df[~df['반납대여소명'].str.contains('\?')]
df_new
# Out:
#               자전거번호                 대여일시  대여대여소번호           대여대여소명  대여거치대  \
# 0         SPB-36260  2020-06-01 00:00:35     1681         현대6차 아파트      0
# 1         SPB-36146  2020-06-01 00:01:47      816      신용산역 6번출구 앞      0
# 2         SPB-33273  2020-06-01 00:03:05     1050       둔촌역 3번 출입구      0
# 3         SPB-35969  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)      0
# 4         SPB-30703  2020-06-01 00:00:46     1132         등촌역 7번출구      0
# ...             ...                  ...      ...              ...    ...
# 25968004  SPB-31282  2021-05-31 23:48:22     2190             도원맨션      0
# 25968005  SPB-50316  2021-05-31 23:55:04     1106           신방화사거리      0
# 25968006  SPB-44035  2021-05-31 23:51:12     1627        수락산역 4번출구      0
# 25968007  SPB-50409  2021-05-31 23:31:37     1008  암사역 3번출구(국민은행앞)      0
# 25968008  SPB-55881  2021-05-31 23:51:36     2377       수서역 5번출구 뒤      0
#
#                          반납일시  반납대여소번호           반납대여소명  반납거치대  이용시간     이용거리
# ...

# %%
df_new = df_new.drop(['자전거번호', '대여거치대', '반납거치대', '이용거리'], axis = 1)
df_new.head()
# Out:
#                   대여일시  대여대여소번호           대여대여소명                 반납일시  \
# 0  2020-06-01 00:00:35     1681         현대6차 아파트  2020-06-01 00:05:24
# 1  2020-06-01 00:01:47      816      신용산역 6번출구 앞  2020-06-01 00:05:54
# 2  2020-06-01 00:03:05     1050       둔촌역 3번 출입구  2020-06-01 00:05:59
# 3  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)  2020-06-01 00:06:10
# 4  2020-06-01 00:00:46     1132         등촌역 7번출구  2020-06-01 00:06:53
#
#    반납대여소번호           반납대여소명  이용시간
# 0     1665          양지근린공원앞     5
# 1      829            베르가모앞     4
# 2     1078            둔촌사거리     3
# 3     1209  잠실나루역 (2번 출구 쪽)     2
# 4     1169        염창역 1번 출구     6

# %%
df = df_new.copy()

# %%
df['대여일시'] = pd.to_datetime(df['대여일시'])
df['반납일시'] = pd.to_datetime(df['반납일시'])

df['대여년'] = df['대여일시'].dt.year
df['대여월'] = df['대여일시'].dt.month
df['대여일'] = df['대여일시'].dt.day
df['대여시간'] = df['대여일시'].dt.hour

df['반납년'] = df['반납일시'].dt.year
df['반납월'] = df['반납일시'].dt.month
df['반납일'] = df['반납일시'].dt.day
df['반납시간'] = df['반납일시'].dt.hour

# %%
df = df.sort_values('대여일시', ignore_index = True)
df.head()
# Out:
#                  대여일시  대여대여소번호              대여대여소명                반납일시  \
# 0 2020-06-01 00:00:00      106          합정역 7번출구 앞 2020-06-01 00:41:00
# 1 2020-06-01 00:00:16      956             응암시장교차로 2020-06-01 00:08:25
# 2 2020-06-01 00:00:24     2340  삼호물산버스정류장(23370) 옆 2020-06-01 00:14:50
# 3 2020-06-01 00:00:26     1057              능골근린공원 2020-06-01 00:07:13
# 4 2020-06-01 00:00:32     3511            응봉역 1번출구 2020-06-01 00:21:38
#
#    반납대여소번호     반납대여소명  이용시간   대여년  대여월  대여일  대여시간   반납년  반납월  반납일  반납시간
# 0      830   청암자이아파트앞    40  2020    6    1     0  2020    6    1     0
# 1      939   은평구청 교차로     7  2020    6    1     0  2020    6    1     0
# 2     2263  바우뫼문화복지회관    13  2020    6    1     0  2020    6    1     0
# 3     1057     능골근린공원     7  2020    6    1     0  2020    6    1     0
# 4      362   청계8가 사거리    21  2020    6    1     0  2020    6    1     0

# %%
df_rental = df[['대여일시', '대여대여소명','대여대여소번호', '대여년', '대여월', '대여일', '대여시간']]
df_rental.reset_index(drop = True, inplace = True)
df_rental.head()
# Out:
#                  대여일시              대여대여소명  대여대여소번호   대여년  대여월  대여일  대여시간
# 0 2020-06-01 00:00:00          합정역 7번출구 앞      106  2020    6    1     0
# 1 2020-06-01 00:00:16             응암시장교차로      956  2020    6    1     0
# 2 2020-06-01 00:00:24  삼호물산버스정류장(23370) 옆     2340  2020    6    1     0
# 3 2020-06-01 00:00:26              능골근린공원     1057  2020    6    1     0
# 4 2020-06-01 00:00:32            응봉역 1번출구     3511  2020    6    1     0

# %%
df_rental = df_rental[df_rental['대여대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
df_rental
# Out:
#                         대여일시             대여대여소명  대여대여소번호   대여년  대여월  대여일  대여시간
# 136      2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     0
# 6109     2020-06-01 07:17:57  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     7
# 6783     2020-06-01 07:29:14  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     7
# 6889     2020-06-01 07:30:48  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     7
# 9565     2020-06-01 08:02:26  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     8
# ...                      ...                ...      ...   ...  ...  ...   ...
# 25920843 2021-05-31 22:40:31  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 25922100 2021-05-31 22:58:01  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 25922659 2021-05-31 23:06:34  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 25923363 2021-05-31 23:18:47  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 25923652 2021-05-31 23:24:50  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
#
# ...

# %%
df_return = df[['반납일시', '반납대여소명', '반납대여소번호','반납년', '반납월', '반납일', '반납시간']]
df_return.reset_index(drop = True, inplace = True)
df_return
# Out:
#                         반납일시           반납대여소명  반납대여소번호   반납년  반납월  반납일  반납시간
# 0        2020-06-01 00:41:00         청암자이아파트앞      830  2020    6    1     0
# 1        2020-06-01 00:08:25         은평구청 교차로      939  2020    6    1     0
# 2        2020-06-01 00:14:50        바우뫼문화복지회관     2263  2020    6    1     0
# 3        2020-06-01 00:07:13           능골근린공원     1057  2020    6    1     0
# 4        2020-06-01 00:21:38         청계8가 사거리      362  2020    6    1     0
# ...                      ...              ...      ...   ...  ...  ...   ...
# 25924496 2021-05-31 23:59:57        방화역 4번출구앞     1103  2021    5   31    23
# 25924497 2021-05-31 23:59:27  석촌호교차로 (스타벅스 앞)     1293  2021    5   31    23
# 25924498 2021-05-31 23:59:27          도봉세무서 앞     1560  2021    5   31    23
# 25924499 2021-05-31 23:58:12     동대문롯데캐슬아파트 앞      657  2021    5   31    23
# 25924500 2021-05-31 23:59:45    당고개입구오거리 당현천변     4004  2021    5   31    23
#
# [25924501 rows x 7 columns]

# %%
df_return = df_return[df_return['반납대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
df_return
# Out:
#                         반납일시             반납대여소명  반납대여소번호   반납년  반납월  반납일  반납시간
# 3132     2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     4
# 4287     2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# 4359     2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# 4625     2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# 4688     2020-06-01 06:59:42  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# ...                      ...                ...      ...   ...  ...  ...   ...
# 25919365 2021-05-31 22:34:42  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 25919758 2021-05-31 22:42:32  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 25921663 2021-05-31 23:02:56  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 25922005 2021-05-31 23:05:41  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 25922867 2021-05-31 23:17:55  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
#
# ...

# %%
df_rental.reset_index(drop=True, inplace = True)
df_return.reset_index(drop=True, inplace = True)

# %%
df_rental['대여'] = 1
df_rental
# Out:
#                      대여일시             대여대여소명  대여대여소번호   대여년  대여월  대여일  대여시간  \
# 0     2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     0
# 1     2020-06-01 07:17:57  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     7
# 2     2020-06-01 07:29:14  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     7
# 3     2020-06-01 07:30:48  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     7
# 4     2020-06-01 08:02:26  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     8
# ...                   ...                ...      ...   ...  ...  ...   ...
# 67120 2021-05-31 22:40:31  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 67121 2021-05-31 22:58:01  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 67122 2021-05-31 23:06:34  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 67123 2021-05-31 23:18:47  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 67124 2021-05-31 23:24:50  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
#
#        대여
# 0       1
# 1       1
# 2       1
# ...

# %%
df_rental.columns = ['일시','대여소명','대여소번호', '년','월','일', '시간','대여']
df_rental
# Out:
#                        일시               대여소명  대여소번호     년  월   일  시간  대여
# 0     2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   0   1
# 1     2020-06-01 07:17:57  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   7   1
# 2     2020-06-01 07:29:14  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   7   1
# 3     2020-06-01 07:30:48  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   7   1
# 4     2020-06-01 08:02:26  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   8   1
# ...                   ...                ...    ...   ... ..  ..  ..  ..
# 67120 2021-05-31 22:40:31  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  22   1
# 67121 2021-05-31 22:58:01  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  22   1
# 67122 2021-05-31 23:06:34  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23   1
# 67123 2021-05-31 23:18:47  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23   1
# 67124 2021-05-31 23:24:50  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23   1
#
# [67125 rows x 8 columns]

# %%
df_return['반납'] = 1
df_return
# Out:
#                      반납일시             반납대여소명  반납대여소번호   반납년  반납월  반납일  반납시간  \
# 0     2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     4
# 1     2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# 2     2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# 3     2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# 4     2020-06-01 06:59:42  롯데월드타워(잠실역2번출구 쪽)     1210  2020    6    1     6
# ...                   ...                ...      ...   ...  ...  ...   ...
# 67605 2021-05-31 22:34:42  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 67606 2021-05-31 22:42:32  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    22
# 67607 2021-05-31 23:02:56  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 67608 2021-05-31 23:05:41  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
# 67609 2021-05-31 23:17:55  롯데월드타워(잠실역2번출구 쪽)     1210  2021    5   31    23
#
#        반납
# 0       1
# 1       1
# 2       1
# ...

# %%
df_return.columns = ['일시','대여소명','대여소번호', '년','월','일', '시간','반납']
df_return
# Out:
#                        일시               대여소명  대여소번호     년  월   일  시간  반납
# 0     2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   4   1
# 1     2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6   1
# 2     2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6   1
# 3     2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6   1
# 4     2020-06-01 06:59:42  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6   1
# ...                   ...                ...    ...   ... ..  ..  ..  ..
# 67605 2021-05-31 22:34:42  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  22   1
# 67606 2021-05-31 22:42:32  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  22   1
# 67607 2021-05-31 23:02:56  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23   1
# 67608 2021-05-31 23:05:41  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23   1
# 67609 2021-05-31 23:17:55  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23   1
#
# [67610 rows x 8 columns]

# %%
df = pd.merge(df_rental, df_return, on=['일시', '대여소명','대여소번호','년', '월','일', '시간'], how='outer')
df = df.fillna(0)
df = df.sort_values('일시', ignore_index = True)
df
# Out:
#                         일시               대여소명  대여소번호     년  월   일  시간   대여  \
# 0      2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   0  1.0
# 1      2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   4  0.0
# 2      2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6  0.0
# 3      2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6  0.0
# 4      2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6  0.0
# ...                    ...                ...    ...   ... ..  ..  ..  ...
# 134429 2021-05-31 23:05:41  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  0.0
# 134430 2021-05-31 23:06:34  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  1.0
# 134431 2021-05-31 23:17:55  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  0.0
# 134432 2021-05-31 23:18:47  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  1.0
# 134433 2021-05-31 23:24:50  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  1.0
#
#          반납
# 0       0.0
# 1       1.0
# 2       1.0
# 3       1.0
# ...

# %%
df['반납-대여'] = df['반납'] - df['대여']
df
# Out:
#                         일시               대여소명  대여소번호     년  월   일  시간   대여  \
# 0      2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   0  1.0
# 1      2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   4  0.0
# 2      2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6  0.0
# 3      2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6  0.0
# 4      2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   6  0.0
# ...                    ...                ...    ...   ... ..  ..  ..  ...
# 134429 2021-05-31 23:05:41  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  0.0
# 134430 2021-05-31 23:06:34  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  1.0
# 134431 2021-05-31 23:17:55  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  0.0
# 134432 2021-05-31 23:18:47  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  1.0
# 134433 2021-05-31 23:24:50  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31  23  1.0
#
#          반납  반납-대여
# 0       0.0   -1.0
# 1       1.0    1.0
# ...

# %%
df['현재재고'] = 0
df['현재재고'][0] = -1

# %%
for i in range(1, len(df)):
    df['현재재고'][i] = df['현재재고'][i - 1] + df['반납-대여'][i]
df.head(100)
# Out:
#                     일시               대여소명  대여소번호     년  월  일  시간   대여   반납  \
# 0  2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   0  1.0  0.0
# 1  2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   4  0.0  1.0
# 2  2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   6  0.0  1.0
# 3  2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   6  0.0  1.0
# 4  2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   6  0.0  1.0
# 5  2020-06-01 06:59:42  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   6  0.0  1.0
# 6  2020-06-01 07:09:23  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   7  0.0  1.0
# 7  2020-06-01 07:13:24  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   7  0.0  1.0
# 8  2020-06-01 07:15:57  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   7  0.0  1.0
# 9  2020-06-01 07:17:57  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   7  1.0  0.0
# 10 2020-06-01 07:20:28  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6  1   7  0.0  1.0
# ...

# %%
data = pd.read_excel('./롯데월드타워(잠실역2번출구 쪽) 1년 365일 8시 재고량.xlsx')
data = data.drop(['자치구'], axis = 1)
data
# Out:
#                             일시               대여소명  대여소번호     년  월   일  시간  재고량
# 0   2020-01-01 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   1   8    1
# 1   2020-01-02 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   2   8    4
# 2   2020-01-03 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   3   8    7
# 3   2020-01-04 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   4   8    6
# 4   2020-01-05 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   5   8    2
# ..                         ...                ...    ...   ... ..  ..  ..  ...
# 500 2021-05-27 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  27   8   11
# 501 2021-05-28 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  28   8    9
# 502 2021-05-29 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  29   8    2
# 503 2021-05-30 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  30   8    6
# 504 2021-05-31 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2021  5  31   8   24
#
# [505 rows x 8 columns]

# %%
df_new = pd.merge(df, data, on = ['일시', '대여소명', '대여소번호', '년', '월', '일', '시간'], how = 'outer')
df_new = df_new.sort_values('일시', ignore_index = True)
df_new.head(100)
# Out:
#                            일시               대여소명  대여소번호     년  월   일  시간  대여  \
# 0  2020-01-01 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   1   8 NaN
# 1  2020-01-02 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   2   8 NaN
# 2  2020-01-03 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   3   8 NaN
# 3  2020-01-04 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   4   8 NaN
# 4  2020-01-05 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   5   8 NaN
# 5  2020-01-06 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   6   8 NaN
# 6  2020-01-07 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   7   8 NaN
# 7  2020-01-08 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   8   8 NaN
# 8  2020-01-09 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1   9   8 NaN
# 9  2020-01-10 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1  10   8 NaN
# 10 2020-01-11 08:00:00.000001  롯데월드타워(잠실역2번출구 쪽)   1210  2020  1  11   8 NaN
# ...

# %%
df.to_csv('./1년 롯데월드타워(잠실역2번출구 쪽) 대여량, 반납량.csv', index = False, encoding = 'cp949')

# %%
df1 = df[df['월'] == 1].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2021, 24*31*len(stops)),'월':np.repeat(1, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame1 = pd.concat([stops2,Dayhour],axis=1)

# %%
df2 = df[df['월'] == 2].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2021, 24*28*len(stops)),'월':np.repeat(2, 24*28*len(stops)),'일':np.repeat(np.arange(1,29), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),28)})
stops2 = pd.concat([stops] * 24*28).reset_index(drop=True)
Dayhour_frame2= pd.concat([stops2,Dayhour],axis=1)

# %%
df3 = df[df['월'] == 3].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2021, 24*31*len(stops)),'월':np.repeat(3, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame3 = pd.concat([stops2,Dayhour],axis=1)

# %%
df4 = df[df['월'] == 4].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2021, 24*30*len(stops)),'월':np.repeat(4, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame4 = pd.concat([stops2,Dayhour],axis=1)

# %%
df5 = df[df['월'] == 5].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2021, 24*31*len(stops)),'월':np.repeat(5, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame5 = pd.concat([stops2,Dayhour],axis=1)

# %%
df6 = df[df['월'] == 6].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*30*len(stops)),'월':np.repeat(6, 24*30*len(stops)), '일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame6 = pd.concat([stops2,Dayhour],axis=1)

# %%
df7 = df[df['월'] == 7].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*31*len(stops)),'월':np.repeat(7, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame7 = pd.concat([stops2,Dayhour],axis=1)

# %%
df8 = df[df['월'] == 8].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*31*len(stops)),'월':np.repeat(8, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame8 = pd.concat([stops2,Dayhour],axis=1)

# %%
df9 = df[df['월'] == 9].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*30*len(stops)),'월':np.repeat(9, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame9 = pd.concat([stops2,Dayhour],axis=1)

# %%
df10 = df[df['월'] == 10].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*31*len(stops)),'월':np.repeat(10, 24*31*len(stops)), '일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame10 = pd.concat([stops2,Dayhour],axis=1)

# %%
df11 = df[df['월'] == 11].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*30*len(stops)),'월':np.repeat(11, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame11 = pd.concat([stops2,Dayhour],axis=1)

# %%
df12 = df[df['월'] == 12].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'년':np.repeat(2020, 24*31*len(stops)),'월':np.repeat(12, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame12 = pd.concat([stops2,Dayhour],axis=1)

# %%
df = pd.merge(df,Dayhour_frame1, on = ['대여소명','대여소번호','년', '월', '일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame2, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame3, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame4, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame5, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame6, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame7, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame8, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame9, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame10, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame11, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df = pd.merge(df,Dayhour_frame12, on = ['대여소명','대여소번호','년', '월', '일','시간'],how='outer')
df
# Out:
#                         일시               대여소명  대여소번호     년   월   일  시간   대여  \
# 0      2020-06-01 00:10:06  롯데월드타워(잠실역2번출구 쪽)   1210  2020   6   1   0  1.0
# 1      2020-06-01 04:44:25  롯데월드타워(잠실역2번출구 쪽)   1210  2020   6   1   4  0.0
# 2      2020-06-01 06:34:50  롯데월드타워(잠실역2번출구 쪽)   1210  2020   6   1   6  0.0
# 3      2020-06-01 06:40:39  롯데월드타워(잠실역2번출구 쪽)   1210  2020   6   1   6  0.0
# 4      2020-06-01 06:56:00  롯데월드타워(잠실역2번출구 쪽)   1210  2020   6   1   6  0.0
# ...                    ...                ...    ...   ...  ..  ..  ..  ...
# 135989                 NaT  롯데월드타워(잠실역2번출구 쪽)   1210  2020  12  30  23  NaN
# 135990                 NaT  롯데월드타워(잠실역2번출구 쪽)   1210  2020  12  31   1  NaN
# 135991                 NaT  롯데월드타워(잠실역2번출구 쪽)   1210  2020  12  31   3  NaN
# 135992                 NaT  롯데월드타워(잠실역2번출구 쪽)   1210  2020  12  31   4  NaN
# 135993                 NaT  롯데월드타워(잠실역2번출구 쪽)   1210  2020  12  31  23  NaN
#
#          반납
# 0       0.0
# 1       1.0
# 2       1.0
# ...

# %%
df = pd.merge(df, return_ubound, on=['대여소명','대여소번호'], how='outer')
df.fillna(0, inplace=True)
df
# Out:
#                    대여소명  대여소번호     년   월   일  시간  return_count  rent_count  \
# 0         뚝섬유원지역 1번출구 앞    502  2021   5   2  17         262.0       119.0
# 1         뚝섬유원지역 1번출구 앞    502  2021   5   5  18         248.0       145.0
# 2         뚝섬유원지역 1번출구 앞    502  2021   5   2  16         246.0       194.0
# 3         뚝섬유원지역 1번출구 앞    502  2021   5   5  17         235.0       182.0
# 4         뚝섬유원지역 1번출구 앞    502  2021   5   5  16         230.0       179.0
# ...                 ...    ...   ...  ..  ..  ..           ...         ...
# 21698515         상암단말정비  99998  2020  12  31  19           0.0         0.0
# 21698516         상암단말정비  99998  2020  12  31  20           0.0         0.0
# 21698517         상암단말정비  99998  2020  12  31  21           0.0         0.0
# 21698518         상암단말정비  99998  2020  12  31  22           0.0         0.0
# 21698519         상암단말정비  99998  2020  12  31  23           0.0         0.0
#
#           upperbound
# 0               49.0
# 1               49.0
# ...

# %%
df = df.sort_values(['대여소명', '대여소번호','년', '월', '일', '시간'], ignore_index = True)
df
# Out:
#                    대여소명  대여소번호     년  월   일  시간  return_count  rent_count  \
# 0         (구)신한은행 중랑교지점   1442  2020  6   1   0           1.0         1.0
# 1         (구)신한은행 중랑교지점   1442  2020  6   1   1           1.0         0.0
# 2         (구)신한은행 중랑교지점   1442  2020  6   1   2           3.0         1.0
# 3         (구)신한은행 중랑교지점   1442  2020  6   1   3           0.0         0.0
# 4         (구)신한은행 중랑교지점   1442  2020  6   1   4           1.0         0.0
# ...                 ...    ...   ... ..  ..  ..           ...         ...
# 21698515        힐스테이트에코   2720  2021  5  31  19           7.0        15.0
# 21698516        힐스테이트에코   2720  2021  5  31  20           8.0        20.0
# 21698517        힐스테이트에코   2720  2021  5  31  21           4.0        27.0
# 21698518        힐스테이트에코   2720  2021  5  31  22           7.0        11.0
# 21698519        힐스테이트에코   2720  2021  5  31  23           0.0         0.0
#
#           upperbound
# 0                8.0
# 1                8.0
# ...

# %%
df = df.rename(columns = {'upperbound' : 'c'})
df
# Out:
#                    대여소명  대여소번호     년  월   일  시간  return_count  rent_count    c
# 0         (구)신한은행 중랑교지점   1442  2020  6   1   0           1.0         1.0  8.0
# 1         (구)신한은행 중랑교지점   1442  2020  6   1   1           1.0         0.0  8.0
# 2         (구)신한은행 중랑교지점   1442  2020  6   1   2           3.0         1.0  8.0
# 3         (구)신한은행 중랑교지점   1442  2020  6   1   3           0.0         0.0  8.0
# 4         (구)신한은행 중랑교지점   1442  2020  6   1   4           1.0         0.0  8.0
# ...                 ...    ...   ... ..  ..  ..           ...         ...  ...
# 21698515        힐스테이트에코   2720  2021  5  31  19           7.0        15.0  9.0
# 21698516        힐스테이트에코   2720  2021  5  31  20           8.0        20.0  9.0
# 21698517        힐스테이트에코   2720  2021  5  31  21           4.0        27.0  9.0
# 21698518        힐스테이트에코   2720  2021  5  31  22           7.0        11.0  9.0
# 21698519        힐스테이트에코   2720  2021  5  31  23           0.0         0.0  9.0
#
# ...

# %%
# 일부 칼럼 타입 카테고리로 변환

df = df.astype({'대여소명' : 'category', '대여소번호' : 'category'})

# %%
station = pd.read_csv('./대학원/데이터/정리 데이터/공공자전거 대여소 정보(21.06월 기준).csv')
station.head()
# Out:
#    대여소 번호   보관소(대여소)명  자치구               상세주소         위도          경도  \
# 0     102  망원역 1번출구 앞  마포구  서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 1     103  망원역 2번출구 앞  마포구  서울특별시 마포구 월드컵로 79  37.554951  126.910835
# 2     104  합정역 1번출구 앞  마포구   서울특별시 마포구 양화로 59  37.550629  126.914986
# 3     105  합정역 5번출구 앞  마포구   서울특별시 마포구 양화로 48  37.550007  126.914825
# 4     106  합정역 7번출구 앞  마포구    서울특별시 마포구 독막로 4  37.548645  126.912826
#
#         설치 시기  LCD 거치대수  QR 거치대수 운영 방식
# 0  2015-09-06      20.0      NaN   LCD
# 1  2015-09-06      14.0      NaN   LCD
# 2  2015-09-06      13.0      NaN   LCD
# 3  2015-09-06       5.0      NaN   LCD
# 4  2015-09-06      10.0      NaN   LCD

# %%
station = station.astype({'자치구' : 'category', '대여소 번호' : 'category'})

# %%
station = station.rename(columns = {'대여소 번호' : '대여소번호'})
station
# Out:
#      대여소번호     보관소(대여소)명  자치구               상세주소         위도          경도  \
# 0      102    망원역 1번출구 앞  마포구  서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 1      103    망원역 2번출구 앞  마포구  서울특별시 마포구 월드컵로 79  37.554951  126.910835
# 2      104    합정역 1번출구 앞  마포구   서울특별시 마포구 양화로 59  37.550629  126.914986
# 3      105    합정역 5번출구 앞  마포구   서울특별시 마포구 양화로 48  37.550007  126.914825
# 4      106    합정역 7번출구 앞  마포구    서울특별시 마포구 독막로 4  37.548645  126.912826
# ...    ...           ...  ...                ...        ...         ...
# 2462  4864         송파사거리  송파구       송파구 송파동 97-2  37.502056  127.110550
# 2463  4865  한성백제역 1번출구 뒤  송파구       송파구 방이동 45-4  37.516342  127.115593
# 2464  4867     가락대림아파트 앞  송파구       송파구 가락동 94-9  37.500027  127.118431
# 2465  4868      레이크 호텔 앞  송파구        송파구 석촌동 158  37.507172  127.101242
# 2466  4869        잠실나들목6  송파구             잠실동 24  37.516296  127.084610
#
#            설치 시기  LCD 거치대수  QR 거치대수 운영 방식
# 0     2015-09-06      20.0      NaN   LCD
# ...

# %%
df = pd.merge(df, station[['자치구', '대여소번호']], on = '대여소번호')
df.head()
# Out:
#             대여소명  대여소번호     년  월  일  시간  return_count  rent_count    c  자치구
# 0  (구)신한은행 중랑교지점   1442  2020  6  1   0           1.0         1.0  8.0  중랑구
# 1  (구)신한은행 중랑교지점   1442  2020  6  1   1           1.0         0.0  8.0  중랑구
# 2  (구)신한은행 중랑교지점   1442  2020  6  1   2           3.0         1.0  8.0  중랑구
# 3  (구)신한은행 중랑교지점   1442  2020  6  1   3           0.0         0.0  8.0  중랑구
# 4  (구)신한은행 중랑교지점   1442  2020  6  1   4           1.0         0.0  8.0  중랑구

# %%
df = df[['자치구', '대여소명', '대여소번호', '년', '월', '일', '시간','c',  'return_count', 'rent_count']]
df.head()
# Out:
#    자치구           대여소명  대여소번호     년  월  일  시간    c  return_count  rent_count
# 0  중랑구  (구)신한은행 중랑교지점   1442  2020  6  1   0  8.0           1.0         1.0
# 1  중랑구  (구)신한은행 중랑교지점   1442  2020  6  1   1  8.0           1.0         0.0
# 2  중랑구  (구)신한은행 중랑교지점   1442  2020  6  1   2  8.0           3.0         1.0
# 3  중랑구  (구)신한은행 중랑교지점   1442  2020  6  1   3  8.0           0.0         0.0
# 4  중랑구  (구)신한은행 중랑교지점   1442  2020  6  1   4  8.0           1.0         0.0

# %%
df.to_csv('./1년 1시간별 대여량, 반납량.csv', index = False, encoding = 'cp949')
