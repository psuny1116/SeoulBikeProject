# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('./1년 365일 1시간별 Ls, Ws.csv', encoding = 'cp949')
df
# Out:
#         자치구               대여소명  대여소번호     년  월   일  시간  lambda    mu     c  \
# 0       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   0     0.0   1.0  30.0
# 1       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   1     0.0   0.0  30.0
# 2       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   2     0.0   0.0  30.0
# 3       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   3     0.0   0.0  30.0
# 4       송파구  롯데월드타워(잠실역2번출구 쪽)   1210  2020  6   1   4     1.0   0.0  30.0
# ...     ...                ...    ...   ... ..  ..  ..     ...   ...   ...
# 262795  송파구        한성백제역 2번 출구   2621  2021  5  31  19    14.0  16.0  19.0
# 262796  송파구        한성백제역 2번 출구   2621  2021  5  31  20    24.0  17.0  19.0
# 262797  송파구        한성백제역 2번 출구   2621  2021  5  31  21    20.0  19.0  19.0
# 262798  송파구        한성백제역 2번 출구   2621  2021  5  31  22    14.0  18.0  19.0
# 262799  송파구        한성백제역 2번 출구   2621  2021  5  31  23     5.0   1.0  19.0
#
#              rho           p_0      p_1+        L_s
# 0       0.000000  1.000000e+00  0.000000   0.000000
# 1       0.000000  1.000000e+00  0.000000   0.000000
# 2       0.000000  1.000000e+00  0.000000   0.000000
# 3       0.000000  1.000000e+00  0.000000   0.000000
# 4       0.000000  1.000000e+00  0.000000   0.000000
# ...          ...           ...       ...        ...
# 262795  0.875000  1.342943e-01  0.865706   5.512905
# 262796  1.411765  4.167178e-04  0.999583  16.591669
# 262797  1.052632  2.941117e-02  0.970589  11.176245
# 262798  0.777778  2.236903e-01  0.776310   3.367870
# 262799  5.000000  4.194304e-14  1.000000  18.750000
#
# [262800 rows x 14 columns]

# %%
df = df[df['대여소명'] == '잠실역 6번출구']
df
# Out:
#         자치구      대여소명  대여소번호     년  월   일  시간  lambda    mu     c       rho  \
# 227760  송파구  잠실역 6번출구   1231  2020  6   1   0     0.0   0.0  11.0  0.000000
# 227761  송파구  잠실역 6번출구   1231  2020  6   1   1     3.0   3.0  11.0  1.000000
# 227762  송파구  잠실역 6번출구   1231  2020  6   1   2     0.0   3.0  11.0  0.000000
# 227763  송파구  잠실역 6번출구   1231  2020  6   1   3     0.0   0.0  11.0  0.000000
# 227764  송파구  잠실역 6번출구   1231  2020  6   1   4     0.0   0.0  11.0  0.000000
# ...     ...       ...    ...   ... ..  ..  ..     ...   ...   ...       ...
# 236515  송파구  잠실역 6번출구   1231  2021  5  31  19     8.0  12.0  11.0  0.666667
# 236516  송파구  잠실역 6번출구   1231  2021  5  31  20     3.0   7.0  11.0  0.428571
# 236517  송파구  잠실역 6번출구   1231  2021  5  31  21     6.0   5.0  11.0  1.200000
# 236518  송파구  잠실역 6번출구   1231  2021  5  31  22    16.0  12.0  11.0  1.333333
# 236519  송파구  잠실역 6번출구   1231  2021  5  31  23     2.0   5.0  11.0  0.400000
#
#              p_0      p_1+       L_s
# 227760  1.000000  0.000000  0.000000
# 227761  0.083333  0.916667  5.500000
# 227762  1.000000  0.000000  0.000000
# 227763  1.000000  0.000000  0.000000
# 227764  1.000000  0.000000  0.000000
# ...          ...       ...       ...
# 236515  0.335922  0.664078  1.906793
# 236516  0.571451  0.428549  0.749539
# 236517  0.025265  0.974735  7.515898
# 236518  0.010904  0.989096  8.392551
# 236519  0.600010  0.399990  0.666465
#
# [8760 rows x 14 columns]

# %%
df = df.drop(['대여소번호', 'c', 'rho', 'p_0'], axis = 1)
df
# Out:
#         자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s
# 227760  송파구  잠실역 6번출구  2020  6   1   0     0.0   0.0  0.000000  0.000000
# 227761  송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000
# 227762  송파구  잠실역 6번출구  2020  6   1   2     0.0   3.0  0.000000  0.000000
# 227763  송파구  잠실역 6번출구  2020  6   1   3     0.0   0.0  0.000000  0.000000
# 227764  송파구  잠실역 6번출구  2020  6   1   4     0.0   0.0  0.000000  0.000000
# ...     ...       ...   ... ..  ..  ..     ...   ...       ...       ...
# 236515  송파구  잠실역 6번출구  2021  5  31  19     8.0  12.0  0.664078  1.906793
# 236516  송파구  잠실역 6번출구  2021  5  31  20     3.0   7.0  0.428549  0.749539
# 236517  송파구  잠실역 6번출구  2021  5  31  21     6.0   5.0  0.974735  7.515898
# 236518  송파구  잠실역 6번출구  2021  5  31  22    16.0  12.0  0.989096  8.392551
# 236519  송파구  잠실역 6번출구  2021  5  31  23     2.0   5.0  0.399990  0.666465
#
# [8760 rows x 10 columns]

# %%
data = pd.read_csv('./잠실역 6번출구 365일 균형, 불균형.csv', encoding = 'cp949')
data
# Out:
#       자치구      대여소명     년  월   일  시간  재고량  3사분위수  2사분위수  1사분위수   균형
# 0     송파구  잠실역 6번출구  2020  6   1   0  0.0    9.0    5.0    2.0  불균형
# 1     송파구  잠실역 6번출구  2020  6   1   1  0.0    9.0    5.0    2.0  불균형
# 2     송파구  잠실역 6번출구  2020  6   1   2  0.0    9.0    5.0    2.0  불균형
# 3     송파구  잠실역 6번출구  2020  6   1   3  0.0    9.0    5.0    2.0  불균형
# 4     송파구  잠실역 6번출구  2020  6   1   4  0.0    9.0    5.0    2.0  불균형
# ...   ...       ...   ... ..  ..  ..  ...    ...    ...    ...  ...
# 8755  송파구  잠실역 6번출구  2021  5  31  19  7.0    9.0    5.0    2.0   균형
# 8756  송파구  잠실역 6번출구  2021  5  31  20  3.0    9.0    5.0    2.0   균형
# 8757  송파구  잠실역 6번출구  2021  5  31  21  4.0    9.0    5.0    2.0   균형
# 8758  송파구  잠실역 6번출구  2021  5  31  22  8.0    9.0    5.0    2.0   균형
# 8759  송파구  잠실역 6번출구  2021  5  31  23  5.0    9.0    5.0    2.0   균형
#
# [8760 rows x 11 columns]

# %%
df_new = pd.merge(df,data, on = ['자치구', '대여소명','년', '월', '일', '시간'],how='outer')
df_new
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s  재고량  \
# 0     송파구  잠실역 6번출구  2020  6   1   0     0.0   0.0  0.000000  0.000000  0.0
# 1     송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000  0.0
# 2     송파구  잠실역 6번출구  2020  6   1   2     0.0   3.0  0.000000  0.000000  0.0
# 3     송파구  잠실역 6번출구  2020  6   1   3     0.0   0.0  0.000000  0.000000  0.0
# 4     송파구  잠실역 6번출구  2020  6   1   4     0.0   0.0  0.000000  0.000000  0.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...  ...
# 8755  송파구  잠실역 6번출구  2021  5  31  19     8.0  12.0  0.664078  1.906793  7.0
# 8756  송파구  잠실역 6번출구  2021  5  31  20     3.0   7.0  0.428549  0.749539  3.0
# 8757  송파구  잠실역 6번출구  2021  5  31  21     6.0   5.0  0.974735  7.515898  4.0
# 8758  송파구  잠실역 6번출구  2021  5  31  22    16.0  12.0  0.989096  8.392551  8.0
# 8759  송파구  잠실역 6번출구  2021  5  31  23     2.0   5.0  0.399990  0.666465  5.0
#
#       3사분위수  2사분위수  1사분위수   균형
# 0       9.0    5.0    2.0  불균형
# 1       9.0    5.0    2.0  불균형
# 2       9.0    5.0    2.0  불균형
# 3       9.0    5.0    2.0  불균형
# 4       9.0    5.0    2.0  불균형
# ...     ...    ...    ...  ...
# 8755    9.0    5.0    2.0   균형
# 8756    9.0    5.0    2.0   균형
# 8757    9.0    5.0    2.0   균형
# 8758    9.0    5.0    2.0   균형
# 8759    9.0    5.0    2.0   균형
#
# [8760 rows x 15 columns]

# %%
df_new['내 균형'] = '균형'
df_new
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s  재고량  \
# 0     송파구  잠실역 6번출구  2020  6   1   0     0.0   0.0  0.000000  0.000000  0.0
# 1     송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000  0.0
# 2     송파구  잠실역 6번출구  2020  6   1   2     0.0   3.0  0.000000  0.000000  0.0
# 3     송파구  잠실역 6번출구  2020  6   1   3     0.0   0.0  0.000000  0.000000  0.0
# 4     송파구  잠실역 6번출구  2020  6   1   4     0.0   0.0  0.000000  0.000000  0.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...  ...
# 8755  송파구  잠실역 6번출구  2021  5  31  19     8.0  12.0  0.664078  1.906793  7.0
# 8756  송파구  잠실역 6번출구  2021  5  31  20     3.0   7.0  0.428549  0.749539  3.0
# 8757  송파구  잠실역 6번출구  2021  5  31  21     6.0   5.0  0.974735  7.515898  4.0
# 8758  송파구  잠실역 6번출구  2021  5  31  22    16.0  12.0  0.989096  8.392551  8.0
# 8759  송파구  잠실역 6번출구  2021  5  31  23     2.0   5.0  0.399990  0.666465  5.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 0       9.0    5.0    2.0  불균형   균형
# 1       9.0    5.0    2.0  불균형   균형
# 2       9.0    5.0    2.0  불균형   균형
# 3       9.0    5.0    2.0  불균형   균형
# 4       9.0    5.0    2.0  불균형   균형
# ...     ...    ...    ...  ...  ...
# 8755    9.0    5.0    2.0   균형   균형
# 8756    9.0    5.0    2.0   균형   균형
# 8757    9.0    5.0    2.0   균형   균형
# 8758    9.0    5.0    2.0   균형   균형
# 8759    9.0    5.0    2.0   균형   균형
#
# [8760 rows x 16 columns]

# %% [markdown]
# # 일단 L_s, 기존균형 비교

# %% [markdown]
# ## L_s가 Q1보다 작거나, Q3보다 크면 불균형

# %% [markdown]
# ### L_s가 q1보다 작지만 이때 p_1+이 충분히 크다면 균형
# - ls가 q1보다 작고 p_1+가 0.5보다 작으면 불균형

# %%
# ls가 q1보다 작으므로 불균형

e = df_new[(df_new['L_s'] < df_new['1사분위수']) & (df_new['p_1+'] < 0.6)]
e
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s   재고량  \
# 0     송파구  잠실역 6번출구  2020  6   1   0     0.0   0.0  0.000000  0.000000   0.0
# 2     송파구  잠실역 6번출구  2020  6   1   2     0.0   3.0  0.000000  0.000000   0.0
# 3     송파구  잠실역 6번출구  2020  6   1   3     0.0   0.0  0.000000  0.000000   0.0
# 4     송파구  잠실역 6번출구  2020  6   1   4     0.0   0.0  0.000000  0.000000   0.0
# 5     송파구  잠실역 6번출구  2020  6   1   5     1.0   0.0  0.000000  0.000000   1.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...   ...
# 8745  송파구  잠실역 6번출구  2021  5  31   9     2.0   0.0  0.000000  0.000000  31.0
# 8746  송파구  잠실역 6번출구  2021  5  31  10     3.0   0.0  0.000000  0.000000  34.0
# 8754  송파구  잠실역 6번출구  2021  5  31  18     9.0  32.0  0.281250  0.391301  11.0
# 8756  송파구  잠실역 6번출구  2021  5  31  20     3.0   7.0  0.428549  0.749539   3.0
# 8759  송파구  잠실역 6번출구  2021  5  31  23     2.0   5.0  0.399990  0.666465   5.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 0       9.0    5.0    2.0  불균형   균형
# 2       9.0    5.0    2.0  불균형   균형
# 3       9.0    5.0    2.0  불균형   균형
# 4       9.0    5.0    2.0  불균형   균형
# 5       9.0    5.0    2.0  불균형   균형
# ...     ...    ...    ...  ...  ...
# 8745    9.0    5.0    2.0  불균형   균형
# 8746    9.0    5.0    2.0  불균형   균형
# 8754    9.0    5.0    2.0  불균형   균형
# 8756    9.0    5.0    2.0   균형   균형
# 8759    9.0    5.0    2.0   균형   균형
#
# [4548 rows x 16 columns]

# %%
for i in range(len(df_new)):
    if (df_new['L_s'][i] < df_new['1사분위수'][i]) & (df_new['p_1+'][i] < 0.6):
        df_new['내 균형'][i] = '불균형'

# %%
# ls가 q3보다 크므로 불균형

r = df_new[(df_new['L_s'] > df_new['3사분위수']) & (df_new['L_s'] > (10*0.7))]
r
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+        L_s   재고량  \
# 11    송파구  잠실역 6번출구  2020  6   1  11     3.0   2.0  0.996116   9.093207   4.0
# 17    송파구  잠실역 6번출구  2020  6   1  17     6.0   2.0  0.999996  10.500023   1.0
# 24    송파구  잠실역 6번출구  2020  6   2   0     3.0   2.0  0.996116   9.093207   0.0
# 34    송파구  잠실역 6번출구  2020  6   2  10     2.0   1.0  0.999756  10.002930   1.0
# 38    송파구  잠실역 6번출구  2020  6   2  14     3.0   2.0  0.996116   9.093207   2.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...        ...   ...
# 8728  송파구  잠실역 6번출구  2021  5  30  16    15.0  10.0  0.996116   9.093207  13.0
# 8730  송파구  잠실역 6번출구  2021  5  30  18    23.0   9.0  0.999980  10.357298  28.0
# 8731  송파구  잠실역 6번출구  2021  5  30  19     3.0   2.0  0.996116   9.093207  29.0
# 8743  송파구  잠실역 6번출구  2021  5  31   7     5.0   1.0  1.000000  10.750000  33.0
# 8747  송파구  잠실역 6번출구  2021  5  31  11     3.0   1.0  0.999996  10.500023  36.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 11      9.0    5.0    2.0   균형   균형
# 17      9.0    5.0    2.0  불균형   균형
# 24      9.0    5.0    2.0  불균형   균형
# 34      9.0    5.0    2.0  불균형   균형
# 38      9.0    5.0    2.0   균형   균형
# ...     ...    ...    ...  ...  ...
# 8728    9.0    5.0    2.0  불균형   균형
# 8730    9.0    5.0    2.0  불균형   균형
# 8731    9.0    5.0    2.0  불균형   균형
# 8743    9.0    5.0    2.0  불균형   균형
# 8747    9.0    5.0    2.0  불균형   균형
#
# [1463 rows x 16 columns]

# %%
for i in range(len(df_new)):
    if (df_new['L_s'][i] > df_new['3사분위수'][i]) & (df_new['L_s'][i] > (10*0.7)):
        df_new['내 균형'][i] = '불균형'

# %% [markdown]
# # L_s가 Q1~Q3사이이더라도 이때 p_1+가 너무 작으면(50%이하) 불균형
# - 따릉이 목표 거치율이 60~70%이므로 한대라도 있을 확률인 p_1+도 유사하게 잡기 위해

# %%
t = df_new[(df_new['3사분위수']>=df_new['L_s']) & (df_new['L_s'] >= df_new['1사분위수'])]
t
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s   재고량  \
# 1     송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000   0.0
# 6     송파구  잠실역 6번출구  2020  6   1   6     2.0   2.0  0.916667  5.500000   1.0
# 8     송파구  잠실역 6번출구  2020  6   1   8     8.0  10.0  0.785242  3.114516   3.0
# 9     송파구  잠실역 6번출구  2020  6   1   9     3.0   3.0  0.916667  5.500000   3.0
# 13    송파구  잠실역 6번출구  2020  6   1  13     4.0   4.0  0.916667  5.500000   3.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...   ...
# 8751  송파구  잠실역 6번출구  2021  5  31  15     4.0   5.0  0.785242  3.114516  35.0
# 8752  송파구  잠실역 6번출구  2021  5  31  16     5.0   6.0  0.812279  3.484102  34.0
# 8753  송파구  잠실역 6번출구  2021  5  31  17     7.0   7.0  0.916667  5.500000  34.0
# 8757  송파구  잠실역 6번출구  2021  5  31  21     6.0   5.0  0.974735  7.515898   4.0
# 8758  송파구  잠실역 6번출구  2021  5  31  22    16.0  12.0  0.989096  8.392551   8.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 1       9.0    5.0    2.0  불균형   균형
# 6       9.0    5.0    2.0  불균형   균형
# 8       9.0    5.0    2.0   균형   균형
# 9       9.0    5.0    2.0   균형   균형
# 13      9.0    5.0    2.0   균형   균형
# ...     ...    ...    ...  ...  ...
# 8751    9.0    5.0    2.0  불균형   균형
# 8752    9.0    5.0    2.0  불균형   균형
# 8753    9.0    5.0    2.0  불균형   균형
# 8757    9.0    5.0    2.0   균형   균형
# 8758    9.0    5.0    2.0   균형   균형
#
# [2478 rows x 16 columns]

# %%
t[t['p_1+']< 0.6]
# Out:
# Empty DataFrame
# Columns: [자치구, 대여소명, 년, 월, 일, 시간, lambda, mu, p_1+, L_s, 재고량, 3사분위수, 2사분위수, 1사분위수, 균형, 내 균형]
# Index: []

# %% [markdown]
# - 위 결과를 보면 l_s가 q1~q3사이에 있지만 자전거가 한대라도 있을 확률이 0.5이하이므로 불균형이다
# - 특히 19시, 20시의 경우 퇴근시간이므로 이시간에 불균형이면 이용에 불편을 초래함
# - 또한 21년 1월 19시의 경우 불균형인데도 불구하고 기존연구방법에서는 이를 균형으로 판단

# %%
for i in range(len(df_new)):
    if (df_new['3사분위수'][i]>=df_new['L_s'][i]) & (df_new['L_s'][i] >= df_new['1사분위수'][i]) & (df_new['p_1+'][i] < 0.6):
        df_new['내 균형'][i] = '불균형'

# %%
df_new
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s  재고량  \
# 0     송파구  잠실역 6번출구  2020  6   1   0     0.0   0.0  0.000000  0.000000  0.0
# 1     송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000  0.0
# 2     송파구  잠실역 6번출구  2020  6   1   2     0.0   3.0  0.000000  0.000000  0.0
# 3     송파구  잠실역 6번출구  2020  6   1   3     0.0   0.0  0.000000  0.000000  0.0
# 4     송파구  잠실역 6번출구  2020  6   1   4     0.0   0.0  0.000000  0.000000  0.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...  ...
# 8755  송파구  잠실역 6번출구  2021  5  31  19     8.0  12.0  0.664078  1.906793  7.0
# 8756  송파구  잠실역 6번출구  2021  5  31  20     3.0   7.0  0.428549  0.749539  3.0
# 8757  송파구  잠실역 6번출구  2021  5  31  21     6.0   5.0  0.974735  7.515898  4.0
# 8758  송파구  잠실역 6번출구  2021  5  31  22    16.0  12.0  0.989096  8.392551  8.0
# 8759  송파구  잠실역 6번출구  2021  5  31  23     2.0   5.0  0.399990  0.666465  5.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 0       9.0    5.0    2.0  불균형  불균형
# 1       9.0    5.0    2.0  불균형   균형
# 2       9.0    5.0    2.0  불균형  불균형
# 3       9.0    5.0    2.0  불균형  불균형
# 4       9.0    5.0    2.0  불균형  불균형
# ...     ...    ...    ...  ...  ...
# 8755    9.0    5.0    2.0   균형   균형
# 8756    9.0    5.0    2.0   균형  불균형
# 8757    9.0    5.0    2.0   균형   균형
# 8758    9.0    5.0    2.0   균형   균형
# 8759    9.0    5.0    2.0   균형  불균형
#
# [8760 rows x 16 columns]

# %%
len(df_new[df_new['균형'] == '불균형'])
# Out:
# 3686

# %%
len(df_new[df_new['내 균형'] == '불균형'])
# Out:
# 6011

# %%
len(df_new)
# Out:
# 8760

# %%
# TN

len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '불균형')])
# Out:
# 2572

# %%
# TP

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')])
# Out:
# 1635

# %%
# FN

len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '균형')])
# Out:
# 1114

# %%
# FP

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '불균형')])
# Out:
# 3439

# %%
# 정확도(기존방법과 내 방법의 일치율)

(len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) + len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '불균형')])) / len(df_new)
# Out:
# 0.4802511415525114

# %%
# 정밀도(기존 방법에서 균형으로 판단한 데이터 중 내가 균형이라고 판단한 비율)

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) / (len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) + len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '불균형')]))
# Out:
# 0.3222309814741821

# %%
# 재현율(내 방법에서 균형으로 판단한 것 중 기존 방법에서도 균형으로 판단한 비율)

len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) / (len(df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '균형')]) + len(df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '균형')]))
# Out:
# 0.5947617315387413

# %%
a = df_new[(df_new['균형'] == '불균형') & (df_new['내 균형'] == '균형')]
a
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s   재고량  \
# 1     송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000   0.0
# 6     송파구  잠실역 6번출구  2020  6   1   6     2.0   2.0  0.916667  5.500000   1.0
# 15    송파구  잠실역 6번출구  2020  6   1  15     9.0  13.0  0.688532  2.102746   0.0
# 16    송파구  잠실역 6번출구  2020  6   1  16     6.0   9.0  0.664078  1.906793  -3.0
# 18    송파구  잠실역 6번출구  2020  6   1  18    11.0  15.0  0.726723  2.452537  -3.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...   ...
# 8749  송파구  잠실역 6번출구  2021  5  31  13     3.0   4.0  0.741822  2.607449  35.0
# 8750  송파구  잠실역 6번출구  2021  5  31  14     4.0   3.0  0.989096  8.392551  36.0
# 8751  송파구  잠실역 6번출구  2021  5  31  15     4.0   5.0  0.785242  3.114516  35.0
# 8752  송파구  잠실역 6번출구  2021  5  31  16     5.0   6.0  0.812279  3.484102  34.0
# 8753  송파구  잠실역 6번출구  2021  5  31  17     7.0   7.0  0.916667  5.500000  34.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 1       9.0    5.0    2.0  불균형   균형
# 6       9.0    5.0    2.0  불균형   균형
# 15      9.0    5.0    2.0  불균형   균형
# 16      9.0    5.0    2.0  불균형   균형
# 18      9.0    5.0    2.0  불균형   균형
# ...     ...    ...    ...  ...  ...
# 8749    9.0    5.0    2.0  불균형   균형
# 8750    9.0    5.0    2.0  불균형   균형
# 8751    9.0    5.0    2.0  불균형   균형
# 8752    9.0    5.0    2.0  불균형   균형
# 8753    9.0    5.0    2.0  불균형   균형
#
# [1114 rows x 16 columns]

# %%
len(a)
# Out:
# 1114

# %%
len(a[a['p_1+'] > 0.9])
# Out:
# 759

# %%
len(a[a['p_1+'] > 0.8])
# Out:
# 866

# %%
len(a[a['p_1+'] > 0.7])
# Out:
# 990

# %%
len(a[a['p_1+'] > 0.6])
# Out:
# 1114

# %% [markdown]
# - 기존방법이 불균형으로 판단한 데이터 중 본 연구에서 균형으로 판단한 데이터는 76개이지만
# - 이 중 대여소에 적어도 자전거가 1대 있을 확률이 70%가 넘는 데이터가 70개로 무려 92%이상의 경우에 이용자가 대여소에 도착했을 때 자전거를 빌릴 수 있는 확률이 70%이상이었다.
# - 따라서 이러한 경우에는 자전거 재배치를 위한 대여소 내 재고의 균형/ 불균형을 판단할 경우에는 재배치를 할 필요가 없다고 판단하여 균형으로 판단할 수 있다.

# %%
b = df_new[(df_new['균형'] == '균형') & (df_new['내 균형'] == '불균형')]
b
# Out:
#       자치구      대여소명     년  월   일  시간  lambda   mu      p_1+       L_s  재고량  \
# 7     송파구  잠실역 6번출구  2020  6   1   7     2.0  0.0  0.000000  0.000000  3.0
# 10    송파구  잠실역 6번출구  2020  6   1  10     0.0  1.0  0.000000  0.000000  3.0
# 11    송파구  잠실역 6번출구  2020  6   1  11     3.0  2.0  0.996116  9.093207  4.0
# 38    송파구  잠실역 6번출구  2020  6   2  14     3.0  2.0  0.996116  9.093207  2.0
# 39    송파구  잠실역 6번출구  2020  6   2  15     0.0  1.0  0.000000  0.000000  2.0
# ...   ...       ...   ... ..  ..  ..     ...  ...       ...       ...  ...
# 8706  송파구  잠실역 6번출구  2021  5  29  18     1.0  7.0  0.142857  0.166667  5.0
# 8721  송파구  잠실역 6번출구  2021  5  30   9     5.0  3.0  0.998546  9.526178  2.0
# 8727  송파구  잠실역 6번출구  2021  5  30  15    12.0  7.0  0.998889  9.618658  8.0
# 8756  송파구  잠실역 6번출구  2021  5  31  20     3.0  7.0  0.428549  0.749539  3.0
# 8759  송파구  잠실역 6번출구  2021  5  31  23     2.0  5.0  0.399990  0.666465  5.0
#
#       3사분위수  2사분위수  1사분위수  균형 내 균형
# 7       9.0    5.0    2.0  균형  불균형
# 10      9.0    5.0    2.0  균형  불균형
# 11      9.0    5.0    2.0  균형  불균형
# 38      9.0    5.0    2.0  균형  불균형
# 39      9.0    5.0    2.0  균형  불균형
# ...     ...    ...    ...  ..  ...
# 8706    9.0    5.0    2.0  균형  불균형
# 8721    9.0    5.0    2.0  균형  불균형
# 8727    9.0    5.0    2.0  균형  불균형
# 8756    9.0    5.0    2.0  균형  불균형
# 8759    9.0    5.0    2.0  균형  불균형
#
# [3439 rows x 16 columns]

# %%
len(b)
# Out:
# 3439

# %%
len(b[(b['lambda'] > b['mu']) & (b['L_s'] > (10*0.7))])
# Out:
# 826

# %% [markdown]
# - 기존방법이 균형으로 판단한 데이터 중 본 연구에서 불균형으로 판단한 데이터는 68개이지만
# - 이 중 반납이 대여보다 많고 대여소 내 평균 자전거수(L_s)가 서울시 거치대율의 목표인 거치대수의 60~70%를 초과하는 경우가 63개로 90%이상의 경우에 불필요하게 자전거의 재고가 많다고 판단된다.
# - 따라서 이러한 경우에는 이용자들의 자전거 이용에는 문제가 없지만 주변 대여소의 재고가 부족하다면 자전거 재배치의 측면에서는 재배치를 할 필요가 있다고 판단하여 불균형으로 판단할 수 있다.

# %%
df_new
# Out:
#       자치구      대여소명     년  월   일  시간  lambda    mu      p_1+       L_s  재고량  \
# 0     송파구  잠실역 6번출구  2020  6   1   0     0.0   0.0  0.000000  0.000000  0.0
# 1     송파구  잠실역 6번출구  2020  6   1   1     3.0   3.0  0.916667  5.500000  0.0
# 2     송파구  잠실역 6번출구  2020  6   1   2     0.0   3.0  0.000000  0.000000  0.0
# 3     송파구  잠실역 6번출구  2020  6   1   3     0.0   0.0  0.000000  0.000000  0.0
# 4     송파구  잠실역 6번출구  2020  6   1   4     0.0   0.0  0.000000  0.000000  0.0
# ...   ...       ...   ... ..  ..  ..     ...   ...       ...       ...  ...
# 8755  송파구  잠실역 6번출구  2021  5  31  19     8.0  12.0  0.664078  1.906793  7.0
# 8756  송파구  잠실역 6번출구  2021  5  31  20     3.0   7.0  0.428549  0.749539  3.0
# 8757  송파구  잠실역 6번출구  2021  5  31  21     6.0   5.0  0.974735  7.515898  4.0
# 8758  송파구  잠실역 6번출구  2021  5  31  22    16.0  12.0  0.989096  8.392551  8.0
# 8759  송파구  잠실역 6번출구  2021  5  31  23     2.0   5.0  0.399990  0.666465  5.0
#
#       3사분위수  2사분위수  1사분위수   균형 내 균형
# 0       9.0    5.0    2.0  불균형  불균형
# 1       9.0    5.0    2.0  불균형   균형
# 2       9.0    5.0    2.0  불균형  불균형
# 3       9.0    5.0    2.0  불균형  불균형
# 4       9.0    5.0    2.0  불균형  불균형
# ...     ...    ...    ...  ...  ...
# 8755    9.0    5.0    2.0   균형   균형
# 8756    9.0    5.0    2.0   균형  불균형
# 8757    9.0    5.0    2.0   균형   균형
# 8758    9.0    5.0    2.0   균형   균형
# 8759    9.0    5.0    2.0   균형  불균형
#
# [8760 rows x 16 columns]

# %%
df_new.to_csv('./잠실역 6번출구 365일.csv', index = False, encoding = 'cp949')

# %% [markdown]
# # confusion matrix
#
# 0 |균형|불균형
# -|-|-
# 균형|TP|FP
# 불균형|FN|TN
#
#
# 1. 정확도 accuracy = 실제(내) 데이터와 예측(기존방법)데이터가 얼마나 같은지를 평가하는 지표 = TP + TN / TP+TN+FP+FN
# 2. 정밀도 precision = 균형으로 예측한 데이터 중 실제로 균형인 데이터 비율 = TP / TP+FP
# 3. 재현율 recall = 실제 균형 중 균형으로 예측한 비율 = TP / TP+FN
#
# => 정밀도에 초점. (불균형을 균형으로 예측하여 재배치하지 않으면 서비스에 차질)
