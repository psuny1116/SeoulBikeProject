# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
import os

dirs = os.getcwd() + './data/결과'
files = os.listdir(dirs)
files
# Out:
# ['CJ 드림시티.xlsx',
#  '고속터미널역 8-1번, 8-2번 출구 사이.xlsx',
#  '공릉역 1번 출구 앞.xlsx',
#  '독산보도육교 앞 자전거 보관소.xlsx',
#  '동묘앞역 1번출구 뒤.xlsx',
#  '뚝섬유원지역 1번출구 앞.xlsx',
#  '롯데월드타워(잠실역2번출구 쪽).xlsx',
#  '마곡나루역 2번 출구.xlsx',
#  '마포구민체육센터 앞.xlsx',
#  '목동역5번출구 교통정보센터 앞.xlsx',
#  '봉림교 교통섬.xlsx',
#  '신도림역 1번 출구 앞.xlsx',
#  '안암로터리 버스정류장 앞.xlsx',
#  '여의나루역 1번출구 앞.xlsx',
#  '옥수역 3번출구.xlsx',
#  '용산역 맞은편.xlsx',
#  '이디야 커피 수유역점 앞.xlsx',
#  '장한평역 1번출구 (국민은행앞).xlsx',
#  '중랑세무서.xlsx',
#  '창동역 2번출구.xlsx',
#  '천호역4번출구(현대백화점).xlsx',
#  '청계천 영도교.xlsx',
#  '현대고등학교 건너편.xlsx',
#  '홍은사거리.xlsx',
#  '흑석역 1번출구.xlsx']

# %%
df0 = pd.read_excel('./data/결과/CJ 드림시티.xlsx')
df0 = df0.rename(columns = {'s_min' : 'CJ 드림시티s_min', 's_max' : 'CJ 드림시티s_max'})
df0
# Out:
#    time CJ 드림시티s_min CJ 드림시티s_max
# 0    0시          값없음          값없음
# 1    1시          값없음          값없음
# 2    2시          값없음          값없음
# 3    3시          값없음          값없음
# 4    4시          값없음          값없음
# 5    5시          값없음          값없음
# 6    6시          값없음          값없음
# 7    7시          값없음          값없음
# 8    8시          값없음          값없음
# 9    9시            7          값없음
# 10  10시            1          값없음
# 11  11시            0           17
# 12  12시            0           20
# 13  13시            0           21
# 14  14시            0           21
# 15  15시            0           21
# 16  16시            0           21
# 17  17시            0           21
# 18  18시            0           21
# 19  19시            0           21
# 20  20시            0           21
# 21  21시            0           21
# 22  22시            0           21
# 23  23시            0           22

# %%
df1 = pd.read_excel('./data/결과/고속터미널역 8-1번, 8-2번 출구 사이.xlsx')
df1 = df1.rename(columns = {'s_min' : '고속터미널역 8-1번, 8-2번 출구 사이s_min', 's_max' : '고속터미널역 8-1번, 8-2번 출구 사이s_max'})
df1
# Out:
#    time 고속터미널역 8-1번, 8-2번 출구 사이s_min 고속터미널역 8-1번, 8-2번 출구 사이s_max
# 0    0시                          값없음                          값없음
# 1    1시                          값없음                          값없음
# 2    2시                          값없음                          값없음
# 3    3시                          값없음                          값없음
# 4    4시                          값없음                          값없음
# 5    5시                          값없음                          값없음
# 6    6시                          값없음                          값없음
# 7    7시                          값없음                          값없음
# 8    8시                          값없음                          값없음
# 9    9시                          값없음                          값없음
# 10  10시                          값없음                           24
# 11  11시                           14                           25
# 12  12시                            1                           26
# 13  13시                            0                           26
# 14  14시                            0                           26
# 15  15시                            0                           26
# 16  16시                            0                           26
# 17  17시                            0                           26
# 18  18시                            0                           26
# 19  19시                            0                           26
# 20  20시                            0                           26
# 21  21시                            0                           26
# 22  22시                            0                           26
# 23  23시                            0                           26

# %%
df2 = pd.read_excel('./data/결과/공릉역 1번 출구 앞.xlsx')
df2 = df2.rename(columns = {'s_min' : '공릉역 1번 출구 앞s_min', 's_max' : '공릉역 1번 출구 앞s_max'})
df2
# Out:
#    time 공릉역 1번 출구 앞s_min 공릉역 1번 출구 앞s_max
# 0    0시              값없음              값없음
# 1    1시              값없음              값없음
# 2    2시              값없음              값없음
# 3    3시              값없음              값없음
# 4    4시              값없음              값없음
# 5    5시              값없음              값없음
# 6    6시              값없음              값없음
# 7    7시              값없음              값없음
# 8    8시              값없음                8
# 9    9시                3               10
# 10  10시                2               11
# 11  11시                1               11
# 12  12시                0               12
# 13  13시                0               12
# 14  14시                0               12
# 15  15시                0               12
# 16  16시                0               12
# 17  17시                0               12
# 18  18시                0               12
# 19  19시                0               12
# 20  20시                0               12
# 21  21시                0               12
# 22  22시                0               12
# 23  23시                0               12

# %%
df3 = pd.read_excel('./data/결과/독산보도육교 앞 자전거 보관소.xlsx')
df3 = df3.rename(columns = {'s_min' : '독산보도육교 앞 자전거 보관소s_min', 's_max' : '독산보도육교 앞 자전거 보관소s_max'})
df3
# Out:
#    time 독산보도육교 앞 자전거 보관소s_min 독산보도육교 앞 자전거 보관소s_max
# 0    0시                   값없음                   값없음
# 1    1시                   값없음                   값없음
# 2    2시                   값없음                   값없음
# 3    3시                   값없음                   값없음
# 4    4시                   값없음                   값없음
# 5    5시                   값없음                   값없음
# 6    6시                   값없음                   값없음
# 7    7시                     2                   값없음
# 8    8시                     1                   값없음
# 9    9시                     1                    11
# 10  10시                     1                    14
# 11  11시                     1                    15
# 12  12시                     1                    15
# 13  13시                     1                    15
# 14  14시                     1                    15
# 15  15시                     1                    15
# 16  16시                     1                    15
# 17  17시                     1                    15
# 18  18시                     1                    15
# 19  19시                     1                    15
# 20  20시                     1                    15
# 21  21시                     1                    15
# 22  22시                     1                    15
# 23  23시                     1                    15

# %%
df4 = pd.read_excel('./data/결과/동묘앞역 1번출구 뒤.xlsx')
df4 = df4.rename(columns = {'s_min' : '동묘앞역 1번출구 뒤s_min', 's_max' : '동묘앞역 1번출구 뒤s_max'})
df4
# Out:
#    time 동묘앞역 1번출구 뒤s_min 동묘앞역 1번출구 뒤s_max
# 0    0시              값없음              값없음
# 1    1시              값없음              값없음
# 2    2시              값없음              값없음
# 3    3시              값없음              값없음
# 4    4시              값없음              값없음
# 5    5시              값없음              값없음
# 6    6시              값없음              값없음
# 7    7시              값없음              값없음
# 8    8시              값없음                6
# 9    9시                4               10
# 10  10시                3               10
# 11  11시                2               11
# 12  12시                1               11
# 13  13시                1               11
# 14  14시                1               11
# 15  15시                1               11
# 16  16시                1               11
# 17  17시                1               11
# 18  18시                1               11
# 19  19시                1               11
# 20  20시                0               11
# 21  21시                0               11
# 22  22시                0               11
# 23  23시                0               11

# %%
df5 = pd.read_excel('./data/결과/뚝섬유원지역 1번출구 앞.xlsx')
df5 = df5.rename(columns = {'s_min' : '뚝섬유원지역 1번출구 앞s_min', 's_max' : '뚝섬유원지역 1번출구 앞s_max'})
df5
# Out:
#    time 뚝섬유원지역 1번출구 앞s_min 뚝섬유원지역 1번출구 앞s_max
# 0    0시                값없음                값없음
# 1    1시                값없음                값없음
# 2    2시                값없음                값없음
# 3    3시                값없음                값없음
# 4    4시                값없음                값없음
# 5    5시                값없음                값없음
# 6    6시                값없음                값없음
# 7    7시                값없음                값없음
# 8    8시                값없음                값없음
# 9    9시                값없음                값없음
# 10  10시                값없음                값없음
# 11  11시                값없음                 77
# 12  12시                값없음                 86
# 13  13시                  2                 87
# 14  14시                  0                 88
# 15  15시                  0                 88
# 16  16시                  0                 88
# 17  17시                  0                 88
# 18  18시                  0                 88
# 19  19시                  0                 88
# 20  20시                  0                 88
# 21  21시                  0                 89
# 22  22시                  0                 89
# 23  23시                  0                 89

# %%
df6 = pd.read_excel('./data/결과/롯데월드타워(잠실역2번출구 쪽).xlsx')
df6 = df6.rename(columns = {'s_min' : '롯데월드타워(잠실역2번출구 쪽)s_min', 's_max' : '롯데월드타워(잠실역2번출구 쪽)s_max'})
df6
# Out:
#    time 롯데월드타워(잠실역2번출구 쪽)s_min 롯데월드타워(잠실역2번출구 쪽)s_max
# 0    0시                    값없음                    값없음
# 1    1시                    값없음                    값없음
# 2    2시                    값없음                    값없음
# 3    3시                    값없음                    값없음
# 4    4시                    값없음                    값없음
# 5    5시                    값없음                    값없음
# 6    6시                    값없음                     37
# 7    7시                      2                     37
# 8    8시                      0                     37
# 9    9시                      0                     37
# 10  10시                      0                     37
# 11  11시                      0                     37
# 12  12시                      0                     37
# 13  13시                      0                     37
# 14  14시                      0                     37
# 15  15시                      0                     37
# 16  16시                      0                     37
# 17  17시                      0                     37
# 18  18시                      0                     37
# 19  19시                      0                     37
# 20  20시                      0                     37
# 21  21시                      0                     37
# 22  22시                      0                     37
# 23  23시                      0                     37

# %%
df7 = pd.read_excel('./data/결과/마곡나루역 2번 출구.xlsx')
df7 = df7.rename(columns = {'s_min' : '마곡나루역 2번 출구s_min', 's_max' : '마곡나루역 2번 출구s_max'})
df7
# Out:
#    time 마곡나루역 2번 출구s_min 마곡나루역 2번 출구s_max
# 0    0시              값없음              값없음
# 1    1시              값없음              값없음
# 2    2시              값없음              값없음
# 3    3시              값없음              값없음
# 4    4시              값없음              값없음
# 5    5시              값없음              값없음
# 6    6시              값없음               19
# 7    7시              값없음               30
# 8    8시                0               31
# 9    9시                0               31
# 10  10시                0               31
# 11  11시                0               31
# 12  12시                0               31
# 13  13시                0               31
# 14  14시                0               31
# 15  15시                0               31
# 16  16시                0               31
# 17  17시                0               31
# 18  18시                0               31
# 19  19시                0               31
# 20  20시                0               31
# 21  21시                0               31
# 22  22시                0               31
# 23  23시                0               31

# %%
df8 = pd.read_excel('./data/결과/마포구민체육센터 앞.xlsx')
df8 = df8.rename(columns = {'s_min' : '마포구민체육센터 앞s_min', 's_max' : '마포구민체육센터 앞s_max'})
df8
# Out:
#    time 마포구민체육센터 앞s_min 마포구민체육센터 앞s_max
# 0    0시             값없음             값없음
# 1    1시             값없음             값없음
# 2    2시             값없음             값없음
# 3    3시             값없음             값없음
# 4    4시             값없음             값없음
# 5    5시             값없음             값없음
# 6    6시             값없음             값없음
# 7    7시             값없음             값없음
# 8    8시             값없음             값없음
# 9    9시             값없음             값없음
# 10  10시             값없음             값없음
# 11  11시             값없음             값없음
# 12  12시             값없음              59
# 13  13시               2              64
# 14  14시               0              65
# 15  15시               0              65
# 16  16시               0              65
# 17  17시               0              65
# 18  18시               0              65
# 19  19시               0              65
# 20  20시               0              65
# 21  21시               0              65
# 22  22시               0              65
# 23  23시               0              65

# %%
df9 = pd.read_excel('./data/결과/목동역5번출구 교통정보센터 앞.xlsx')
df9 = df9.rename(columns = {'s_min' : '목동역5번출구 교통정보센터 앞s_min', 's_max' : '목동역5번출구 교통정보센터 앞s_max'})
df9
# Out:
#    time 목동역5번출구 교통정보센터 앞s_min 목동역5번출구 교통정보센터 앞s_max
# 0    0시                   값없음                   값없음
# 1    1시                   값없음                   값없음
# 2    2시                   값없음                   값없음
# 3    3시                   값없음                   값없음
# 4    4시                   값없음                   값없음
# 5    5시                   값없음                   값없음
# 6    6시                   값없음                   값없음
# 7    7시                   값없음                    14
# 8    8시                     3                    15
# 9    9시                     1                    15
# 10  10시                     1                    15
# 11  11시                     1                    15
# 12  12시                     0                    15
# 13  13시                     0                    16
# 14  14시                     0                    16
# 15  15시                     0                    16
# 16  16시                     0                    16
# 17  17시                     0                    16
# 18  18시                     0                    16
# 19  19시                     0                    16
# 20  20시                     0                    16
# 21  21시                     0                    16
# 22  22시                     0                    16
# 23  23시                     0                    16

# %%
df10 = pd.read_excel('./data/결과/봉림교 교통섬.xlsx')
df10 = df10.rename(columns = {'s_min' : '봉림교 교통섬s_min', 's_max' : '봉림교 교통섬s_max'})
df10
# Out:
#    time 봉림교 교통섬s_min 봉림교 교통섬s_max
# 0    0시          값없음          값없음
# 1    1시          값없음          값없음
# 2    2시          값없음          값없음
# 3    3시          값없음          값없음
# 4    4시          값없음          값없음
# 5    5시          값없음          값없음
# 6    6시          값없음          값없음
# 7    7시          값없음          값없음
# 8    8시          값없음          값없음
# 9    9시          값없음          값없음
# 10  10시          값없음          값없음
# 11  11시          값없음          값없음
# 12  12시            4          값없음
# 13  13시            2           43
# 14  14시            1           44
# 15  15시            0           45
# 16  16시            0           45
# 17  17시            0           45
# 18  18시            0           45
# 19  19시            0           45
# 20  20시            0           45
# 21  21시            0           45
# 22  22시            0           45
# 23  23시            0           45

# %%
df11 = pd.read_excel('./data/결과/신도림역 1번 출구 앞.xlsx')
df11 = df11.rename(columns = {'s_min' : '신도림역 1번 출구 앞s_min', 's_max' : '신도림역 1번 출구 앞s_max'})
df11
# Out:
#    time 신도림역 1번 출구 앞s_min 신도림역 1번 출구 앞s_max
# 0    0시               값없음               값없음
# 1    1시               값없음               값없음
# 2    2시               값없음               값없음
# 3    3시               값없음               값없음
# 4    4시               값없음               값없음
# 5    5시               값없음               값없음
# 6    6시               값없음               값없음
# 7    7시               값없음                22
# 8    8시                 0                23
# 9    9시                 0                23
# 10  10시                 0                23
# 11  11시                 0                23
# 12  12시                 0                23
# 13  13시                 0                23
# 14  14시                 0                23
# 15  15시                 0                23
# 16  16시                 0                23
# 17  17시                 0                23
# 18  18시                 0                23
# 19  19시                 0                23
# 20  20시                 0                23
# 21  21시                 0                23
# 22  22시                 0                23
# 23  23시                 0                23

# %%
df12 = pd.read_excel('./data/결과/안암로터리 버스정류장 앞.xlsx')
df12 = df12.rename(columns = {'s_min' : '안암로터리 버스정류장 앞s_min', 's_max' : '안암로터리 버스정류장 앞s_max'})
df12
# Out:
#    time 안암로터리 버스정류장 앞s_min 안암로터리 버스정류장 앞s_max
# 0    0시                값없음                값없음
# 1    1시                값없음                값없음
# 2    2시                값없음                값없음
# 3    3시                값없음                값없음
# 4    4시                값없음                값없음
# 5    5시                값없음                값없음
# 6    6시                값없음                값없음
# 7    7시                값없음                값없음
# 8    8시                값없음                값없음
# 9    9시                값없음                 15
# 10  10시                값없음                 17
# 11  11시                  3                 17
# 12  12시                  0                 17
# 13  13시                  0                 17
# 14  14시                  0                 17
# 15  15시                  0                 17
# 16  16시                  0                 17
# 17  17시                  0                 17
# 18  18시                  0                 17
# 19  19시                  0                 17
# 20  20시                  0                 17
# 21  21시                  0                 17
# 22  22시                  0                 17
# 23  23시                  0                 17

# %%
df13 = pd.read_excel('./data/결과/여의나루역 1번출구 앞.xlsx')
df13 = df13.rename(columns = {'s_min' : '여의나루역 1번출구 앞s_min', 's_max' : '여의나루역 1번출구 앞s_max'})
df13
# Out:
#    time 여의나루역 1번출구 앞s_min 여의나루역 1번출구 앞s_max
# 0    0시               값없음               값없음
# 1    1시               값없음               값없음
# 2    2시               값없음               값없음
# 3    3시               값없음               값없음
# 4    4시               값없음               값없음
# 5    5시               값없음               값없음
# 6    6시               값없음               값없음
# 7    7시               값없음               값없음
# 8    8시               값없음               값없음
# 9    9시               값없음               값없음
# 10  10시               값없음               값없음
# 11  11시               값없음               값없음
# 12  12시               값없음               값없음
# 13  13시                 2                84
# 14  14시                 0                84
# 15  15시                 0                84
# 16  16시                 0                84
# 17  17시                 0                84
# 18  18시                 0                84
# 19  19시                 0                84
# 20  20시                 0                84
# 21  21시                 0                84
# 22  22시                 0                84
# 23  23시                 0                84

# %%
df14 = pd.read_excel('./data/결과/옥수역 3번출구.xlsx')
df14 = df14.rename(columns = {'s_min' : '옥수역 3번출구s_min', 's_max' : '옥수역 3번출구s_max'})
df14
# Out:
#    time 옥수역 3번출구s_min 옥수역 3번출구s_max
# 0    0시           값없음           값없음
# 1    1시           값없음           값없음
# 2    2시           값없음           값없음
# 3    3시           값없음           값없음
# 4    4시           값없음           값없음
# 5    5시           값없음           값없음
# 6    6시           값없음           값없음
# 7    7시           값없음           값없음
# 8    8시           값없음           값없음
# 9    9시             1            28
# 10  10시             0            31
# 11  11시             0            32
# 12  12시             0            33
# 13  13시             0            33
# 14  14시             0            33
# 15  15시             0            33
# 16  16시             0            33
# 17  17시             0            33
# 18  18시             0            33
# 19  19시             0            33
# 20  20시             0            33
# 21  21시             0            33
# 22  22시             0            33
# 23  23시             0            33

# %%
df15 = pd.read_excel('./data/결과/용산역 맞은편.xlsx')
df15 = df15.rename(columns = {'s_min' : '용산역 맞은편s_min', 's_max' : '용산역 맞은편s_max'})
df15
# Out:
#    time 용산역 맞은편s_min 용산역 맞은편s_max
# 0    0시          값없음          값없음
# 1    1시          값없음          값없음
# 2    2시          값없음          값없음
# 3    3시          값없음          값없음
# 4    4시          값없음          값없음
# 5    5시          값없음          값없음
# 6    6시          값없음          값없음
# 7    7시          값없음          값없음
# 8    8시          값없음           19
# 9    9시          값없음           20
# 10  10시           10           20
# 11  11시            2           20
# 12  12시            1           20
# 13  13시            1           20
# 14  14시            1           20
# 15  15시            1           20
# 16  16시            1           20
# 17  17시            1           20
# 18  18시            1           20
# 19  19시            1           20
# 20  20시            1           20
# 21  21시            1           20
# 22  22시            1           20
# 23  23시            1           20

# %%
df16 = pd.read_excel('./data/결과/이디야 커피 수유역점 앞.xlsx')
df16 = df16.rename(columns = {'s_min' : '이디야 커피 수유역점 앞s_min', 's_max' : '이디야 커피 수유역점 앞s_max'})
df16
# Out:
#    time 이디야 커피 수유역점 앞s_min 이디야 커피 수유역점 앞s_max
# 0    0시                값없음                값없음
# 1    1시                값없음                값없음
# 2    2시                값없음                값없음
# 3    3시                값없음                값없음
# 4    4시                값없음                값없음
# 5    5시                값없음                값없음
# 6    6시                값없음                값없음
# 7    7시                값없음                값없음
# 8    8시                값없음                  6
# 9    9시                값없음                  7
# 10  10시                값없음                  8
# 11  11시                  8                  8
# 12  12시                  3                  8
# 13  13시                  2                  8
# 14  14시                  2                  8
# 15  15시                  1                  8
# 16  16시                  1                  8
# 17  17시                  1                  8
# 18  18시                  1                  8
# 19  19시                  1                  8
# 20  20시                  1                  8
# 21  21시                  1                  8
# 22  22시                  1                  8
# 23  23시                  1                  8

# %%
df17 = pd.read_excel('./data/결과/장한평역 1번출구 (국민은행앞).xlsx')
df17 = df17.rename(columns = {'s_min' : '장한평역 1번출구 (국민은행앞)s_min', 's_max' : '장한평역 1번출구 (국민은행앞)s_max'})
df17
# Out:
#    time 장한평역 1번출구 (국민은행앞)s_min 장한평역 1번출구 (국민은행앞)s_max
# 0    0시                    값없음                    값없음
# 1    1시                    값없음                    값없음
# 2    2시                    값없음                    값없음
# 3    3시                    값없음                    값없음
# 4    4시                    값없음                    값없음
# 5    5시                    값없음                    값없음
# 6    6시                    값없음                    값없음
# 7    7시                      5                     12
# 8    8시                      0                     12
# 9    9시                      0                     12
# 10  10시                      0                     12
# 11  11시                      0                     12
# 12  12시                      0                     12
# 13  13시                      0                     12
# 14  14시                      0                     12
# 15  15시                      0                     12
# 16  16시                      0                     12
# 17  17시                      0                     12
# 18  18시                      0                     12
# 19  19시                      0                     12
# 20  20시                      0                     12
# 21  21시                      0                     12
# 22  22시                      0                     12
# 23  23시                      0                     12

# %%
df18 = pd.read_excel('./data/결과/중랑세무서.xlsx')
df18 = df18.rename(columns = {'s_min' : '중랑세무서s_min', 's_max' : '중랑세무서s_max'})
df18
# Out:
#    time 중랑세무서s_min 중랑세무서s_max
# 0    0시        값없음        값없음
# 1    1시        값없음        값없음
# 2    2시        값없음        값없음
# 3    3시        값없음        값없음
# 4    4시        값없음        값없음
# 5    5시        값없음        값없음
# 6    6시        값없음        값없음
# 7    7시        값없음        값없음
# 8    8시          9        값없음
# 9    9시          4        값없음
# 10  10시          3        값없음
# 11  11시          2          7
# 12  12시          2         12
# 13  13시          2         14
# 14  14시          2         14
# 15  15시          2         14
# 16  16시          2         14
# 17  17시          2         14
# 18  18시          1         14
# 19  19시          1         14
# 20  20시          1         14
# 21  21시          1         14
# 22  22시          1         14
# 23  23시          1         14

# %%
df19 = pd.read_excel('./data/결과/창동역 2번출구.xlsx')
df19 = df19.rename(columns = {'s_min' : '창동역 2번출구s_min', 's_max' : '창동역 2번출구s_max'})
df19
# Out:
#    time 창동역 2번출구s_min 창동역 2번출구s_max
# 0    0시           값없음           값없음
# 1    1시           값없음           값없음
# 2    2시           값없음           값없음
# 3    3시           값없음           값없음
# 4    4시           값없음           값없음
# 5    5시           값없음           값없음
# 6    6시           값없음           값없음
# 7    7시           값없음            11
# 8    8시             8            12
# 9    9시             2            12
# 10  10시             1            12
# 11  11시             1            12
# 12  12시             0            12
# 13  13시             0            12
# 14  14시             0            12
# 15  15시             0            12
# 16  16시             0            12
# 17  17시             0            12
# 18  18시             0            12
# 19  19시             0            12
# 20  20시             0            12
# 21  21시             0            12
# 22  22시             0            12
# 23  23시             0            12

# %%
df20 = pd.read_excel('./data/결과/천호역4번출구(현대백화점).xlsx')
df20 = df20.rename(columns = {'s_min' : '천호역4번출구(현대백화점)s_min', 's_max' : '천호역4번출구(현대백화점)s_max'})
df20
# Out:
#    time 천호역4번출구(현대백화점)s_min 천호역4번출구(현대백화점)s_max
# 0    0시                 값없음                 값없음
# 1    1시                 값없음                 값없음
# 2    2시                 값없음                 값없음
# 3    3시                 값없음                 값없음
# 4    4시                 값없음                 값없음
# 5    5시                 값없음                 값없음
# 6    6시                 값없음                 값없음
# 7    7시                 값없음                 값없음
# 8    8시                  14                  13
# 9    9시                   3                  14
# 10  10시                   1                  14
# 11  11시                   0                  14
# 12  12시                   0                  14
# 13  13시                   0                  14
# 14  14시                   0                  14
# 15  15시                   0                  14
# 16  16시                   0                  14
# 17  17시                   0                  14
# 18  18시                   0                  14
# 19  19시                   0                  14
# 20  20시                   0                  14
# 21  21시                   0                  15
# 22  22시                   0                  15
# 23  23시                   0                  15

# %%
df21 = pd.read_excel('./data/결과/청계천 영도교.xlsx')
df21 = df21.rename(columns = {'s_min' : '청계천 영도교s_min', 's_max' : '청계천 영도교s_max'})
df21
# Out:
#    time 청계천 영도교s_min 청계천 영도교s_max
# 0    0시          값없음          값없음
# 1    1시          값없음          값없음
# 2    2시          값없음          값없음
# 3    3시          값없음          값없음
# 4    4시          값없음          값없음
# 5    5시          값없음          값없음
# 6    6시          값없음          값없음
# 7    7시            3            1
# 8    8시            2            5
# 9    9시            2            6
# 10  10시            2            6
# 11  11시            2            7
# 12  12시            2            7
# 13  13시            2            7
# 14  14시            1            7
# 15  15시            1            7
# 16  16시            1            8
# 17  17시            1            8
# 18  18시            1            8
# 19  19시            1            8
# 20  20시            1            8
# 21  21시            1            8
# 22  22시            1            8
# 23  23시            1            8

# %%
df22 = pd.read_excel('./data/결과/현대고등학교 건너편.xlsx')
df22 = df22.rename(columns = {'s_min' : '현대고등학교 건너편s_min', 's_max' : '현대고등학교 건너편s_max'})
df22
# Out:
#    time 현대고등학교 건너편s_min 현대고등학교 건너편s_max
# 0    0시             값없음             값없음
# 1    1시             값없음             값없음
# 2    2시             값없음             값없음
# 3    3시             값없음             값없음
# 4    4시             값없음             값없음
# 5    5시             값없음             값없음
# 6    6시             값없음             값없음
# 7    7시             값없음             값없음
# 8    8시             값없음             값없음
# 9    9시             값없음             값없음
# 10  10시             값없음             값없음
# 11  11시             값없음             값없음
# 12  12시               2             값없음
# 13  13시               1              15
# 14  14시               1              15
# 15  15시               1              15
# 16  16시               1              16
# 17  17시               0              16
# 18  18시               0              16
# 19  19시               0              16
# 20  20시               0              16
# 21  21시               0              16
# 22  22시               0              16
# 23  23시               0              16

# %%
df23 = pd.read_excel('./data/결과/홍은사거리.xlsx')
df23 = df23.rename(columns = {'s_min' : '홍은사거리s_min', 's_max' : '홍은사거리s_max'})
df23
# Out:
#    time 홍은사거리s_min 홍은사거리s_max
# 0    0시        값없음        값없음
# 1    1시        값없음        값없음
# 2    2시        값없음        값없음
# 3    3시        값없음        값없음
# 4    4시        값없음        값없음
# 5    5시        값없음        값없음
# 6    6시        값없음        값없음
# 7    7시        값없음        값없음
# 8    8시          4        값없음
# 9    9시          2          9
# 10  10시          2         13
# 11  11시          1         14
# 12  12시          1         14
# 13  13시          1         14
# 14  14시          1         14
# 15  15시          1         14
# 16  16시          1         14
# 17  17시          1         14
# 18  18시          1         14
# 19  19시          1         14
# 20  20시          1         14
# 21  21시          1         14
# 22  22시          1         14
# 23  23시          1         14

# %%
df24 = pd.read_excel('./data/결과/흑석역 1번출구.xlsx')
df24 = df24.rename(columns = {'s_min' : '흑석역 1번출구s_min', 's_max' : '흑석역 1번출구s_max'})
df24
# Out:
#    time 흑석역 1번출구s_min 흑석역 1번출구s_max
# 0    0시           값없음           값없음
# 1    1시           값없음           값없음
# 2    2시           값없음           값없음
# 3    3시           값없음           값없음
# 4    4시           값없음           값없음
# 5    5시           값없음           값없음
# 6    6시           값없음           값없음
# 7    7시           값없음           값없음
# 8    8시            11           값없음
# 9    9시             2           값없음
# 10  10시             1           값없음
# 11  11시             1            16
# 12  12시             0            18
# 13  13시             0            19
# 14  14시             0            20
# 15  15시             0            20
# 16  16시             0            20
# 17  17시             0            20
# 18  18시             0            20
# 19  19시             0            20
# 20  20시             0            20
# 21  21시             0            20
# 22  22시             0            20
# 23  23시             0            20

# %%
df = pd.merge(df0, df1, on = 'time')
df = pd.merge(df, df2, on = 'time')
df = pd.merge(df, df3, on = 'time')
df = pd.merge(df, df4, on = 'time')
df = pd.merge(df, df5, on = 'time')
df = pd.merge(df, df6, on = 'time')
df = pd.merge(df, df7, on = 'time')
df = pd.merge(df, df8, on = 'time')
df = pd.merge(df, df9, on = 'time')
df = pd.merge(df, df10, on = 'time')
df = pd.merge(df, df11, on = 'time')
df = pd.merge(df, df12, on = 'time')
df = pd.merge(df, df13, on = 'time')
df = pd.merge(df, df14, on = 'time')
df = pd.merge(df, df15, on = 'time')
df = pd.merge(df, df16, on = 'time')
df = pd.merge(df, df17, on = 'time')
df = pd.merge(df, df18, on = 'time')
df = pd.merge(df, df19, on = 'time')
df = pd.merge(df, df20, on = 'time')
df = pd.merge(df, df21, on = 'time')
df = pd.merge(df, df22, on = 'time')
df = pd.merge(df, df23, on = 'time')
df = pd.merge(df, df24, on = 'time')
df
# Out:
#    time CJ 드림시티s_min CJ 드림시티s_max 고속터미널역 8-1번, 8-2번 출구 사이s_min  \
# 0    0시          값없음          값없음                          값없음
# 1    1시          값없음          값없음                          값없음
# 2    2시          값없음          값없음                          값없음
# 3    3시          값없음          값없음                          값없음
# 4    4시          값없음          값없음                          값없음
# 5    5시          값없음          값없음                          값없음
# 6    6시          값없음          값없음                          값없음
# 7    7시          값없음          값없음                          값없음
# 8    8시          값없음          값없음                          값없음
# 9    9시            7          값없음                          값없음
# 10  10시            1          값없음                          값없음
# 11  11시            0           17                           14
# 12  12시            0           20                            1
# 13  13시            0           21                            0
# 14  14시            0           21                            0
# 15  15시            0           21                            0
# 16  16시            0           21                            0
# 17  17시            0           21                            0
# 18  18시            0           21                            0
# 19  19시            0           21                            0
# 20  20시            0           21                            0
# 21  21시            0           21                            0
# 22  22시            0           21                            0
# 23  23시            0           22                            0
#
#    고속터미널역 8-1번, 8-2번 출구 사이s_max 공릉역 1번 출구 앞s_min 공릉역 1번 출구 앞s_max  \
# 0                           값없음              값없음              값없음
# 1                           값없음              값없음              값없음
# 2                           값없음              값없음              값없음
# 3                           값없음              값없음              값없음
# 4                           값없음              값없음              값없음
# 5                           값없음              값없음              값없음
# 6                           값없음              값없음              값없음
# 7                           값없음              값없음              값없음
# 8                           값없음              값없음                8
# 9                           값없음                3               10
# 10                           24                2               11
# 11                           25                1               11
# 12                           26                0               12
# 13                           26                0               12
# 14                           26                0               12
# 15                           26                0               12
# 16                           26                0               12
# 17                           26                0               12
# 18                           26                0               12
# 19                           26                0               12
# 20                           26                0               12
# 21                           26                0               12
# 22                           26                0               12
# 23                           26                0               12
#
#    독산보도육교 앞 자전거 보관소s_min 독산보도육교 앞 자전거 보관소s_max 동묘앞역 1번출구 뒤s_min  \
# 0                    값없음                   값없음              값없음
# 1                    값없음                   값없음              값없음
# 2                    값없음                   값없음              값없음
# 3                    값없음                   값없음              값없음
# 4                    값없음                   값없음              값없음
# 5                    값없음                   값없음              값없음
# 6                    값없음                   값없음              값없음
# 7                      2                   값없음              값없음
# 8                      1                   값없음              값없음
# 9                      1                    11                4
# 10                     1                    14                3
# 11                     1                    15                2
# 12                     1                    15                1
# 13                     1                    15                1
# 14                     1                    15                1
# 15                     1                    15                1
# 16                     1                    15                1
# 17                     1                    15                1
# 18                     1                    15                1
# 19                     1                    15                1
# 20                     1                    15                0
# 21                     1                    15                0
# 22                     1                    15                0
# 23                     1                    15                0
#
#    동묘앞역 1번출구 뒤s_max 뚝섬유원지역 1번출구 앞s_min 뚝섬유원지역 1번출구 앞s_max  \
# 0               값없음                값없음                값없음
# 1               값없음                값없음                값없음
# 2               값없음                값없음                값없음
# 3               값없음                값없음                값없음
# 4               값없음                값없음                값없음
# 5               값없음                값없음                값없음
# 6               값없음                값없음                값없음
# 7               값없음                값없음                값없음
# 8                 6                값없음                값없음
# 9                10                값없음                값없음
# 10               10                값없음                값없음
# 11               11                값없음                 77
# 12               11                값없음                 86
# 13               11                  2                 87
# 14               11                  0                 88
# 15               11                  0                 88
# 16               11                  0                 88
# 17               11                  0                 88
# 18               11                  0                 88
# 19               11                  0                 88
# 20               11                  0                 88
# 21               11                  0                 89
# 22               11                  0                 89
# 23               11                  0                 89
#
#    롯데월드타워(잠실역2번출구 쪽)s_min 롯데월드타워(잠실역2번출구 쪽)s_max 마곡나루역 2번 출구s_min  \
# 0                     값없음                    값없음              값없음
# 1                     값없음                    값없음              값없음
# 2                     값없음                    값없음              값없음
# 3                     값없음                    값없음              값없음
# 4                     값없음                    값없음              값없음
# 5                     값없음                    값없음              값없음
# 6                     값없음                     37              값없음
# 7                       2                     37              값없음
# 8                       0                     37                0
# 9                       0                     37                0
# 10                      0                     37                0
# 11                      0                     37                0
# 12                      0                     37                0
# 13                      0                     37                0
# 14                      0                     37                0
# 15                      0                     37                0
# 16                      0                     37                0
# 17                      0                     37                0
# 18                      0                     37                0
# 19                      0                     37                0
# 20                      0                     37                0
# 21                      0                     37                0
# 22                      0                     37                0
# 23                      0                     37                0
#
#    마곡나루역 2번 출구s_max 마포구민체육센터 앞s_min 마포구민체육센터 앞s_max 목동역5번출구 교통정보센터 앞s_min  \
# 0               값없음             값없음             값없음                   값없음
# 1               값없음             값없음             값없음                   값없음
# 2               값없음             값없음             값없음                   값없음
# 3               값없음             값없음             값없음                   값없음
# 4               값없음             값없음             값없음                   값없음
# 5               값없음             값없음             값없음                   값없음
# 6                19             값없음             값없음                   값없음
# 7                30             값없음             값없음                   값없음
# 8                31             값없음             값없음                     3
# 9                31             값없음             값없음                     1
# 10               31             값없음             값없음                     1
# 11               31             값없음             값없음                     1
# 12               31             값없음              59                     0
# 13               31               2              64                     0
# 14               31               0              65                     0
# 15               31               0              65                     0
# 16               31               0              65                     0
# 17               31               0              65                     0
# 18               31               0              65                     0
# 19               31               0              65                     0
# 20               31               0              65                     0
# 21               31               0              65                     0
# 22               31               0              65                     0
# 23               31               0              65                     0
#
#    목동역5번출구 교통정보센터 앞s_max 봉림교 교통섬s_min 봉림교 교통섬s_max 신도림역 1번 출구 앞s_min  \
# 0                    값없음          값없음          값없음               값없음
# 1                    값없음          값없음          값없음               값없음
# 2                    값없음          값없음          값없음               값없음
# 3                    값없음          값없음          값없음               값없음
# 4                    값없음          값없음          값없음               값없음
# 5                    값없음          값없음          값없음               값없음
# 6                    값없음          값없음          값없음               값없음
# 7                     14          값없음          값없음               값없음
# 8                     15          값없음          값없음                 0
# 9                     15          값없음          값없음                 0
# 10                    15          값없음          값없음                 0
# 11                    15          값없음          값없음                 0
# 12                    15            4          값없음                 0
# 13                    16            2           43                 0
# 14                    16            1           44                 0
# 15                    16            0           45                 0
# 16                    16            0           45                 0
# 17                    16            0           45                 0
# 18                    16            0           45                 0
# 19                    16            0           45                 0
# 20                    16            0           45                 0
# 21                    16            0           45                 0
# 22                    16            0           45                 0
# 23                    16            0           45                 0
#
#    신도림역 1번 출구 앞s_max 안암로터리 버스정류장 앞s_min 안암로터리 버스정류장 앞s_max 여의나루역 1번출구 앞s_min  \
# 0                값없음                값없음                값없음               값없음
# 1                값없음                값없음                값없음               값없음
# 2                값없음                값없음                값없음               값없음
# 3                값없음                값없음                값없음               값없음
# 4                값없음                값없음                값없음               값없음
# 5                값없음                값없음                값없음               값없음
# 6                값없음                값없음                값없음               값없음
# 7                 22                값없음                값없음               값없음
# 8                 23                값없음                값없음               값없음
# 9                 23                값없음                 15               값없음
# 10                23                값없음                 17               값없음
# 11                23                  3                 17               값없음
# 12                23                  0                 17               값없음
# 13                23                  0                 17                 2
# 14                23                  0                 17                 0
# 15                23                  0                 17                 0
# 16                23                  0                 17                 0
# 17                23                  0                 17                 0
# 18                23                  0                 17                 0
# 19                23                  0                 17                 0
# 20                23                  0                 17                 0
# 21                23                  0                 17                 0
# 22                23                  0                 17                 0
# 23                23                  0                 17                 0
#
#    여의나루역 1번출구 앞s_max 옥수역 3번출구s_min 옥수역 3번출구s_max 용산역 맞은편s_min 용산역 맞은편s_max  \
# 0                값없음           값없음           값없음          값없음          값없음
# 1                값없음           값없음           값없음          값없음          값없음
# 2                값없음           값없음           값없음          값없음          값없음
# 3                값없음           값없음           값없음          값없음          값없음
# 4                값없음           값없음           값없음          값없음          값없음
# 5                값없음           값없음           값없음          값없음          값없음
# 6                값없음           값없음           값없음          값없음          값없음
# 7                값없음           값없음           값없음          값없음          값없음
# 8                값없음           값없음           값없음          값없음           19
# 9                값없음             1            28          값없음           20
# 10               값없음             0            31           10           20
# 11               값없음             0            32            2           20
# 12               값없음             0            33            1           20
# 13                84             0            33            1           20
# 14                84             0            33            1           20
# 15                84             0            33            1           20
# 16                84             0            33            1           20
# 17                84             0            33            1           20
# 18                84             0            33            1           20
# 19                84             0            33            1           20
# 20                84             0            33            1           20
# 21                84             0            33            1           20
# 22                84             0            33            1           20
# 23                84             0            33            1           20
#
#    이디야 커피 수유역점 앞s_min 이디야 커피 수유역점 앞s_max 장한평역 1번출구 (국민은행앞)s_min  \
# 0                 값없음                값없음                    값없음
# 1                 값없음                값없음                    값없음
# 2                 값없음                값없음                    값없음
# 3                 값없음                값없음                    값없음
# 4                 값없음                값없음                    값없음
# 5                 값없음                값없음                    값없음
# 6                 값없음                값없음                    값없음
# 7                 값없음                값없음                      5
# 8                 값없음                  6                      0
# 9                 값없음                  7                      0
# 10                값없음                  8                      0
# 11                  8                  8                      0
# 12                  3                  8                      0
# 13                  2                  8                      0
# 14                  2                  8                      0
# 15                  1                  8                      0
# 16                  1                  8                      0
# 17                  1                  8                      0
# 18                  1                  8                      0
# 19                  1                  8                      0
# 20                  1                  8                      0
# 21                  1                  8                      0
# 22                  1                  8                      0
# 23                  1                  8                      0
#
#    장한평역 1번출구 (국민은행앞)s_max 중랑세무서s_min 중랑세무서s_max 창동역 2번출구s_min 창동역 2번출구s_max  \
# 0                     값없음        값없음        값없음           값없음           값없음
# 1                     값없음        값없음        값없음           값없음           값없음
# 2                     값없음        값없음        값없음           값없음           값없음
# 3                     값없음        값없음        값없음           값없음           값없음
# 4                     값없음        값없음        값없음           값없음           값없음
# 5                     값없음        값없음        값없음           값없음           값없음
# 6                     값없음        값없음        값없음           값없음           값없음
# 7                      12        값없음        값없음           값없음            11
# 8                      12          9        값없음             8            12
# 9                      12          4        값없음             2            12
# 10                     12          3        값없음             1            12
# 11                     12          2          7             1            12
# 12                     12          2         12             0            12
# 13                     12          2         14             0            12
# 14                     12          2         14             0            12
# 15                     12          2         14             0            12
# 16                     12          2         14             0            12
# 17                     12          2         14             0            12
# 18                     12          1         14             0            12
# 19                     12          1         14             0            12
# 20                     12          1         14             0            12
# 21                     12          1         14             0            12
# 22                     12          1         14             0            12
# 23                     12          1         14             0            12
#
#    천호역4번출구(현대백화점)s_min 천호역4번출구(현대백화점)s_max 청계천 영도교s_min 청계천 영도교s_max  \
# 0                  값없음                 값없음          값없음          값없음
# 1                  값없음                 값없음          값없음          값없음
# 2                  값없음                 값없음          값없음          값없음
# 3                  값없음                 값없음          값없음          값없음
# 4                  값없음                 값없음          값없음          값없음
# 5                  값없음                 값없음          값없음          값없음
# 6                  값없음                 값없음          값없음          값없음
# 7                  값없음                 값없음            3            1
# 8                   14                  13            2            5
# 9                    3                  14            2            6
# 10                   1                  14            2            6
# 11                   0                  14            2            7
# 12                   0                  14            2            7
# 13                   0                  14            2            7
# 14                   0                  14            1            7
# 15                   0                  14            1            7
# 16                   0                  14            1            8
# 17                   0                  14            1            8
# 18                   0                  14            1            8
# 19                   0                  14            1            8
# 20                   0                  14            1            8
# 21                   0                  15            1            8
# 22                   0                  15            1            8
# 23                   0                  15            1            8
#
#    현대고등학교 건너편s_min 현대고등학교 건너편s_max 홍은사거리s_min 홍은사거리s_max 흑석역 1번출구s_min  \
# 0              값없음             값없음        값없음        값없음           값없음
# 1              값없음             값없음        값없음        값없음           값없음
# 2              값없음             값없음        값없음        값없음           값없음
# 3              값없음             값없음        값없음        값없음           값없음
# 4              값없음             값없음        값없음        값없음           값없음
# 5              값없음             값없음        값없음        값없음           값없음
# 6              값없음             값없음        값없음        값없음           값없음
# 7              값없음             값없음        값없음        값없음           값없음
# 8              값없음             값없음          4        값없음            11
# 9              값없음             값없음          2          9             2
# 10             값없음             값없음          2         13             1
# 11             값없음             값없음          1         14             1
# 12               2             값없음          1         14             0
# 13               1              15          1         14             0
# 14               1              15          1         14             0
# 15               1              15          1         14             0
# 16               1              16          1         14             0
# 17               0              16          1         14             0
# 18               0              16          1         14             0
# 19               0              16          1         14             0
# 20               0              16          1         14             0
# 21               0              16          1         14             0
# 22               0              16          1         14             0
# 23               0              16          1         14             0
#
#    흑석역 1번출구s_max
# 0            값없음
# 1            값없음
# 2            값없음
# 3            값없음
# 4            값없음
# 5            값없음
# 6            값없음
# 7            값없음
# 8            값없음
# 9            값없음
# 10           값없음
# 11            16
# 12            18
# 13            19
# 14            20
# 15            20
# 16            20
# 17            20
# 18            20
# 19            20
# 20            20
# 21            20
# 22            20
# 23            20

# %%
df.T
# Out:
#                                0    1    2    3    4    5    6    7    8   \
# time                           0시   1시   2시   3시   4시   5시   6시   7시   8시
# CJ 드림시티s_min                  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# CJ 드림시티s_max                  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 고속터미널역 8-1번, 8-2번 출구 사이s_min  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 고속터미널역 8-1번, 8-2번 출구 사이s_max  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 공릉역 1번 출구 앞s_min              값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 공릉역 1번 출구 앞s_max              값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    8
# 독산보도육교 앞 자전거 보관소s_min         값없음  값없음  값없음  값없음  값없음  값없음  값없음    2    1
# 독산보도육교 앞 자전거 보관소s_max         값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 동묘앞역 1번출구 뒤s_min              값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 동묘앞역 1번출구 뒤s_max              값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    6
# 뚝섬유원지역 1번출구 앞s_min            값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 뚝섬유원지역 1번출구 앞s_max            값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 롯데월드타워(잠실역2번출구 쪽)s_min        값없음  값없음  값없음  값없음  값없음  값없음  값없음    2    0
# 롯데월드타워(잠실역2번출구 쪽)s_max        값없음  값없음  값없음  값없음  값없음  값없음   37   37   37
# 마곡나루역 2번 출구s_min              값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    0
# 마곡나루역 2번 출구s_max              값없음  값없음  값없음  값없음  값없음  값없음   19   30   31
# 마포구민체육센터 앞s_min               값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 마포구민체육센터 앞s_max               값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 목동역5번출구 교통정보센터 앞s_min         값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    3
# 목동역5번출구 교통정보센터 앞s_max         값없음  값없음  값없음  값없음  값없음  값없음  값없음   14   15
# 봉림교 교통섬s_min                  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 봉림교 교통섬s_max                  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 신도림역 1번 출구 앞s_min             값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    0
# 신도림역 1번 출구 앞s_max             값없음  값없음  값없음  값없음  값없음  값없음  값없음   22   23
# 안암로터리 버스정류장 앞s_min            값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 안암로터리 버스정류장 앞s_max            값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 여의나루역 1번출구 앞s_min             값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 여의나루역 1번출구 앞s_max             값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 옥수역 3번출구s_min                 값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 옥수역 3번출구s_max                 값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 용산역 맞은편s_min                  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 용산역 맞은편s_max                  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음   19
# 이디야 커피 수유역점 앞s_min            값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 이디야 커피 수유역점 앞s_max            값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    6
# 장한평역 1번출구 (국민은행앞)s_min        값없음  값없음  값없음  값없음  값없음  값없음  값없음    5    0
# 장한평역 1번출구 (국민은행앞)s_max        값없음  값없음  값없음  값없음  값없음  값없음  값없음   12   12
# 중랑세무서s_min                    값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    9
# 중랑세무서s_max                    값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 창동역 2번출구s_min                 값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    8
# 창동역 2번출구s_max                 값없음  값없음  값없음  값없음  값없음  값없음  값없음   11   12
# 천호역4번출구(현대백화점)s_min           값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음   14
# 천호역4번출구(현대백화점)s_max           값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음   13
# 청계천 영도교s_min                  값없음  값없음  값없음  값없음  값없음  값없음  값없음    3    2
# 청계천 영도교s_max                  값없음  값없음  값없음  값없음  값없음  값없음  값없음    1    5
# 현대고등학교 건너편s_min               값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 현대고등학교 건너편s_max               값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 홍은사거리s_min                    값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음    4
# 홍은사거리s_max                    값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
# 흑석역 1번출구s_min                 값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음   11
# 흑석역 1번출구s_max                 값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음  값없음
#
#                                9    10   11   12   13   14   15   16   17  \
# time                           9시  10시  11시  12시  13시  14시  15시  16시  17시
# CJ 드림시티s_min                    7    1    0    0    0    0    0    0    0
# CJ 드림시티s_max                  값없음  값없음   17   20   21   21   21   21   21
# 고속터미널역 8-1번, 8-2번 출구 사이s_min  값없음  값없음   14    1    0    0    0    0    0
# 고속터미널역 8-1번, 8-2번 출구 사이s_max  값없음   24   25   26   26   26   26   26   26
# 공릉역 1번 출구 앞s_min                3    2    1    0    0    0    0    0    0
# 공릉역 1번 출구 앞s_max               10   11   11   12   12   12   12   12   12
# 독산보도육교 앞 자전거 보관소s_min           1    1    1    1    1    1    1    1    1
# 독산보도육교 앞 자전거 보관소s_max          11   14   15   15   15   15   15   15   15
# 동묘앞역 1번출구 뒤s_min                4    3    2    1    1    1    1    1    1
# 동묘앞역 1번출구 뒤s_max               10   10   11   11   11   11   11   11   11
# 뚝섬유원지역 1번출구 앞s_min            값없음  값없음  값없음  값없음    2    0    0    0    0
# 뚝섬유원지역 1번출구 앞s_max            값없음  값없음   77   86   87   88   88   88   88
# 롯데월드타워(잠실역2번출구 쪽)s_min          0    0    0    0    0    0    0    0    0
# 롯데월드타워(잠실역2번출구 쪽)s_max         37   37   37   37   37   37   37   37   37
# 마곡나루역 2번 출구s_min                0    0    0    0    0    0    0    0    0
# 마곡나루역 2번 출구s_max               31   31   31   31   31   31   31   31   31
# 마포구민체육센터 앞s_min               값없음  값없음  값없음  값없음    2    0    0    0    0
# 마포구민체육센터 앞s_max               값없음  값없음  값없음   59   64   65   65   65   65
# 목동역5번출구 교통정보센터 앞s_min           1    1    1    0    0    0    0    0    0
# 목동역5번출구 교통정보센터 앞s_max          15   15   15   15   16   16   16   16   16
# 봉림교 교통섬s_min                  값없음  값없음  값없음    4    2    1    0    0    0
# 봉림교 교통섬s_max                  값없음  값없음  값없음  값없음   43   44   45   45   45
# 신도림역 1번 출구 앞s_min               0    0    0    0    0    0    0    0    0
# 신도림역 1번 출구 앞s_max              23   23   23   23   23   23   23   23   23
# 안암로터리 버스정류장 앞s_min            값없음  값없음    3    0    0    0    0    0    0
# 안암로터리 버스정류장 앞s_max             15   17   17   17   17   17   17   17   17
# 여의나루역 1번출구 앞s_min             값없음  값없음  값없음  값없음    2    0    0    0    0
# 여의나루역 1번출구 앞s_max             값없음  값없음  값없음  값없음   84   84   84   84   84
# 옥수역 3번출구s_min                   1    0    0    0    0    0    0    0    0
# 옥수역 3번출구s_max                  28   31   32   33   33   33   33   33   33
# 용산역 맞은편s_min                  값없음   10    2    1    1    1    1    1    1
# 용산역 맞은편s_max                   20   20   20   20   20   20   20   20   20
# 이디야 커피 수유역점 앞s_min            값없음  값없음    8    3    2    2    1    1    1
# 이디야 커피 수유역점 앞s_max              7    8    8    8    8    8    8    8    8
# 장한평역 1번출구 (국민은행앞)s_min          0    0    0    0    0    0    0    0    0
# 장한평역 1번출구 (국민은행앞)s_max         12   12   12   12   12   12   12   12   12
# 중랑세무서s_min                      4    3    2    2    2    2    2    2    2
# 중랑세무서s_max                    값없음  값없음    7   12   14   14   14   14   14
# 창동역 2번출구s_min                   2    1    1    0    0    0    0    0    0
# 창동역 2번출구s_max                  12   12   12   12   12   12   12   12   12
# 천호역4번출구(현대백화점)s_min             3    1    0    0    0    0    0    0    0
# 천호역4번출구(현대백화점)s_max            14   14   14   14   14   14   14   14   14
# 청계천 영도교s_min                    2    2    2    2    2    1    1    1    1
# 청계천 영도교s_max                    6    6    7    7    7    7    7    8    8
# 현대고등학교 건너편s_min               값없음  값없음  값없음    2    1    1    1    1    0
# 현대고등학교 건너편s_max               값없음  값없음  값없음  값없음   15   15   15   16   16
# 홍은사거리s_min                      2    2    1    1    1    1    1    1    1
# 홍은사거리s_max                      9   13   14   14   14   14   14   14   14
# 흑석역 1번출구s_min                   2    1    1    0    0    0    0    0    0
# 흑석역 1번출구s_max                 값없음  값없음   16   18   19   20   20   20   20
#
#                                18   19   20   21   22   23
# time                          18시  19시  20시  21시  22시  23시
# CJ 드림시티s_min                    0    0    0    0    0    0
# CJ 드림시티s_max                   21   21   21   21   21   22
# 고속터미널역 8-1번, 8-2번 출구 사이s_min    0    0    0    0    0    0
# 고속터미널역 8-1번, 8-2번 출구 사이s_max   26   26   26   26   26   26
# 공릉역 1번 출구 앞s_min                0    0    0    0    0    0
# 공릉역 1번 출구 앞s_max               12   12   12   12   12   12
# 독산보도육교 앞 자전거 보관소s_min           1    1    1    1    1    1
# 독산보도육교 앞 자전거 보관소s_max          15   15   15   15   15   15
# 동묘앞역 1번출구 뒤s_min                1    1    0    0    0    0
# 동묘앞역 1번출구 뒤s_max               11   11   11   11   11   11
# 뚝섬유원지역 1번출구 앞s_min              0    0    0    0    0    0
# 뚝섬유원지역 1번출구 앞s_max             88   88   88   89   89   89
# 롯데월드타워(잠실역2번출구 쪽)s_min          0    0    0    0    0    0
# 롯데월드타워(잠실역2번출구 쪽)s_max         37   37   37   37   37   37
# 마곡나루역 2번 출구s_min                0    0    0    0    0    0
# 마곡나루역 2번 출구s_max               31   31   31   31   31   31
# 마포구민체육센터 앞s_min                 0    0    0    0    0    0
# 마포구민체육센터 앞s_max                65   65   65   65   65   65
# 목동역5번출구 교통정보센터 앞s_min           0    0    0    0    0    0
# 목동역5번출구 교통정보센터 앞s_max          16   16   16   16   16   16
# 봉림교 교통섬s_min                    0    0    0    0    0    0
# 봉림교 교통섬s_max                   45   45   45   45   45   45
# 신도림역 1번 출구 앞s_min               0    0    0    0    0    0
# 신도림역 1번 출구 앞s_max              23   23   23   23   23   23
# 안암로터리 버스정류장 앞s_min              0    0    0    0    0    0
# 안암로터리 버스정류장 앞s_max             17   17   17   17   17   17
# 여의나루역 1번출구 앞s_min               0    0    0    0    0    0
# 여의나루역 1번출구 앞s_max              84   84   84   84   84   84
# 옥수역 3번출구s_min                   0    0    0    0    0    0
# 옥수역 3번출구s_max                  33   33   33   33   33   33
# 용산역 맞은편s_min                    1    1    1    1    1    1
# 용산역 맞은편s_max                   20   20   20   20   20   20
# 이디야 커피 수유역점 앞s_min              1    1    1    1    1    1
# 이디야 커피 수유역점 앞s_max              8    8    8    8    8    8
# 장한평역 1번출구 (국민은행앞)s_min          0    0    0    0    0    0
# 장한평역 1번출구 (국민은행앞)s_max         12   12   12   12   12   12
# 중랑세무서s_min                      1    1    1    1    1    1
# 중랑세무서s_max                     14   14   14   14   14   14
# 창동역 2번출구s_min                   0    0    0    0    0    0
# 창동역 2번출구s_max                  12   12   12   12   12   12
# 천호역4번출구(현대백화점)s_min             0    0    0    0    0    0
# 천호역4번출구(현대백화점)s_max            14   14   14   15   15   15
# 청계천 영도교s_min                    1    1    1    1    1    1
# 청계천 영도교s_max                    8    8    8    8    8    8
# 현대고등학교 건너편s_min                 0    0    0    0    0    0
# 현대고등학교 건너편s_max                16   16   16   16   16   16
# 홍은사거리s_min                      1    1    1    1    1    1
# 홍은사거리s_max                     14   14   14   14   14   14
# 흑석역 1번출구s_min                   0    0    0    0    0    0
# 흑석역 1번출구s_max                  20   20   20   20   20   20

# %%
data = df[df['time'] == '18시'].T
data
# Out:
#                                18
# time                          18시
# CJ 드림시티s_min                    0
# CJ 드림시티s_max                   21
# 고속터미널역 8-1번, 8-2번 출구 사이s_min    0
# 고속터미널역 8-1번, 8-2번 출구 사이s_max   26
# 공릉역 1번 출구 앞s_min                0
# 공릉역 1번 출구 앞s_max               12
# 독산보도육교 앞 자전거 보관소s_min           1
# 독산보도육교 앞 자전거 보관소s_max          15
# 동묘앞역 1번출구 뒤s_min                1
# 동묘앞역 1번출구 뒤s_max               11
# 뚝섬유원지역 1번출구 앞s_min              0
# 뚝섬유원지역 1번출구 앞s_max             88
# 롯데월드타워(잠실역2번출구 쪽)s_min          0
# 롯데월드타워(잠실역2번출구 쪽)s_max         37
# 마곡나루역 2번 출구s_min                0
# 마곡나루역 2번 출구s_max               31
# 마포구민체육센터 앞s_min                 0
# 마포구민체육센터 앞s_max                65
# 목동역5번출구 교통정보센터 앞s_min           0
# 목동역5번출구 교통정보센터 앞s_max          16
# 봉림교 교통섬s_min                    0
# 봉림교 교통섬s_max                   45
# 신도림역 1번 출구 앞s_min               0
# 신도림역 1번 출구 앞s_max              23
# 안암로터리 버스정류장 앞s_min              0
# 안암로터리 버스정류장 앞s_max             17
# 여의나루역 1번출구 앞s_min               0
# 여의나루역 1번출구 앞s_max              84
# 옥수역 3번출구s_min                   0
# 옥수역 3번출구s_max                  33
# 용산역 맞은편s_min                    1
# 용산역 맞은편s_max                   20
# 이디야 커피 수유역점 앞s_min              1
# 이디야 커피 수유역점 앞s_max              8
# 장한평역 1번출구 (국민은행앞)s_min          0
# 장한평역 1번출구 (국민은행앞)s_max         12
# 중랑세무서s_min                      1
# 중랑세무서s_max                     14
# 창동역 2번출구s_min                   0
# 창동역 2번출구s_max                  12
# 천호역4번출구(현대백화점)s_min             0
# 천호역4번출구(현대백화점)s_max            14
# 청계천 영도교s_min                    1
# 청계천 영도교s_max                    8
# 현대고등학교 건너편s_min                 0
# 현대고등학교 건너편s_max                16
# 홍은사거리s_min                      1
# 홍은사거리s_max                     14
# 흑석역 1번출구s_min                   0
# 흑석역 1번출구s_max                  20

# %%
x = []
for i in range(1, len(data), 2):
    x.append(data.iloc[i])
x
# Out:
# [18    0
#  Name: CJ 드림시티s_min, dtype: object,
#  18    0
#  Name: 고속터미널역 8-1번, 8-2번 출구 사이s_min, dtype: object,
#  18    0
#  Name: 공릉역 1번 출구 앞s_min, dtype: object,
#  18    1
#  Name: 독산보도육교 앞 자전거 보관소s_min, dtype: object,
#  18    1
#  Name: 동묘앞역 1번출구 뒤s_min, dtype: object,
#  18    0
#  Name: 뚝섬유원지역 1번출구 앞s_min, dtype: object,
#  18    0
#  Name: 롯데월드타워(잠실역2번출구 쪽)s_min, dtype: object,
#  18    0
#  Name: 마곡나루역 2번 출구s_min, dtype: object,
#  18    0
#  Name: 마포구민체육센터 앞s_min, dtype: object,
#  18    0
#  Name: 목동역5번출구 교통정보센터 앞s_min, dtype: object,
#  18    0
#  Name: 봉림교 교통섬s_min, dtype: object,
#  18    0
#  Name: 신도림역 1번 출구 앞s_min, dtype: object,
#  18    0
#  Name: 안암로터리 버스정류장 앞s_min, dtype: object,
#  18    0
#  Name: 여의나루역 1번출구 앞s_min, dtype: object,
#  18    0
#  Name: 옥수역 3번출구s_min, dtype: object,
#  18    1
#  Name: 용산역 맞은편s_min, dtype: object,
#  18    1
#  Name: 이디야 커피 수유역점 앞s_min, dtype: object,
#  18    0
#  Name: 장한평역 1번출구 (국민은행앞)s_min, dtype: object,
#  18    1
#  Name: 중랑세무서s_min, dtype: object,
#  18    0
#  Name: 창동역 2번출구s_min, dtype: object,
#  18    0
#  Name: 천호역4번출구(현대백화점)s_min, dtype: object,
#  18    1
#  Name: 청계천 영도교s_min, dtype: object,
#  18    0
#  Name: 현대고등학교 건너편s_min, dtype: object,
#  18    1
#  Name: 홍은사거리s_min, dtype: object,
#  18    0
#  Name: 흑석역 1번출구s_min, dtype: object]
