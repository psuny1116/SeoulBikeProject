# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'NanumGothic'

# %%
df = pd.read_csv('./data/공공자전거 대여이력 정보_2021.06.csv', engine = 'python')
df
# Out:
#              자전거번호                 대여일시  대여대여소번호          대여대여소명  대여거치대  \
# 0        SPB-30385  2021-05-31 23:07:00     3571  화양 APT(횡단보도 옆)      0
# 1        SPB-46321  2021-05-31 23:37:19     1911      구로디지털단지역 앞      0
# 2        SPB-48119  2021-05-31 23:48:40     3860      건국대학교 정문 앞      0
# 3        SPB-55360  2021-05-31 23:47:52     2222     사당역 12번출구 뒤      0
# 4        SPB-54699  2021-05-31 23:51:14     1955       디지털입구 교차로      0
# ...            ...                  ...      ...             ...    ...
# 3445866  SPB-36886  2021-06-30 22:44:14      152      마포구민체육센터 앞      0
# 3445867  SPB-30409  2021-06-30 22:45:19      152      마포구민체육센터 앞      0
# 3445868  SPB-46230  2021-06-30 22:43:43      152      마포구민체육센터 앞      0
# 3445869  SPB-41691  2021-06-30 22:11:14     2220     반포본동 주민센터 앞      0
# 3445870  SPB-52274  2021-06-30 22:12:10     2220     반포본동 주민센터 앞      0
#
#                         반납일시  반납대여소번호        반납대여소명  반납거치대  이용시간      이용거리
# 0        2021-06-01 00:00:00     3538      서울숲 IT캐슬      0    53   2502.80
# 1        2021-06-01 00:00:02     1843        독산고등학교      0    22   1630.00
# 2        2021-06-01 00:00:03     3586  군자역 비채온 오피스텔      0    11   1420.00
# 3        2021-06-01 00:00:05     2228        뒷벌공원 옆      0    12   1350.00
# 4        2021-06-01 00:00:08     1856         모두의학교      0     8    930.00
# ...                      ...      ...           ...    ...   ...       ...
# 3445866  2021-07-01 04:48:33      126      서강대 후문 옆      0   364  10153.36
# 3445867  2021-07-01 04:52:25      437      대흥역 1번출구      0   367  10100.71
# 3445868  2021-07-01 04:52:27      437      대흥역 1번출구      0   368    430.00
# 3445869  2021-07-01 04:55:29     2526      반포경남쇼핑 앞      0   404      0.00
# 3445870  2021-07-01 04:55:30     2526      반포경남쇼핑 앞      0   403   4541.22
#
# [3445871 rows x 11 columns]

# %%
df = df.drop(['자전거번호', '대여대여소번호', '대여거치대', '반납대여소번호', '반납거치대', '이용시간', '이용거리'], axis = 1)
df
# Out:
#                         대여일시          대여대여소명                 반납일시  \
# 0        2021-05-31 23:07:00  화양 APT(횡단보도 옆)  2021-06-01 00:00:00
# 1        2021-05-31 23:37:19      구로디지털단지역 앞  2021-06-01 00:00:02
# 2        2021-05-31 23:48:40      건국대학교 정문 앞  2021-06-01 00:00:03
# 3        2021-05-31 23:47:52     사당역 12번출구 뒤  2021-06-01 00:00:05
# 4        2021-05-31 23:51:14       디지털입구 교차로  2021-06-01 00:00:08
# ...                      ...             ...                  ...
# 3445866  2021-06-30 22:44:14      마포구민체육센터 앞  2021-07-01 04:48:33
# 3445867  2021-06-30 22:45:19      마포구민체육센터 앞  2021-07-01 04:52:25
# 3445868  2021-06-30 22:43:43      마포구민체육센터 앞  2021-07-01 04:52:27
# 3445869  2021-06-30 22:11:14     반포본동 주민센터 앞  2021-07-01 04:55:29
# 3445870  2021-06-30 22:12:10     반포본동 주민센터 앞  2021-07-01 04:55:30
#
#                반납대여소명
# 0            서울숲 IT캐슬
# 1              독산고등학교
# 2        군자역 비채온 오피스텔
# 3              뒷벌공원 옆
# 4               모두의학교
# ...               ...
# 3445866      서강대 후문 옆
# 3445867      대흥역 1번출구
# 3445868      대흥역 1번출구
# 3445869      반포경남쇼핑 앞
# 3445870      반포경남쇼핑 앞
#
# [3445871 rows x 4 columns]

# %%
df['대여일시'] = pd.to_datetime(df['대여일시'])
df['반납일시'] = pd.to_datetime(df['반납일시'])

# %%
df['대여월'] = df['대여일시'].dt.month
df['대여일'] = df['대여일시'].dt.day
df['대여요일'] = df['대여일시'].dt.dayofweek
df['대여시간'] = df['대여일시'].dt.hour
df['대여시간_분'] = df['대여일시'].dt.minute

df['반납월'] = df['반납일시'].dt.month
df['반납일'] = df['반납일시'].dt.day
df['반납요일'] = df['반납일시'].dt.dayofweek
df['반납시간'] = df['반납일시'].dt.hour
df['반납시간_분'] = df['반납일시'].dt.minute

# %%
df = df.sort_values('대여일시', ignore_index = True)
df
# Out:
#                        대여일시        대여대여소명                반납일시  \
# 0       2021-05-31 18:39:50    신목동역 2번 출구 2021-06-01 00:10:23
# 1       2021-05-31 19:03:06    잠실새내역 1번출구 2021-06-01 00:27:39
# 2       2021-05-31 19:16:35      조원동서울본병원 2021-06-01 00:15:25
# 3       2021-05-31 19:17:35    혜화역 3번출구 뒤 2021-06-01 00:33:45
# 4       2021-05-31 19:21:39       뚝섬 유원지역 2021-06-01 00:03:39
# ...                     ...           ...                 ...
# 3445866 2021-06-30 23:56:16      노들역 1번출구 2021-07-01 00:03:17
# 3445867 2021-06-30 23:56:22      독립문역 사거리 2021-07-01 00:04:52
# 3445868 2021-06-30 23:56:22   한강트럼프월드3차 앞 2021-07-01 00:06:14
# 3445869 2021-06-30 23:58:26     대림아파트 사거리 2021-07-01 00:06:51
# 3445870 2021-06-30 23:58:42  천왕역 1번 출입구 앞 2021-07-01 00:15:37
#
#                    반납대여소명  대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  반납시간  \
# 0         목동아파트2단지 222동 앞    5   31     0    18      39    6    1     1     0
# 1        잠실본동주민센터뒤 잠실근린공원    5   31     0    19       3    6    1     1     0
# 2                 봉림교 교통섬    5   31     0    19      16    6    1     1     0
# 3              LG베스트샵 종암점    5   31     0    19      17    6    1     1     0
# 4           뚝섬유원지역 1번출구 앞    5   31     0    19      21    6    1     1     0
# ...                   ...  ...  ...   ...   ...     ...  ...  ...   ...   ...
# 3445866            사육신공원앞    6   30     2    23      56    7    1     3     0
# 3445867       독립문역 3-1번출구    6   30     2    23      56    7    1     3     0
# 3445868       한강트럼프월드3차 앞    6   30     2    23      56    7    1     3     0
# 3445869       신길삼거리(우리은행)    6   30     2    23      58    7    1     3     0
# 3445870        천왕차량사업소 입구    6   30     2    23      58    7    1     3     0
#
#          반납시간_분
# 0            10
# 1            27
# 2            15
# 3            33
# 4             3
# ...         ...
# 3445866       3
# 3445867       4
# 3445868       6
# 3445869       6
# 3445870      15
#
# [3445871 rows x 14 columns]

# %%
df = df[df['대여월'] != 5]
df = df[df['반납월'] != 7]
df
# Out:
#                        대여일시       대여대여소명                반납일시         반납대여소명  \
# 1342    2021-06-01 00:00:01   LG베스트샵 종암점 2021-06-01 00:15:20         용문2교 옆
# 1343    2021-06-01 00:00:01  영등포구청역 1번출구 2021-06-01 00:11:17      유원목동아파트 앞
# 1344    2021-06-01 00:00:02      서남병원 후문 2021-06-01 00:06:00      잣절보도육교 아래
# 1345    2021-06-01 00:00:06       안암2교 옆 2021-06-01 00:04:51      보문역6번출구 앞
# 1346    2021-06-01 00:00:06   한성대입구역2번출구 2021-06-01 00:23:20  상왕십리역 4번 출구 앞
# ...                     ...          ...                 ...            ...
# 3445569 2021-06-30 22:49:40   양평1 보행육교 앞 2021-06-30 22:53:15   양평동6차현대아파트 앞
# 3445602 2021-06-30 22:50:11   강변역 4번출구 뒤 2021-06-30 22:53:13      구의삼성쉐르빌 앞
# 3445621 2021-06-30 22:50:32       증산3교 앞 2021-06-30 22:52:57         증산3교 앞
# 3445726 2021-06-30 22:52:06       성북3교 위 2021-06-30 23:48:56         성북3교 위
# 3445827 2021-06-30 22:53:28       충북 미래관 2021-06-30 23:48:51         충북 미래관
#
#          대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  반납시간  반납시간_분
# 1342       6    1     1     0       0    6    1     1     0      15
# 1343       6    1     1     0       0    6    1     1     0      11
# 1344       6    1     1     0       0    6    1     1     0       6
# 1345       6    1     1     0       0    6    1     1     0       4
# 1346       6    1     1     0       0    6    1     1     0      23
# ...      ...  ...   ...   ...     ...  ...  ...   ...   ...     ...
# 3445569    6   30     2    22      49    6   30     2    22      53
# 3445602    6   30     2    22      50    6   30     2    22      53
# 3445621    6   30     2    22      50    6   30     2    22      52
# 3445726    6   30     2    22      52    6   30     2    23      48
# 3445827    6   30     2    22      53    6   30     2    23      48
#
# [3442056 rows x 14 columns]

# %%
df['대여대여소명'] = df['대여대여소명'].astype('category')
df['반납대여소명'] = df['반납대여소명'].astype('category')

# %% [markdown]
# ### 평균서비스율(10분당 자전거 대여수의 평균) = $\mu$
# - $\mu$ = 10이면 10분동안 평균 10대의 자전거 대여

# %%
df_rental = df[['대여일시', '대여대여소명', '대여월', '대여일', '대여요일', '대여시간', '대여시간_분']]
df_rental.reset_index(drop = True, inplace = True)
df_rental
# Out:
#                        대여일시       대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분
# 0       2021-06-01 00:00:01   LG베스트샵 종암점    6    1     1     0       0
# 1       2021-06-01 00:00:01  영등포구청역 1번출구    6    1     1     0       0
# 2       2021-06-01 00:00:02      서남병원 후문    6    1     1     0       0
# 3       2021-06-01 00:00:06       안암2교 옆    6    1     1     0       0
# 4       2021-06-01 00:00:06   한성대입구역2번출구    6    1     1     0       0
# ...                     ...          ...  ...  ...   ...   ...     ...
# 3442051 2021-06-30 22:49:40   양평1 보행육교 앞    6   30     2    22      49
# 3442052 2021-06-30 22:50:11   강변역 4번출구 뒤    6   30     2    22      50
# 3442053 2021-06-30 22:50:32       증산3교 앞    6   30     2    22      50
# 3442054 2021-06-30 22:52:06       성북3교 위    6   30     2    22      52
# 3442055 2021-06-30 22:53:28       충북 미래관    6   30     2    22      53
#
# [3442056 rows x 7 columns]

# %%
df_rental = df_rental[df_rental['대여대여소명'] == '뚝섬유원지역 1번출구 앞']
df_rental.reset_index(drop = True, inplace = True)
df_rental
# Out:
#                      대여일시         대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분
# 0     2021-06-01 00:00:35  뚝섬유원지역 1번출구 앞    6    1     1     0       0
# 1     2021-06-01 00:04:03  뚝섬유원지역 1번출구 앞    6    1     1     0       4
# 2     2021-06-01 00:04:59  뚝섬유원지역 1번출구 앞    6    1     1     0       4
# 3     2021-06-01 00:12:06  뚝섬유원지역 1번출구 앞    6    1     1     0      12
# 4     2021-06-01 00:13:22  뚝섬유원지역 1번출구 앞    6    1     1     0      13
# ...                   ...            ...  ...  ...   ...   ...     ...
# 14957 2021-06-30 22:32:00  뚝섬유원지역 1번출구 앞    6   30     2    22      32
# 14958 2021-06-30 22:34:46  뚝섬유원지역 1번출구 앞    6   30     2    22      34
# 14959 2021-06-30 22:36:18  뚝섬유원지역 1번출구 앞    6   30     2    22      36
# 14960 2021-06-30 22:40:25  뚝섬유원지역 1번출구 앞    6   30     2    22      40
# 14961 2021-06-30 22:40:35  뚝섬유원지역 1번출구 앞    6   30     2    22      40
#
# [14962 rows x 7 columns]

# %% [markdown]
# #### 0시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 0]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    151
# 1         10    128
# 2         20    106
# 3         30    101
# 4         40    111
# 5         50    113

# %%
# 10분당 평균 대여율 = 평균서비스율

mu0 = df_rental_hour_group['count'].sum() / 6
mu0
# Out:
# 118.33333333333333

# %% [markdown]
# #### 1시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 1]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    108
# 1         10     95
# 2         20     99
# 3         30     59
# 4         40     44
# 5         50     68

# %%
# 1시 10분당 평균 대여율 = 평균서비스율

mu1 = df_rental_hour_group['count'].sum() / 6
mu1
# Out:
# 78.83333333333333

# %% [markdown]
# #### 2시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 2]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     47
# 1         10     55
# 2         20     57
# 3         30     41
# 4         40     22
# 5         50     36

# %%
# 2시 10분당 평균 대여율 = 평균서비스율

mu2 = df_rental_hour_group['count'].sum() / 6
mu2
# Out:
# 43.0

# %% [markdown]
# #### 3시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 3]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     27
# 1         10     22
# 2         20     25
# 3         30     23
# 4         40     25
# 5         50     18

# %%
# 10분당 평균 대여율 = 평균서비스율

mu3 = df_rental_hour_group['count'].sum() / 6
mu3
# Out:
# 23.333333333333332

# %% [markdown]
# #### 4시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 4]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     31
# 1         10     20
# 2         20     18
# 3         30     14
# 4         40      8
# 5         50     12

# %%
# 10분당 평균 대여율 = 평균서비스율

mu4 = df_rental_hour_group['count'].sum() / 6
mu4
# Out:
# 17.166666666666668

# %% [markdown]
# #### 5시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 5]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     15
# 1         10     11
# 2         20      5
# 3         30      6
# 4         40     11
# 5         50     10

# %%
# 10분당 평균 대여율 = 평균서비스율

mu5 = df_rental_hour_group['count'].sum() / 6
mu5
# Out:
# 9.666666666666666

# %% [markdown]
# #### 6시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 6]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      5
# 1         10     11
# 2         20      8
# 3         30     16
# 4         40     18
# 5         50     29

# %%
# 10분당 평균 대여율 = 평균서비스율

mu6 = df_rental_hour_group['count'].sum() / 6
mu6
# Out:
# 14.5

# %% [markdown]
# #### 7시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 7]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     27
# 1         10     23
# 2         20     41
# 3         30     43
# 4         40     50
# 5         50     92

# %%
# 10분당 평균 대여율 = 평균서비스율

mu7 = df_rental_hour_group['count'].sum() / 6
mu7
# Out:
# 46.0

# %% [markdown]
# #### 8시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 8]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     81
# 1         10    104
# 2         20     60
# 3         30    102
# 4         40     70
# 5         50     56

# %%
# 10분당 평균 대여율 = 평균서비스율

mu8 = df_rental_hour_group['count'].sum() / 6
mu8
# Out:
# 78.83333333333333

# %% [markdown]
# #### 9시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 9]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     46
# 1         10     51
# 2         20     56
# 3         30     60
# 4         40     52
# 5         50     56

# %%
# 10분당 평균 대여율 = 평균서비스율

mu9 = df_rental_hour_group['count'].sum() / 6
mu9
# Out:
# 53.5

# %% [markdown]
# #### 10시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 10]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     43
# 1         10     50
# 2         20     50
# 3         30     38
# 4         40     44
# 5         50     29

# %%
# 10분당 평균 대여율 = 평균서비스율

mu10 = df_rental_hour_group['count'].sum() / 6
mu10
# Out:
# 42.333333333333336

# %% [markdown]
# #### 11시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 11]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     58
# 1         10     49
# 2         20     26
# 3         30     43
# 4         40     24
# 5         50     46

# %%
# 10분당 평균 대여율 = 평균서비스율

mu11 = df_rental_hour_group['count'].sum() / 6
mu11
# Out:
# 41.0

# %% [markdown]
# #### 12시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 12]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     37
# 1         10     55
# 2         20     60
# 3         30     54
# 4         40     50
# 5         50     51

# %%
# 10분당 평균 대여율 = 평균서비스율

mu12 = df_rental_hour_group['count'].sum() / 6
mu12
# Out:
# 51.166666666666664

# %% [markdown]
# #### 13시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 13]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     65
# 1         10     64
# 2         20     40
# 3         30     50
# 4         40     56
# 5         50     70

# %%
# 10분당 평균 대여율 = 평균서비스율

mu13 = df_rental_hour_group['count'].sum() / 6
mu13
# Out:
# 57.5

# %% [markdown]
# #### 14시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 14]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     50
# 1         10     55
# 2         20     91
# 3         30     77
# 4         40     50
# 5         50     63

# %%
# 10분당 평균 대여율 = 평균서비스율

mu14 = df_rental_hour_group['count'].sum() / 6
mu14
# Out:
# 64.33333333333333

# %% [markdown]
# #### 15시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 15]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     72
# 1         10     80
# 2         20     88
# 3         30    109
# 4         40    104
# 5         50     90

# %%
# 10분당 평균 대여율 = 평균서비스율

mu15 = df_rental_hour_group['count'].sum() / 6
mu15
# Out:
# 90.5

# %% [markdown]
# #### 16시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 16]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     95
# 1         10    103
# 2         20    107
# 3         30    130
# 4         40    109
# 5         50    119

# %%
# 10분당 평균 대여율 = 평균서비스율

mu16 = df_rental_hour_group['count'].sum() / 6
mu16
# Out:
# 110.5

# %% [markdown]
# #### 17시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 17]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    152
# 1         10    125
# 2         20    140
# 3         30    123
# 4         40    152
# 5         50    176

# %%
# 10분당 평균 대여율 = 평균서비스율

mu17 = df_rental_hour_group['count'].sum() / 6
mu17
# Out:
# 144.66666666666666

# %% [markdown]
# #### 18시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 18]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    200
# 1         10    242
# 2         20    210
# 3         30    251
# 4         40    249
# 5         50    246

# %%
# 10분당 평균 대여율 = 평균서비스율

mu18 = df_rental_hour_group['count'].sum() / 6
mu18
# Out:
# 233.0

# %% [markdown]
# #### 19시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 19]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    217
# 1         10    228
# 2         20    252
# 3         30    243
# 4         40    233
# 5         50    256

# %%
# 10분당 평균 대여율 = 평균서비스율

mu19 = df_rental_hour_group['count'].sum() / 6
mu19
# Out:
# 238.16666666666666

# %% [markdown]
# #### 20시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 20]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    251
# 1         10    242
# 2         20    248
# 3         30    276
# 4         40    235
# 5         50    289

# %%
# 10분당 평균 대여율 = 평균서비스율

mu20 = df_rental_hour_group['count'].sum() / 6
mu20
# Out:
# 256.8333333333333

# %% [markdown]
# #### 21시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 21]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    239
# 1         10    289
# 2         20    244
# 3         30    288
# 4         40    289
# 5         50    268

# %%
# 10분당 평균 대여율 = 평균서비스율

mu21 = df_rental_hour_group['count'].sum() / 6
mu21
# Out:
# 269.5

# %% [markdown]
# #### 22시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 22]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    238
# 1         10    254
# 2         20    257
# 3         30    229
# 4         40    235
# 5         50    222

# %%
# 10분당 평균 대여율 = 평균서비스율

mu22 = df_rental_hour_group['count'].sum() / 6
mu22
# Out:
# 239.16666666666666

# %% [markdown]
# #### 23시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 23]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    197
# 1         10    212
# 2         20    150
# 3         30    170
# 4         40    156
# 5         50    146

# %%
# 10분당 평균 대여율 = 평균서비스율

mu23 = df_rental_hour_group['count'].sum() / 6
mu23
# Out:
# 171.83333333333334

# %% [markdown]
# - 2021년 6월 한달동안의 뚝섬유원지역 1번출구 앞 대여소의 평균서비스율 뮤(10분당 평균 대여수)는

# %%
a = [mu0, mu1, mu2, mu3, mu4, mu5, mu6, mu7, mu8, mu9, mu10, mu11, mu12, mu13, mu14, mu15, mu16, mu17, mu18, mu19, mu20, mu21, mu22, mu23]
time = ['0시', '1시', '2시', '3시', '4시', '5시', '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시',
       '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시']

result = pd.DataFrame(time)
result.columns = ['time']
result['mu'] = a
result
# Out:
#    time          mu
# 0    0시  118.333333
# 1    1시   78.833333
# 2    2시   43.000000
# 3    3시   23.333333
# 4    4시   17.166667
# 5    5시    9.666667
# 6    6시   14.500000
# 7    7시   46.000000
# 8    8시   78.833333
# 9    9시   53.500000
# 10  10시   42.333333
# 11  11시   41.000000
# 12  12시   51.166667
# 13  13시   57.500000
# 14  14시   64.333333
# 15  15시   90.500000
# 16  16시  110.500000
# 17  17시  144.666667
# 18  18시  233.000000
# 19  19시  238.166667
# 20  20시  256.833333
# 21  21시  269.500000
# 22  22시  239.166667
# 23  23시  171.833333

# %% [markdown]
# ### 평균도착률(10분당 자전거 반납수의 평균) = $\lambda$
# - $\lambda$ = 10이면 10분동안 평균 10대의 자전거를 반납

# %%
df_return = df[['반납일시', '반납대여소명', '반납월', '반납일', '반납요일', '반납시간', '반납시간_분']]
df_return
# Out:
#                        반납일시         반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분
# 1342    2021-06-01 00:15:20         용문2교 옆    6    1     1     0      15
# 1343    2021-06-01 00:11:17      유원목동아파트 앞    6    1     1     0      11
# 1344    2021-06-01 00:06:00      잣절보도육교 아래    6    1     1     0       6
# 1345    2021-06-01 00:04:51      보문역6번출구 앞    6    1     1     0       4
# 1346    2021-06-01 00:23:20  상왕십리역 4번 출구 앞    6    1     1     0      23
# ...                     ...            ...  ...  ...   ...   ...     ...
# 3445569 2021-06-30 22:53:15   양평동6차현대아파트 앞    6   30     2    22      53
# 3445602 2021-06-30 22:53:13      구의삼성쉐르빌 앞    6   30     2    22      53
# 3445621 2021-06-30 22:52:57         증산3교 앞    6   30     2    22      52
# 3445726 2021-06-30 23:48:56         성북3교 위    6   30     2    23      48
# 3445827 2021-06-30 23:48:51         충북 미래관    6   30     2    23      48
#
# [3442056 rows x 7 columns]

# %%
df_return = df_return[df_return['반납대여소명'] == '뚝섬유원지역 1번출구 앞']
df_return
# Out:
#                        반납일시         반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분
# 2492    2021-06-01 00:39:17  뚝섬유원지역 1번출구 앞    6    1     1     0      39
# 2871    2021-06-01 01:43:26  뚝섬유원지역 1번출구 앞    6    1     1     1      43
# 2908    2021-06-01 01:05:59  뚝섬유원지역 1번출구 앞    6    1     1     1       5
# 2911    2021-06-01 01:43:19  뚝섬유원지역 1번출구 앞    6    1     1     1      43
# 2914    2021-06-01 01:43:52  뚝섬유원지역 1번출구 앞    6    1     1     1      43
# ...                     ...            ...  ...  ...   ...   ...     ...
# 3440920 2021-06-30 22:26:30  뚝섬유원지역 1번출구 앞    6   30     2    22      26
# 3440927 2021-06-30 22:26:35  뚝섬유원지역 1번출구 앞    6   30     2    22      26
# 3442339 2021-06-30 22:44:17  뚝섬유원지역 1번출구 앞    6   30     2    22      44
# 3442846 2021-06-30 22:34:35  뚝섬유원지역 1번출구 앞    6   30     2    22      34
# 3444698 2021-06-30 22:41:26  뚝섬유원지역 1번출구 앞    6   30     2    22      41
#
# [15969 rows x 7 columns]

# %% [markdown]
# #### 0시

# %%
df_return_hour = df_return[df_return['반납시간'] == 0]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    127
# 1         10    108
# 2         20    107
# 3         30     98
# 4         40     77
# 5         50     96

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda0 = df_return_hour_group['count'].sum() / 6
lda0
# Out:
# 102.16666666666667

# %% [markdown]
# #### 1시

# %%
df_return_hour = df_return[df_return['반납시간'] == 1]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     68
# 1         10     41
# 2         20     57
# 3         30     53
# 4         40     55
# 5         50     42

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda1 = df_return_hour_group['count'].sum() / 6
lda1
# Out:
# 52.666666666666664

# %% [markdown]
# #### 2시

# %%
df_return_hour = df_return[df_return['반납시간'] == 2]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     20
# 1         10     39
# 2         20     43
# 3         30     39
# 4         40     16
# 5         50     14

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda2 = df_return_hour_group['count'].sum() / 6
lda2
# Out:
# 28.5

# %% [markdown]
# #### 3시

# %%
df_return_hour = df_return[df_return['반납시간'] == 3]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     11
# 1         10     32
# 2         20     20
# 3         30      7
# 4         40      9
# 5         50     16

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda3 = df_return_hour_group['count'].sum() / 6
lda3
# Out:
# 15.833333333333334

# %% [markdown]
# #### 4시

# %%
df_return_hour = df_return[df_return['반납시간'] == 4]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     14
# 1         10     17
# 2         20      8
# 3         30      7
# 4         40      8
# 5         50      8

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda4 = df_return_hour_group['count'].sum() / 6
lda4
# Out:
# 10.333333333333334

# %% [markdown]
# #### 5시

# %%
df_return_hour = df_return[df_return['반납시간'] == 5]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      7
# 1         10     15
# 2         20      9
# 3         30     28
# 4         40     10
# 5         50     11

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda5 = df_return_hour_group['count'].sum() / 6
lda5
# Out:
# 13.333333333333334

# %% [markdown]
# #### 6시

# %%
df_return_hour = df_return[df_return['반납시간'] == 6]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      5
# 1         10     13
# 2         20     13
# 3         30     27
# 4         40     18
# 5         50     31

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda6 = df_return_hour_group['count'].sum() / 6
lda6
# Out:
# 17.833333333333332

# %% [markdown]
# #### 7시

# %%
df_return_hour = df_return[df_return['반납시간'] == 7]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     43
# 1         10     76
# 2         20     66
# 3         30     56
# 4         40     77
# 5         50     92

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda7 = df_return_hour_group['count'].sum() / 6
lda7
# Out:
# 68.33333333333333

# %% [markdown]
# #### 8시

# %%
df_return_hour = df_return[df_return['반납시간'] == 8]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    114
# 1         10     91
# 2         20     61
# 3         30     89
# 4         40     61
# 5         50     65

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda8 = df_return_hour_group['count'].sum() / 6
lda8
# Out:
# 80.16666666666667

# %% [markdown]
# #### 9시

# %%
df_return_hour = df_return[df_return['반납시간'] == 9]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    108
# 1         10     53
# 2         20     77
# 3         30     44
# 4         40     48
# 5         50     40

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda9 = df_return_hour_group['count'].sum() / 6
lda9
# Out:
# 61.666666666666664

# %% [markdown]
# #### 10시

# %%
df_return_hour = df_return[df_return['반납시간'] == 10]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     33
# 1         10     42
# 2         20     48
# 3         30     41
# 4         40     51
# 5         50     46

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda10 = df_return_hour_group['count'].sum() / 6
lda10
# Out:
# 43.5

# %% [markdown]
# #### 11시

# %%
df_return_hour = df_return[df_return['반납시간'] == 11]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     35
# 1         10     33
# 2         20     42
# 3         30     44
# 4         40     45
# 5         50     45

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda11 = df_return_hour_group['count'].sum() / 6
lda11
# Out:
# 40.666666666666664

# %% [markdown]
# #### 12시

# %%
df_return_hour = df_return[df_return['반납시간'] == 12]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     56
# 1         10     61
# 2         20     63
# 3         30     51
# 4         40     53
# 5         50     61

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda12 = df_return_hour_group['count'].sum() / 6
lda12
# Out:
# 57.5

# %% [markdown]
# #### 13시

# %%
df_return_hour = df_return[df_return['반납시간'] == 13]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     54
# 1         10     62
# 2         20     50
# 3         30     49
# 4         40     64
# 5         50     50

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda13 = df_return_hour_group['count'].sum() / 6
lda13
# Out:
# 54.833333333333336

# %% [markdown]
# #### 14시

# %%
df_return_hour = df_return[df_return['반납시간'] == 14]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     63
# 1         10     70
# 2         20     66
# 3         30     67
# 4         40     65
# 5         50     75

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda14 = df_return_hour_group['count'].sum() / 6
lda14
# Out:
# 67.66666666666667

# %% [markdown]
# #### 15시

# %%
df_return_hour = df_return[df_return['반납시간'] == 15]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     69
# 1         10     86
# 2         20     81
# 3         30     91
# 4         40     89
# 5         50     76

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda15 = df_return_hour_group['count'].sum() / 6
lda15
# Out:
# 82.0

# %% [markdown]
# #### 16시

# %%
df_return_hour = df_return[df_return['반납시간'] == 16]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    115
# 1         10     93
# 2         20    127
# 3         30    153
# 4         40    118
# 5         50    136

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda16 = df_return_hour_group['count'].sum() / 6
lda16
# Out:
# 123.66666666666667

# %% [markdown]
# #### 17시

# %%
df_return_hour = df_return[df_return['반납시간'] == 17]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    125
# 1         10    153
# 2         20    137
# 3         30    220
# 4         40    162
# 5         50    204

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda17 = df_return_hour_group['count'].sum() / 6
lda17
# Out:
# 166.83333333333334

# %% [markdown]
# #### 18시

# %%
df_return_hour = df_return[df_return['반납시간'] == 18]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    250
# 1         10    266
# 2         20    254
# 3         30    285
# 4         40    262
# 5         50    266

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda18 = df_return_hour_group['count'].sum() / 6
lda18
# Out:
# 263.8333333333333

# %% [markdown]
# #### 19시

# %%
df_return_hour = df_return[df_return['반납시간'] == 19]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    279
# 1         10    292
# 2         20    238
# 3         30    311
# 4         40    252
# 5         50    327

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda19 = df_return_hour_group['count'].sum() / 6
lda19
# Out:
# 283.1666666666667

# %% [markdown]
# #### 20시

# %%
df_return_hour = df_return[df_return['반납시간'] == 20]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    297
# 1         10    323
# 2         20    323
# 3         30    305
# 4         40    310
# 5         50    303

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda20 = df_return_hour_group['count'].sum() / 6
lda20
# Out:
# 310.1666666666667

# %% [markdown]
# #### 21시

# %%
df_return_hour = df_return[df_return['반납시간'] == 21]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    286
# 1         10    309
# 2         20    304
# 3         30    247
# 4         40    298
# 5         50    257

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda21 = df_return_hour_group['count'].sum() / 6
lda21
# Out:
# 283.5

# %% [markdown]
# #### 22시

# %%
df_return_hour = df_return[df_return['반납시간'] == 22]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    277
# 1         10    251
# 2         20    249
# 3         30    248
# 4         40    255
# 5         50    250

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda22 = df_return_hour_group['count'].sum() / 6
lda22
# Out:
# 255.0

# %% [markdown]
# #### 23시

# %%
df_return_hour = df_return[df_return['반납시간'] == 23]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    213
# 1         10    211
# 2         20    187
# 3         30    185
# 4         40    138
# 5         50    136

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda23 = df_return_hour_group['count'].sum() / 6
lda23
# Out:
# 178.33333333333334

# %% [markdown]
# - 2021년 6월 한달동안의 뚝섬유원지역 1번출구 앞 대여소의 평균도착률 람다(10분당 평균 반납수)는

# %%
b = [lda0, lda1, lda2, lda3, lda4, lda5, lda6, lda7, lda8, lda9, lda10, lda11, lda12, lda13, lda14, lda15, lda16, lda17, lda18, lda19, lda20, lda21, lda22, lda23]

result['lambda'] = b
result
# Out:
#    time          mu      lambda
# 0    0시  118.333333  102.166667
# 1    1시   78.833333   52.666667
# 2    2시   43.000000   28.500000
# 3    3시   23.333333   15.833333
# 4    4시   17.166667   10.333333
# 5    5시    9.666667   13.333333
# 6    6시   14.500000   17.833333
# 7    7시   46.000000   68.333333
# 8    8시   78.833333   80.166667
# 9    9시   53.500000   61.666667
# 10  10시   42.333333   43.500000
# 11  11시   41.000000   40.666667
# 12  12시   51.166667   57.500000
# 13  13시   57.500000   54.833333
# 14  14시   64.333333   67.666667
# 15  15시   90.500000   82.000000
# 16  16시  110.500000  123.666667
# 17  17시  144.666667  166.833333
# 18  18시  233.000000  263.833333
# 19  19시  238.166667  283.166667
# 20  20시  256.833333  310.166667
# 21  21시  269.500000  283.500000
# 22  22시  239.166667  255.000000
# 23  23시  171.833333  178.333333

# %% [markdown]
# ### 가용도(고객이 station에 도착했을 때 자전거가 station에 있을 확률)
# $1 - (1 - \frac{\lambda}{\mu})(\frac{\lambda}{\mu})^0$ = $\frac{\lambda}{\mu}$

# %%
result['가용도'] = result['lambda'] / result['mu']
result = result[['time', 'lambda', 'mu', '가용도']]
result
# Out:
#    time      lambda          mu       가용도
# 0    0시  102.166667  118.333333  0.863380
# 1    1시   52.666667   78.833333  0.668076
# 2    2시   28.500000   43.000000  0.662791
# 3    3시   15.833333   23.333333  0.678571
# 4    4시   10.333333   17.166667  0.601942
# 5    5시   13.333333    9.666667  1.379310
# 6    6시   17.833333   14.500000  1.229885
# 7    7시   68.333333   46.000000  1.485507
# 8    8시   80.166667   78.833333  1.016913
# 9    9시   61.666667   53.500000  1.152648
# 10  10시   43.500000   42.333333  1.027559
# 11  11시   40.666667   41.000000  0.991870
# 12  12시   57.500000   51.166667  1.123779
# 13  13시   54.833333   57.500000  0.953623
# 14  14시   67.666667   64.333333  1.051813
# 15  15시   82.000000   90.500000  0.906077
# 16  16시  123.666667  110.500000  1.119155
# 17  17시  166.833333  144.666667  1.153226
# 18  18시  263.833333  233.000000  1.132332
# 19  19시  283.166667  238.166667  1.188943
# 20  20시  310.166667  256.833333  1.207657
# 21  21시  283.500000  269.500000  1.051948
# 22  22시  255.000000  239.166667  1.066202
# 23  23시  178.333333  171.833333  1.037827

# %%
plt.style.use('bmh')

# %%
result.plot(kind = 'bar', x = 'time', y = 'lambda', figsize = (24, 10), 
            title = '2021년 6월 뚝섬유원지역 1번출구 앞 대여소 평균도착률(단위시간: 10분)')
plt.show()

# %%
result.plot(kind = 'bar', x = 'time', y = 'mu', figsize = (24, 10), 
            title = '2021년 6월 뚝섬유원지역 1번출구 앞 대여소 평균서비스율(단위시간: 10분)')
plt.show()

# %%
result.plot(kind = 'bar', x = 'time', y = '가용도', figsize = (24, 10), 
            title = '2021년 6월 뚝섬유원지역 1번출구 앞 대여소 가용도')
plt.show()

# %% [markdown]
# - 가용도가 1이하인 시간대는 반납보다 대여가 많아서 자전거 빌리기 어려움
# - 0시 ~ 4시, 11시, 13시, 15시일 때 가용도가 1이하임
# - 롯데월드타워 대여소와 비교해 볼 때 롯데월드타워 대여소보다 가용도가 일정한 편이고 대부분 1보다 큼
# - 따라서 롯데월드타워보다 따릉이 이용이 수월할 것으로 예상됨
# - 또한, 가용도가 대체로 1 근처인 것으로 보아 반납과 대여가 비슷할 것으로 예상됨
# - 롯데월드타워 대여소와 마찬가지로 5시에 갑자기 가용도가 높아진 것으로 보아 이때쯤 자전거 재배치가 이루어지는 것 같음
