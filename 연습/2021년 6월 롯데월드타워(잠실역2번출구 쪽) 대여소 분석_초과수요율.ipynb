# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'NanumGothic'

# %%
df = pd.read_csv('./data/공공자전거 대여이력 정보_2021.06.csv', engine = 'python')
df
# Out:
#              자전거번호                 대여일시  대여대여소번호          대여대여소명  대여거치대  \
# 0        SPB-30385  2021-05-31 23:07:00     3571  화양 APT(횡단보도 옆)      0
# 1        SPB-46321  2021-05-31 23:37:19     1911      구로디지털단지역 앞      0
# 2        SPB-48119  2021-05-31 23:48:40     3860      건국대학교 정문 앞      0
# 3        SPB-55360  2021-05-31 23:47:52     2222     사당역 12번출구 뒤      0
# 4        SPB-54699  2021-05-31 23:51:14     1955       디지털입구 교차로      0
# ...            ...                  ...      ...             ...    ...
# 3445866  SPB-36886  2021-06-30 22:44:14      152      마포구민체육센터 앞      0
# 3445867  SPB-30409  2021-06-30 22:45:19      152      마포구민체육센터 앞      0
# 3445868  SPB-46230  2021-06-30 22:43:43      152      마포구민체육센터 앞      0
# 3445869  SPB-41691  2021-06-30 22:11:14     2220     반포본동 주민센터 앞      0
# 3445870  SPB-52274  2021-06-30 22:12:10     2220     반포본동 주민센터 앞      0
#
#                         반납일시  반납대여소번호        반납대여소명  반납거치대  이용시간      이용거리
# 0        2021-06-01 00:00:00     3538      서울숲 IT캐슬      0    53   2502.80
# 1        2021-06-01 00:00:02     1843        독산고등학교      0    22   1630.00
# 2        2021-06-01 00:00:03     3586  군자역 비채온 오피스텔      0    11   1420.00
# 3        2021-06-01 00:00:05     2228        뒷벌공원 옆      0    12   1350.00
# 4        2021-06-01 00:00:08     1856         모두의학교      0     8    930.00
# ...                      ...      ...           ...    ...   ...       ...
# 3445866  2021-07-01 04:48:33      126      서강대 후문 옆      0   364  10153.36
# 3445867  2021-07-01 04:52:25      437      대흥역 1번출구      0   367  10100.71
# 3445868  2021-07-01 04:52:27      437      대흥역 1번출구      0   368    430.00
# 3445869  2021-07-01 04:55:29     2526      반포경남쇼핑 앞      0   404      0.00
# 3445870  2021-07-01 04:55:30     2526      반포경남쇼핑 앞      0   403   4541.22
#
# [3445871 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# 자전거번호      0
# 대여일시       0
# 대여대여소번호    0
# 대여대여소명     0
# 대여거치대      0
# 반납일시       0
# 반납대여소번호    0
# 반납대여소명     0
# 반납거치대      0
# 이용시간       0
# 이용거리       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3445871 entries, 0 to 3445870
# Data columns (total 11 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여일시     object
#  2   대여대여소번호  int64
#  3   대여대여소명   object
#  4   대여거치대    int64
#  5   반납일시     object
#  6   반납대여소번호  int64
#  7   반납대여소명   object
#  8   반납거치대    int64
#  9   이용시간     int64
#  10  이용거리     float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 289.2+ MB

# %%
df.describe()
# Out:
#             대여대여소번호         대여거치대       반납대여소번호         반납거치대          이용시간  \
# count  3.445871e+06  3.445871e+06  3.445871e+06  3.445871e+06  3.445871e+06
# mean   1.689628e+03  2.556263e+00  1.687082e+03  2.552268e+00  2.588709e+01
# std    1.246268e+03  1.569001e+01  1.240972e+03  1.567813e+01  2.828476e+01
# min    3.000000e+00  0.000000e+00  3.000000e+00  0.000000e+00  1.000000e+00
# 25%    6.740000e+02  0.000000e+00  6.800000e+02  0.000000e+00  8.000000e+00
# 50%    1.362000e+03  0.000000e+00  1.360000e+03  0.000000e+00  1.500000e+01
# 75%    2.408000e+03  0.000000e+00  2.389000e+03  0.000000e+00  3.500000e+01
# max    9.999900e+04  9.900000e+01  9.999900e+04  9.900000e+01  1.272000e+03
#
#                이용거리
# count  3.445871e+06
# mean   3.060081e+03
# std    3.728572e+03
# min    0.000000e+00
# 25%    8.878150e+02
# 50%    1.749740e+03
# 75%    3.677280e+03
# max    1.993206e+05

# %%
df = df.drop(['자전거번호', '대여대여소번호', '대여거치대', '반납대여소번호', '반납거치대', '이용시간', '이용거리'], axis = 1)
df
# Out:
#                         대여일시          대여대여소명                 반납일시  \
# 0        2021-05-31 23:07:00  화양 APT(횡단보도 옆)  2021-06-01 00:00:00
# 1        2021-05-31 23:37:19      구로디지털단지역 앞  2021-06-01 00:00:02
# 2        2021-05-31 23:48:40      건국대학교 정문 앞  2021-06-01 00:00:03
# 3        2021-05-31 23:47:52     사당역 12번출구 뒤  2021-06-01 00:00:05
# 4        2021-05-31 23:51:14       디지털입구 교차로  2021-06-01 00:00:08
# ...                      ...             ...                  ...
# 3445866  2021-06-30 22:44:14      마포구민체육센터 앞  2021-07-01 04:48:33
# 3445867  2021-06-30 22:45:19      마포구민체육센터 앞  2021-07-01 04:52:25
# 3445868  2021-06-30 22:43:43      마포구민체육센터 앞  2021-07-01 04:52:27
# 3445869  2021-06-30 22:11:14     반포본동 주민센터 앞  2021-07-01 04:55:29
# 3445870  2021-06-30 22:12:10     반포본동 주민센터 앞  2021-07-01 04:55:30
#
#                반납대여소명
# 0            서울숲 IT캐슬
# 1              독산고등학교
# 2        군자역 비채온 오피스텔
# 3              뒷벌공원 옆
# 4               모두의학교
# ...               ...
# 3445866      서강대 후문 옆
# 3445867      대흥역 1번출구
# 3445868      대흥역 1번출구
# 3445869      반포경남쇼핑 앞
# 3445870      반포경남쇼핑 앞
#
# [3445871 rows x 4 columns]

# %%
df['대여일시'] = pd.to_datetime(df['대여일시'])
df['반납일시'] = pd.to_datetime(df['반납일시'])

# %%
df['대여월'] = df['대여일시'].dt.month
df['대여일'] = df['대여일시'].dt.day
df['대여요일'] = df['대여일시'].dt.dayofweek
df['대여시간'] = df['대여일시'].dt.hour
df['대여시간_분'] = df['대여일시'].dt.minute

df['반납월'] = df['반납일시'].dt.month
df['반납일'] = df['반납일시'].dt.day
df['반납요일'] = df['반납일시'].dt.dayofweek
df['반납시간'] = df['반납일시'].dt.hour
df['반납시간_분'] = df['반납일시'].dt.minute

# %%
df = df.sort_values('대여일시', ignore_index = True)
df
# Out:
#                        대여일시        대여대여소명                반납일시  \
# 0       2021-05-31 18:39:50    신목동역 2번 출구 2021-06-01 00:10:23
# 1       2021-05-31 19:03:06    잠실새내역 1번출구 2021-06-01 00:27:39
# 2       2021-05-31 19:16:35      조원동서울본병원 2021-06-01 00:15:25
# 3       2021-05-31 19:17:35    혜화역 3번출구 뒤 2021-06-01 00:33:45
# 4       2021-05-31 19:21:39       뚝섬 유원지역 2021-06-01 00:03:39
# ...                     ...           ...                 ...
# 3445866 2021-06-30 23:56:16      노들역 1번출구 2021-07-01 00:03:17
# 3445867 2021-06-30 23:56:22      독립문역 사거리 2021-07-01 00:04:52
# 3445868 2021-06-30 23:56:22   한강트럼프월드3차 앞 2021-07-01 00:06:14
# 3445869 2021-06-30 23:58:26     대림아파트 사거리 2021-07-01 00:06:51
# 3445870 2021-06-30 23:58:42  천왕역 1번 출입구 앞 2021-07-01 00:15:37
#
#                    반납대여소명  대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  반납시간  \
# 0         목동아파트2단지 222동 앞    5   31     0    18      39    6    1     1     0
# 1        잠실본동주민센터뒤 잠실근린공원    5   31     0    19       3    6    1     1     0
# 2                 봉림교 교통섬    5   31     0    19      16    6    1     1     0
# 3              LG베스트샵 종암점    5   31     0    19      17    6    1     1     0
# 4           뚝섬유원지역 1번출구 앞    5   31     0    19      21    6    1     1     0
# ...                   ...  ...  ...   ...   ...     ...  ...  ...   ...   ...
# 3445866            사육신공원앞    6   30     2    23      56    7    1     3     0
# 3445867       독립문역 3-1번출구    6   30     2    23      56    7    1     3     0
# 3445868       한강트럼프월드3차 앞    6   30     2    23      56    7    1     3     0
# 3445869       신길삼거리(우리은행)    6   30     2    23      58    7    1     3     0
# 3445870        천왕차량사업소 입구    6   30     2    23      58    7    1     3     0
#
#          반납시간_분
# 0            10
# 1            27
# 2            15
# 3            33
# 4             3
# ...         ...
# 3445866       3
# 3445867       4
# 3445868       6
# 3445869       6
# 3445870      15
#
# [3445871 rows x 14 columns]

# %% [markdown]
# - 대여일시 기준으로 6월인 것부터 분석할 것이므로 대여월이 5인 것은 삭제

# %%
df = df[df['대여월'] != 5]
df = df[df['반납월'] != 7]
df
# Out:
#                        대여일시       대여대여소명                반납일시         반납대여소명  \
# 1342    2021-06-01 00:00:01   LG베스트샵 종암점 2021-06-01 00:15:20         용문2교 옆
# 1343    2021-06-01 00:00:01  영등포구청역 1번출구 2021-06-01 00:11:17      유원목동아파트 앞
# 1344    2021-06-01 00:00:02      서남병원 후문 2021-06-01 00:06:00      잣절보도육교 아래
# 1345    2021-06-01 00:00:06       안암2교 옆 2021-06-01 00:04:51      보문역6번출구 앞
# 1346    2021-06-01 00:00:06   한성대입구역2번출구 2021-06-01 00:23:20  상왕십리역 4번 출구 앞
# ...                     ...          ...                 ...            ...
# 3445569 2021-06-30 22:49:40   양평1 보행육교 앞 2021-06-30 22:53:15   양평동6차현대아파트 앞
# 3445602 2021-06-30 22:50:11   강변역 4번출구 뒤 2021-06-30 22:53:13      구의삼성쉐르빌 앞
# 3445621 2021-06-30 22:50:32       증산3교 앞 2021-06-30 22:52:57         증산3교 앞
# 3445726 2021-06-30 22:52:06       성북3교 위 2021-06-30 23:48:56         성북3교 위
# 3445827 2021-06-30 22:53:28       충북 미래관 2021-06-30 23:48:51         충북 미래관
#
#          대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  반납시간  반납시간_분
# 1342       6    1     1     0       0    6    1     1     0      15
# 1343       6    1     1     0       0    6    1     1     0      11
# 1344       6    1     1     0       0    6    1     1     0       6
# 1345       6    1     1     0       0    6    1     1     0       4
# 1346       6    1     1     0       0    6    1     1     0      23
# ...      ...  ...   ...   ...     ...  ...  ...   ...   ...     ...
# 3445569    6   30     2    22      49    6   30     2    22      53
# 3445602    6   30     2    22      50    6   30     2    22      53
# 3445621    6   30     2    22      50    6   30     2    22      52
# 3445726    6   30     2    22      52    6   30     2    23      48
# 3445827    6   30     2    22      53    6   30     2    23      48
#
# [3442056 rows x 14 columns]

# %%
df['대여대여소명'] = df['대여대여소명'].astype('category')
df['반납대여소명'] = df['반납대여소명'].astype('category')

# %% [markdown]
# ### 평균서비스율(10분당 자전거 대여수의 평균) = $\mu$
# - $\mu$ = 10이면 10분동안 평균 10대의 자전거 대여

# %%
df_rental = df[['대여일시', '대여대여소명', '대여월', '대여일', '대여요일', '대여시간', '대여시간_분']]
df_rental.reset_index(drop = True, inplace = True)
df_rental
# Out:
#                        대여일시       대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분
# 0       2021-06-01 00:00:01   LG베스트샵 종암점    6    1     1     0       0
# 1       2021-06-01 00:00:01  영등포구청역 1번출구    6    1     1     0       0
# 2       2021-06-01 00:00:02      서남병원 후문    6    1     1     0       0
# 3       2021-06-01 00:00:06       안암2교 옆    6    1     1     0       0
# 4       2021-06-01 00:00:06   한성대입구역2번출구    6    1     1     0       0
# ...                     ...          ...  ...  ...   ...   ...     ...
# 3442051 2021-06-30 22:49:40   양평1 보행육교 앞    6   30     2    22      49
# 3442052 2021-06-30 22:50:11   강변역 4번출구 뒤    6   30     2    22      50
# 3442053 2021-06-30 22:50:32       증산3교 앞    6   30     2    22      50
# 3442054 2021-06-30 22:52:06       성북3교 위    6   30     2    22      52
# 3442055 2021-06-30 22:53:28       충북 미래관    6   30     2    22      53
#
# [3442056 rows x 7 columns]

# %%
df_rental = df_rental[df_rental['대여대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
df_rental.reset_index(drop = True, inplace = True)
df_rental
# Out:
#                     대여일시             대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분
# 0    2021-06-01 00:33:11  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      33
# 1    2021-06-01 00:44:52  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      44
# 2    2021-06-01 00:50:57  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      50
# 3    2021-06-01 02:59:46  롯데월드타워(잠실역2번출구 쪽)    6    1     1     2      59
# 4    2021-06-01 04:30:58  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      30
# ...                  ...                ...  ...  ...   ...   ...     ...
# 9512 2021-06-30 21:45:06  롯데월드타워(잠실역2번출구 쪽)    6   30     2    21      45
# 9513 2021-06-30 22:02:31  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       2
# 9514 2021-06-30 22:08:56  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       8
# 9515 2021-06-30 22:11:04  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      11
# 9516 2021-06-30 22:12:23  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      12
#
# [9517 rows x 7 columns]

# %%
df_rental['unit_time'] = df_rental['대여시간_분'].apply(lambda x: x//10)
df_rental
# Out:
#                     대여일시             대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분  \
# 0    2021-06-01 00:33:11  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      33
# 1    2021-06-01 00:44:52  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      44
# 2    2021-06-01 00:50:57  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      50
# 3    2021-06-01 02:59:46  롯데월드타워(잠실역2번출구 쪽)    6    1     1     2      59
# 4    2021-06-01 04:30:58  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      30
# ...                  ...                ...  ...  ...   ...   ...     ...
# 9512 2021-06-30 21:45:06  롯데월드타워(잠실역2번출구 쪽)    6   30     2    21      45
# 9513 2021-06-30 22:02:31  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       2
# 9514 2021-06-30 22:08:56  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       8
# 9515 2021-06-30 22:11:04  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      11
# 9516 2021-06-30 22:12:23  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      12
#
#       unit_time
# 0             3
# 1             4
# 2             5
# 3             5
# 4             3
# ...         ...
# 9512          4
# 9513          0
# 9514          0
# 9515          1
# 9516          1
#
# [9517 rows x 8 columns]

# %%
df_rental['30time'] = -1

# %%
for i in range(len(df_rental)):
    
    if df_rental['unit_time'][i] == 0 or df_rental['unit_time'][i] == 1 or df_rental['unit_time'][i] == 2:
        df_rental['30time'][i] = 0
    else:
        df_rental['30time'][i] = 30    
df_rental
# Out:
#                     대여일시             대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분  \
# 0    2021-06-01 00:33:11  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      33
# 1    2021-06-01 00:44:52  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      44
# 2    2021-06-01 00:50:57  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      50
# 3    2021-06-01 02:59:46  롯데월드타워(잠실역2번출구 쪽)    6    1     1     2      59
# 4    2021-06-01 04:30:58  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      30
# ...                  ...                ...  ...  ...   ...   ...     ...
# 9512 2021-06-30 21:45:06  롯데월드타워(잠실역2번출구 쪽)    6   30     2    21      45
# 9513 2021-06-30 22:02:31  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       2
# 9514 2021-06-30 22:08:56  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       8
# 9515 2021-06-30 22:11:04  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      11
# 9516 2021-06-30 22:12:23  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      12
#
#       unit_time  30time
# 0             3      30
# 1             4      30
# 2             5      30
# 3             5      30
# 4             3      30
# ...         ...     ...
# 9512          4      30
# 9513          0       0
# 9514          0       0
# 9515          1       0
# 9516          1       0
#
# [9517 rows x 9 columns]

# %%
df_rental = pd.DataFrame(df_rental.groupby(['대여일', '대여시간', '30time']).size()).sort_index()
df_rental
# Out:
#                   0
# 대여일 대여시간 30time
# 1   0    30       3
#     2    30       1
#     4    30       1
#     5    0        1
#     6    30       1
# ...              ..
# 30  20   0       14
#          30       3
#     21   0       11
#          30       4
#     22   0        4
#
# [1074 rows x 1 columns]

# %%
df_rental.reset_index(inplace = True)
df_rental
# Out:
#       대여일  대여시간  30time   0
# 0       1     0      30   3
# 1       1     2      30   1
# 2       1     4      30   1
# 3       1     5       0   1
# 4       1     6      30   1
# ...   ...   ...     ...  ..
# 1069   30    20       0  14
# 1070   30    20      30   3
# 1071   30    21       0  11
# 1072   30    21      30   4
# 1073   30    22       0   4
#
# [1074 rows x 4 columns]

# %%
df_rental = df_rental.rename(columns = {0 : 'count'})
df_rental
# Out:
#       대여일  대여시간  30time  count
# 0       1     0      30      3
# 1       1     2      30      1
# 2       1     4      30      1
# 3       1     5       0      1
# 4       1     6      30      1
# ...   ...   ...     ...    ...
# 1069   30    20       0     14
# 1070   30    20      30      3
# 1071   30    21       0     11
# 1072   30    21      30      4
# 1073   30    22       0      4
#
# [1074 rows x 4 columns]

# %% [markdown]
# 30time칼럼에서 0은 0분-30분, 30은 30분-00분

# %%
df_rental['mu_10'] = df_rental['count'] / 3
df_rental
# Out:
#       대여일  대여시간  30time  count     mu_10
# 0       1     0      30      3  1.000000
# 1       1     2      30      1  0.333333
# 2       1     4      30      1  0.333333
# 3       1     5       0      1  0.333333
# 4       1     6      30      1  0.333333
# ...   ...   ...     ...    ...       ...
# 1069   30    20       0     14  4.666667
# 1070   30    20      30      3  1.000000
# 1071   30    21       0     11  3.666667
# 1072   30    21      30      4  1.333333
# 1073   30    22       0      4  1.333333
#
# [1074 rows x 5 columns]

# %%
df_rental.drop(['count'], axis = 1, inplace = True)

# %%
df_rental
# Out:
#       대여일  대여시간  30time     mu_10
# 0       1     0      30  1.000000
# 1       1     2      30  0.333333
# 2       1     4      30  0.333333
# 3       1     5       0  0.333333
# 4       1     6      30  0.333333
# ...   ...   ...     ...       ...
# 1069   30    20       0  4.666667
# 1070   30    20      30  1.000000
# 1071   30    21       0  3.666667
# 1072   30    21      30  1.333333
# 1073   30    22       0  1.333333
#
# [1074 rows x 4 columns]

# %% [markdown]
# - 즉, 평균서비스율 뮤는 위와 같다
# - 위 표를 보면 1일 0시 30분~59분의 뮤는 1
# - 1일 2시 30분~59분의 뮤는 0.3333
# - 30일 21시 0분~30분의 뮤는 3.666667
# - 30일 21시 30분~59분의 뮤는 1.33333

# %% [markdown]
# ### 평균도착률(10분당 자전거 반납수의 평균) = $\lambda$
# - $\lambda$ = 10이면 10분동안 평균 10대의 자전거를 반납

# %%
df_return = df[['반납일시', '반납대여소명', '반납월', '반납일', '반납요일', '반납시간', '반납시간_분']]
df_return
# Out:
#                        반납일시         반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분
# 1342    2021-06-01 00:15:20         용문2교 옆    6    1     1     0      15
# 1343    2021-06-01 00:11:17      유원목동아파트 앞    6    1     1     0      11
# 1344    2021-06-01 00:06:00      잣절보도육교 아래    6    1     1     0       6
# 1345    2021-06-01 00:04:51      보문역6번출구 앞    6    1     1     0       4
# 1346    2021-06-01 00:23:20  상왕십리역 4번 출구 앞    6    1     1     0      23
# ...                     ...            ...  ...  ...   ...   ...     ...
# 3445569 2021-06-30 22:53:15   양평동6차현대아파트 앞    6   30     2    22      53
# 3445602 2021-06-30 22:53:13      구의삼성쉐르빌 앞    6   30     2    22      53
# 3445621 2021-06-30 22:52:57         증산3교 앞    6   30     2    22      52
# 3445726 2021-06-30 23:48:56         성북3교 위    6   30     2    23      48
# 3445827 2021-06-30 23:48:51         충북 미래관    6   30     2    23      48
#
# [3442056 rows x 7 columns]

# %%
df_return = df_return[df_return['반납대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
df_return.reset_index(drop = True, inplace = True)
df_return
# Out:
#                     반납일시             반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분
# 0    2021-06-01 00:13:16  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      13
# 1    2021-06-01 00:36:29  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      36
# 2    2021-06-01 01:38:07  롯데월드타워(잠실역2번출구 쪽)    6    1     1     1      38
# 3    2021-06-01 04:29:38  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      29
# 4    2021-06-01 04:39:19  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      39
# ...                  ...                ...  ...  ...   ...   ...     ...
# 9514 2021-06-30 22:05:26  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       5
# 9515 2021-06-30 22:11:58  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      11
# 9516 2021-06-30 22:10:35  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      10
# 9517 2021-06-30 22:49:46  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      49
# 9518 2021-06-30 22:52:11  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      52
#
# [9519 rows x 7 columns]

# %%
df_return['unit_time'] = df_return['반납시간_분'].apply(lambda x: x//10)
df_return
# Out:
#                     반납일시             반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분  \
# 0    2021-06-01 00:13:16  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      13
# 1    2021-06-01 00:36:29  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      36
# 2    2021-06-01 01:38:07  롯데월드타워(잠실역2번출구 쪽)    6    1     1     1      38
# 3    2021-06-01 04:29:38  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      29
# 4    2021-06-01 04:39:19  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      39
# ...                  ...                ...  ...  ...   ...   ...     ...
# 9514 2021-06-30 22:05:26  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       5
# 9515 2021-06-30 22:11:58  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      11
# 9516 2021-06-30 22:10:35  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      10
# 9517 2021-06-30 22:49:46  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      49
# 9518 2021-06-30 22:52:11  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      52
#
#       unit_time
# 0             1
# 1             3
# 2             3
# 3             2
# 4             3
# ...         ...
# 9514          0
# 9515          1
# 9516          1
# 9517          4
# 9518          5
#
# [9519 rows x 8 columns]

# %%
df_return['30time'] = -1

# %%
for i in range(len(df_return)):
    
    if df_return['unit_time'][i] == 0 or df_return['unit_time'][i] == 1 or df_return['unit_time'][i] == 2:
        df_return['30time'][i] = 0
    else:
        df_return['30time'][i] = 30    
df_return
# Out:
#                     반납일시             반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분  \
# 0    2021-06-01 00:13:16  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      13
# 1    2021-06-01 00:36:29  롯데월드타워(잠실역2번출구 쪽)    6    1     1     0      36
# 2    2021-06-01 01:38:07  롯데월드타워(잠실역2번출구 쪽)    6    1     1     1      38
# 3    2021-06-01 04:29:38  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      29
# 4    2021-06-01 04:39:19  롯데월드타워(잠실역2번출구 쪽)    6    1     1     4      39
# ...                  ...                ...  ...  ...   ...   ...     ...
# 9514 2021-06-30 22:05:26  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22       5
# 9515 2021-06-30 22:11:58  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      11
# 9516 2021-06-30 22:10:35  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      10
# 9517 2021-06-30 22:49:46  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      49
# 9518 2021-06-30 22:52:11  롯데월드타워(잠실역2번출구 쪽)    6   30     2    22      52
#
#       unit_time  30time
# 0             1       0
# 1             3      30
# 2             3      30
# 3             2       0
# 4             3      30
# ...         ...     ...
# 9514          0       0
# 9515          1       0
# 9516          1       0
# 9517          4      30
# 9518          5      30
#
# [9519 rows x 9 columns]

# %%
df_return = pd.DataFrame(df_return.groupby(['반납일', '반납시간', '30time']).size()).sort_index()
df_return
# Out:
#                   0
# 반납일 반납시간 30time
# 1   0    0        1
#          30       1
#     1    30       1
#     4    0        1
#          30       1
# ...              ..
# 30  20   30       3
#     21   0       11
#          30       4
#     22   0        4
#          30       2
#
# [1104 rows x 1 columns]

# %%
df_return.reset_index(inplace = True)
df_return
# Out:
#       반납일  반납시간  30time   0
# 0       1     0       0   1
# 1       1     0      30   1
# 2       1     1      30   1
# 3       1     4       0   1
# 4       1     4      30   1
# ...   ...   ...     ...  ..
# 1099   30    20      30   3
# 1100   30    21       0  11
# 1101   30    21      30   4
# 1102   30    22       0   4
# 1103   30    22      30   2
#
# [1104 rows x 4 columns]

# %%
df_return = df_return.rename(columns = {0 : 'count'})
df_return
# Out:
#       반납일  반납시간  30time  count
# 0       1     0       0      1
# 1       1     0      30      1
# 2       1     1      30      1
# 3       1     4       0      1
# 4       1     4      30      1
# ...   ...   ...     ...    ...
# 1099   30    20      30      3
# 1100   30    21       0     11
# 1101   30    21      30      4
# 1102   30    22       0      4
# 1103   30    22      30      2
#
# [1104 rows x 4 columns]

# %% [markdown]
# 30time칼럼에서 0은 0분-30분, 30은 30분-00분

# %%
df_return['lambda_10'] = df_return['count'] / 3
df_return
# Out:
#       반납일  반납시간  30time  count  lambda_10
# 0       1     0       0      1   0.333333
# 1       1     0      30      1   0.333333
# 2       1     1      30      1   0.333333
# 3       1     4       0      1   0.333333
# 4       1     4      30      1   0.333333
# ...   ...   ...     ...    ...        ...
# 1099   30    20      30      3   1.000000
# 1100   30    21       0     11   3.666667
# 1101   30    21      30      4   1.333333
# 1102   30    22       0      4   1.333333
# 1103   30    22      30      2   0.666667
#
# [1104 rows x 5 columns]

# %%
df_return.drop(['count'], axis = 1, inplace = True)
df_return
# Out:
#       반납일  반납시간  30time  lambda_10
# 0       1     0       0   0.333333
# 1       1     0      30   0.333333
# 2       1     1      30   0.333333
# 3       1     4       0   0.333333
# 4       1     4      30   0.333333
# ...   ...   ...     ...        ...
# 1099   30    20      30   1.000000
# 1100   30    21       0   3.666667
# 1101   30    21      30   1.333333
# 1102   30    22       0   1.333333
# 1103   30    22      30   0.666667
#
# [1104 rows x 4 columns]

# %% [markdown]
# - 평균도착률 람다는 위 표와 같음
# - 즉, 1일 0시 0분~30분의 람다는 0.333333
# - 30일 22시 0분 ~ 30분의 람다는 1.333333
# - 30일 22시 30분~59분의 람다는 0.666667

# %% [markdown]
# ### 가용도(고객이 station에 도착했을 때 자전거가 station에 있을 확률)
# $1 - (1 - \frac{\lambda}{\mu})(\frac{\lambda}{\mu})^0$ = $\frac{\lambda}{\mu}$

# %%
df_rental = df_rental.rename(columns = {'대여일':'day', '대여시간':'hour', '30time':'minute'})
df_rental
# Out:
#       day  hour  minute     mu_10
# 0       1     0      30  1.000000
# 1       1     2      30  0.333333
# 2       1     4      30  0.333333
# 3       1     5       0  0.333333
# 4       1     6      30  0.333333
# ...   ...   ...     ...       ...
# 1069   30    20       0  4.666667
# 1070   30    20      30  1.000000
# 1071   30    21       0  3.666667
# 1072   30    21      30  1.333333
# 1073   30    22       0  1.333333
#
# [1074 rows x 4 columns]

# %%
df_return = df_return.rename(columns = {'반납일':'day', '반납시간':'hour', '30time':'minute'})
df_return
# Out:
#       day  hour  minute  lambda_10
# 0       1     0       0   0.333333
# 1       1     0      30   0.333333
# 2       1     1      30   0.333333
# 3       1     4       0   0.333333
# 4       1     4      30   0.333333
# ...   ...   ...     ...        ...
# 1099   30    20      30   1.000000
# 1100   30    21       0   3.666667
# 1101   30    21      30   1.333333
# 1102   30    22       0   1.333333
# 1103   30    22      30   0.666667
#
# [1104 rows x 4 columns]

# %%
result = pd.merge(df_return, df_rental, how = 'left')
result
# Out:
#       day  hour  minute  lambda_10     mu_10
# 0       1     0       0   0.333333       NaN
# 1       1     0      30   0.333333  1.000000
# 2       1     1      30   0.333333       NaN
# 3       1     4       0   0.333333       NaN
# 4       1     4      30   0.333333  0.333333
# ...   ...   ...     ...        ...       ...
# 1099   30    20      30   1.000000  1.000000
# 1100   30    21       0   3.666667  3.666667
# 1101   30    21      30   1.333333  1.333333
# 1102   30    22       0   1.333333  1.333333
# 1103   30    22      30   0.666667       NaN
#
# [1104 rows x 5 columns]

# %%
result['가용도'] = result['lambda_10'] / result['mu_10']
result
# Out:
#       day  hour  minute  lambda_10     mu_10       가용도
# 0       1     0       0   0.333333       NaN       NaN
# 1       1     0      30   0.333333  1.000000  0.333333
# 2       1     1      30   0.333333       NaN       NaN
# 3       1     4       0   0.333333       NaN       NaN
# 4       1     4      30   0.333333  0.333333  1.000000
# ...   ...   ...     ...        ...       ...       ...
# 1099   30    20      30   1.000000  1.000000  1.000000
# 1100   30    21       0   3.666667  3.666667  1.000000
# 1101   30    21      30   1.333333  1.333333  1.000000
# 1102   30    22       0   1.333333  1.333333  1.000000
# 1103   30    22      30   0.666667       NaN       NaN
#
# [1104 rows x 6 columns]

# %% [markdown]
# ### 초과수요율(excess demand rate)

# %%
df_rental
# Out:
#       day  hour  minute     mu_10
# 0       1     0      30  1.000000
# 1       1     2      30  0.333333
# 2       1     4      30  0.333333
# 3       1     5       0  0.333333
# 4       1     6      30  0.333333
# ...   ...   ...     ...       ...
# 1069   30    20       0  4.666667
# 1070   30    20      30  1.000000
# 1071   30    21       0  3.666667
# 1072   30    21      30  1.333333
# 1073   30    22       0  1.333333
#
# [1074 rows x 4 columns]

# %%
answer = df_rental
answer
# Out:
#       day  hour  minute     mu_10
# 0       1     0      30  1.000000
# 1       1     2      30  0.333333
# 2       1     4      30  0.333333
# 3       1     5       0  0.333333
# 4       1     6      30  0.333333
# ...   ...   ...     ...       ...
# 1069   30    20       0  4.666667
# 1070   30    20      30  1.000000
# 1071   30    21       0  3.666667
# 1072   30    21      30  1.333333
# 1073   30    22       0  1.333333
#
# [1074 rows x 4 columns]

# %%
answer = answer.set_index(['day', 'hour', 'minute'])
answer
# Out:
#                     mu_10
# day hour minute
# 1   0    30      1.000000
#     2    30      0.333333
#     4    30      0.333333
#     5    0       0.333333
#     6    30      0.333333
# ...                   ...
# 30  20   0       4.666667
#          30      1.000000
#     21   0       3.666667
#          30      1.333333
#     22   0       1.333333
#
# [1074 rows x 1 columns]

# %%
mux = pd.MultiIndex.from_product([answer.index.levels[0], answer.index.levels[1], answer.index.levels[2]],names=['day','hour', 'minute'])
mux
# Out:
# MultiIndex([( 1,  0,  0),
#             ( 1,  0, 30),
#             ( 1,  1,  0),
#             ( 1,  1, 30),
#             ( 1,  2,  0),
#             ( 1,  2, 30),
#             ( 1,  3,  0),
#             ( 1,  3, 30),
#             ( 1,  4,  0),
#             ( 1,  4, 30),
#             ...
#             (30, 19,  0),
#             (30, 19, 30),
#             (30, 20,  0),
#             (30, 20, 30),
#             (30, 21,  0),
#             (30, 21, 30),
#             (30, 22,  0),
#             (30, 22, 30),
#             (30, 23,  0),
#             (30, 23, 30)],
#            names=['day', 'hour', 'minute'], length=1440)

# %%
answer = answer.reindex(mux, fill_value=0).reset_index()
answer
# Out:
#       day  hour  minute     mu_10
# 0       1     0       0  0.000000
# 1       1     0      30  1.000000
# 2       1     1       0  0.000000
# 3       1     1      30  0.000000
# 4       1     2       0  0.000000
# ...   ...   ...     ...       ...
# 1435   30    21      30  1.333333
# 1436   30    22       0  1.333333
# 1437   30    22      30  0.000000
# 1438   30    23       0  0.000000
# 1439   30    23      30  0.000000
#
# [1440 rows x 4 columns]

# %%
answer['obs'] = -1.0
answer
# Out:
#       day  hour  minute     mu_10  obs  prior
# 0       1     0       0  0.000000 -1.0    0.0
# 1       1     0      30  1.000000 -1.0    0.0
# 2       1     1       0  0.000000 -1.0    0.0
# 3       1     1      30  0.000000 -1.0    0.0
# 4       1     2       0  0.000000 -1.0    0.0
# ...   ...   ...     ...       ...  ...    ...
# 1435   30    21      30  1.333333 -1.0    0.0
# 1436   30    22       0  1.333333 -1.0    0.0
# 1437   30    22      30  0.000000 -1.0    0.0
# 1438   30    23       0  0.000000 -1.0    0.0
# 1439   30    23      30  0.000000 -1.0    0.0
#
# [1440 rows x 6 columns]

# %%
for i in range(1, len(answer) - 1):
    answer['obs'][i] = (answer['mu_10'][i-1]+answer['mu_10'][i]+answer['mu_10'][i+1]) / 3
answer
# Out:
#       day  hour  minute     mu_10       obs  prior
# 0       1     0       0  0.000000 -1.000000   -1.0
# 1       1     0      30  1.000000  0.333333   -1.0
# 2       1     1       0  0.000000  0.333333   -1.0
# 3       1     1      30  0.000000  0.000000   -1.0
# 4       1     2       0  0.000000  0.111111   -1.0
# ...   ...   ...     ...       ...       ...    ...
# 1435   30    21      30  1.333333  2.111111   -1.0
# 1436   30    22       0  1.333333  0.888889   -1.0
# 1437   30    22      30  0.000000  0.444444   -1.0
# 1438   30    23       0  0.000000  0.000000   -1.0
# 1439   30    23      30  0.000000 -1.000000   -1.0
#
# [1440 rows x 6 columns]

# %%
answer['prior'] = -1.0
answer
# Out:
#       day  hour  minute     mu_10       obs  prior
# 0       1     0       0  0.000000 -1.000000   -1.0
# 1       1     0      30  1.000000  0.333333   -1.0
# 2       1     1       0  0.000000  0.333333   -1.0
# 3       1     1      30  0.000000  0.000000   -1.0
# 4       1     2       0  0.000000  0.111111   -1.0
# ...   ...   ...     ...       ...       ...    ...
# 1435   30    21      30  1.333333  2.111111   -1.0
# 1436   30    22       0  1.333333  0.888889   -1.0
# 1437   30    22      30  0.000000  0.444444   -1.0
# 1438   30    23       0  0.000000  0.000000   -1.0
# 1439   30    23      30  0.000000 -1.000000   -1.0
#
# [1440 rows x 6 columns]

# %%
for i in range(289, len(answer)):
    answer['prior'][i] = (answer['mu_10'][i-289] + answer['mu_10'][i-288] + answer['mu_10'][i-287]
                          +answer['mu_10'][i-241] + answer['mu_10'][i-240] + answer['mu_10'][i-239]
                         + answer['mu_10'][i-193] + answer['mu_10'][i-192] + answer['mu_10'][i-191]
                         + answer['mu_10'][i-145] + answer['mu_10'][i-144] + answer['mu_10'][i-143]
                         + answer['mu_10'][i-97] + answer['mu_10'][i-96] + answer['mu_10'][i-95]
                         + answer['mu_10'][i-49] + answer['mu_10'][i-48] + answer['mu_10'][i-47]) / 18
answer
# Out:
#       day  hour  minute     mu_10       obs     prior
# 0       1     0       0  0.000000 -1.000000 -1.000000
# 1       1     0      30  1.000000  0.333333 -1.000000
# 2       1     1       0  0.000000  0.333333 -1.000000
# 3       1     1      30  0.000000  0.000000 -1.000000
# 4       1     2       0  0.000000  0.111111 -1.000000
# ...   ...   ...     ...       ...       ...       ...
# 1435   30    21      30  1.333333  2.111111  2.425926
# 1436   30    22       0  1.333333  0.888889  1.907407
# 1437   30    22      30  0.000000  0.444444  1.537037
# 1438   30    23       0  0.000000  0.000000  1.129630
# 1439   30    23      30  0.000000 -1.000000  0.703704
#
# [1440 rows x 6 columns]

# %%
answer = answer[answer['obs'] != -1]
answer = answer[answer['prior'] != -1]
answer
# Out:
#       day  hour  minute     mu_10       obs     prior
# 289     7     0      30  0.000000  0.000000  0.314815
# 290     7     1       0  0.000000  0.000000  0.185185
# 291     7     1      30  0.000000  0.000000  0.148148
# 292     7     2       0  0.000000  0.111111  0.092593
# 293     7     2      30  0.333333  0.111111  0.092593
# ...   ...   ...     ...       ...       ...       ...
# 1434   30    21       0  3.666667  2.000000  2.907407
# 1435   30    21      30  1.333333  2.111111  2.425926
# 1436   30    22       0  1.333333  0.888889  1.907407
# 1437   30    22      30  0.000000  0.444444  1.537037
# 1438   30    23       0  0.000000  0.000000  1.129630
#
# [1150 rows x 6 columns]

# %%
answer['excess_demand'] = (3 * answer['obs'] + 18 * answer['prior']) / 21
answer
# Out:
#       day  hour  minute     mu_10       obs     prior  excess_demand
# 289     7     0      30  0.000000  0.000000  0.314815       0.269841
# 290     7     1       0  0.000000  0.000000  0.185185       0.158730
# 291     7     1      30  0.000000  0.000000  0.148148       0.126984
# 292     7     2       0  0.000000  0.111111  0.092593       0.095238
# 293     7     2      30  0.333333  0.111111  0.092593       0.095238
# ...   ...   ...     ...       ...       ...       ...            ...
# 1434   30    21       0  3.666667  2.000000  2.907407       2.777778
# 1435   30    21      30  1.333333  2.111111  2.425926       2.380952
# 1436   30    22       0  1.333333  0.888889  1.907407       1.761905
# 1437   30    22      30  0.000000  0.444444  1.537037       1.380952
# 1438   30    23       0  0.000000  0.000000  1.129630       0.968254
#
# [1150 rows x 7 columns]

# %%
plt.style.use('bmh')

# %%
answer_7 = answer[answer['day'] == 7]
answer_7
# Out:
#      day  hour  minute      mu_10        obs     prior  excess_demand
# 289    7     0      30   0.000000   0.000000  0.314815       0.269841
# 290    7     1       0   0.000000   0.000000  0.185185       0.158730
# 291    7     1      30   0.000000   0.000000  0.148148       0.126984
# 292    7     2       0   0.000000   0.111111  0.092593       0.095238
# 293    7     2      30   0.333333   0.111111  0.092593       0.095238
# 294    7     3       0   0.000000   0.111111  0.092593       0.095238
# 295    7     3      30   0.000000   0.111111  0.092593       0.095238
# 296    7     4       0   0.333333   0.111111  0.074074       0.079365
# 297    7     4      30   0.000000   0.111111  0.074074       0.079365
# 298    7     5       0   0.000000   0.000000  0.055556       0.047619
# 299    7     5      30   0.000000   0.000000  0.055556       0.047619
# 300    7     6       0   0.000000   0.111111  0.203704       0.190476
# 301    7     6      30   0.333333   0.333333  0.314815       0.317460
# 302    7     7       0   0.666667   0.888889  0.759259       0.777778
# 303    7     7      30   1.666667   1.555556  1.185185       1.238095
# 304    7     8       0   2.333333   3.333333  2.203704       2.365079
# 305    7     8      30   6.000000   3.444444  2.092593       2.285714
# 306    7     9       0   2.000000   3.333333  2.018519       2.206349
# 307    7     9      30   2.000000   1.777778  1.370370       1.428571
# 308    7    10       0   1.333333   1.555556  1.481481       1.492063
# 309    7    10      30   1.333333   1.000000  1.407407       1.349206
# 310    7    11       0   0.333333   1.222222  1.592593       1.539683
# 311    7    11      30   2.000000   1.000000  1.907407       1.777778
# 312    7    12       0   0.666667   1.000000  2.351852       2.158730
# 313    7    12      30   0.333333   0.444444  2.444444       2.158730
# 314    7    13       0   0.333333   0.666667  2.333333       2.095238
# 315    7    13      30   1.333333   1.444444  2.333333       2.206349
# 316    7    14       0   2.666667   1.555556  2.703704       2.539683
# 317    7    14      30   0.666667   1.777778  3.481481       3.238095
# 318    7    15       0   2.000000   2.222222  4.074074       3.809524
# 319    7    15      30   4.000000   3.000000  4.111111       3.952381
# 320    7    16       0   3.000000   3.000000  3.925926       3.793651
# 321    7    16      30   2.000000   3.444444  4.185185       4.079365
# 322    7    17       0   5.333333   4.222222  5.000000       4.888889
# 323    7    17      30   5.333333   8.555556  6.574074       6.857143
# 324    7    18       0  15.000000  11.000000  7.814815       8.269841
# 325    7    18      30  12.666667  11.111111  7.537037       8.047619
# 326    7    19       0   5.666667   7.333333  5.907407       6.111111
# 327    7    19      30   3.666667   4.222222  4.537037       4.492063
# 328    7    20       0   3.333333   3.222222  4.018519       3.904762
# 329    7    20      30   2.666667   2.111111  3.555556       3.349206
# 330    7    21       0   0.333333   2.555556  2.740741       2.714286
# 331    7    21      30   4.666667   2.111111  2.074074       2.079365
# 332    7    22       0   1.333333   2.777778  1.833333       1.968254
# 333    7    22      30   2.333333   1.666667  1.055556       1.142857
# 334    7    23       0   1.333333   1.333333  0.703704       0.793651
# 335    7    23      30   0.333333   0.555556  0.370370       0.396825

# %%
answer_7.plot(kind = 'bar', y = 'excess_demand', figsize = (24, 10), 
            title = '2021년 6월 7일 롯데월드타워(잠실역2번출구 쪽) 대여소 초과수요율')
plt.show()

# %% [markdown]
# - 7일 초과수요율을 살펴보면 오전 7시 30분부터 초과수요율이 1보다 높게 나옴
# - 특히 18시에는 초과수요율이 최대에 달함

# %%
answer.plot(kind = 'bar', y = 'excess_demand', figsize = (24, 10), 
            title = '2021년 6월 롯데월드타워(잠실역2번출구 쪽) 대여소 초과수요율')
plt.show()

# %% [markdown]
# - 6월 전체 초과수요율을 살펴보면 일정한 패턴이 있음을 알 수 있음
# - 하루를 기준으로 출근시간부터 초과수요율이 높아지다가 퇴근시간 이후로 줄어듦
