# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'NanumGothic'

# %%
df1 = pd.read_csv('./data/서울특별시 공공자전거 대여정보_201906_1.csv', engine = 'python')
df1
# Out:
#             자전거번호                 대여일시  대여대여소번호             대여대여소명  대여거치대  \
# 0       SPB-22040  2019-06-03 08:49:27      646  장한평역 1번출구 (국민은행앞)      1
# 1       SPB-07446  2019-06-03 08:33:22      526           용답토속공원 앞      8
# 2       SPB-20387  2019-06-05 08:27:47      646  장한평역 1번출구 (국민은행앞)      1
# 3       SPB-16794  2019-06-05 08:46:29      646  장한평역 1번출구 (국민은행앞)      6
# 4       SPB-18266  2019-06-10 08:27:26      529       장한평역 8번 출구 앞     10
# ...           ...                  ...      ...                ...    ...
# 799955  SPB-22522  2019-06-01 17:47:47      726      목동3단지 시내버스정류장      6
# 799956  SPB-01434  2019-06-01 17:49:18      735             영도초등학교      1
# 799957  SPB-18503  2019-06-01 17:48:02      735             영도초등학교      8
# 799958  SPB-19656  2019-06-01 18:55:01      762        오목로 무중력지대 앞      1
# 799959  SPB-10785  2019-06-01 19:12:48     1136             등촌2파출소     10
#
#                        반납일시  반납대여소번호  반납대여소명  반납거치대  이용시간    이용거리
# 0       2019-06-03 09:17:10        3    중랑센터     14    27  1330.0
# 1       2019-06-03 09:27:16        3    중랑센터     14    54  1180.0
# 2       2019-06-05 08:41:31        3    중랑센터      2    12  1930.0
# 3       2019-06-05 08:53:10        3    중랑센터     14     6  1340.0
# 4       2019-06-10 08:33:40        3    중랑센터      2     5  1230.0
# ...                     ...      ...     ...    ...   ...     ...
# 799955  2019-06-01 18:44:20      735  영도초등학교      5    52  2020.0
# 799956  2019-06-01 18:55:01      735  영도초등학교      2    65  7990.0
# 799957  2019-06-01 18:55:29      735  영도초등학교      4    66  7910.0
# 799958  2019-06-01 19:08:12      735  영도초등학교     10    13  2120.0
# 799959  2019-06-01 19:23:10      735  영도초등학교     10    10  1620.0
#
# [799960 rows x 11 columns]

# %%
df2 = pd.read_csv('./data/서울특별시 공공자전거 대여정보_201906_2.csv', engine = 'python')
df2
# Out:
#             자전거번호                 대여일시  대여대여소번호        대여대여소명  대여거치대  \
# 0       SPB-18282  2019-06-01 21:15:39      764      목동청소년수련관      7
# 1       SPB-06551  2019-06-01 21:28:21      703   오목교역 7번출구 앞      1
# 2       SPB-22632  2019-06-01 21:29:30      704   남부법원검찰청 교차로      3
# 3       SPB-08605  2019-06-01 21:38:13      731  서울시 도로환경관리센터     10
# 4       SPB-01650  2019-06-01 21:39:16      731  서울시 도로환경관리센터     10
# ...           ...                  ...      ...           ...    ...
# 799946  SPB-06091  2019-06-23 19:31:21     1673      노원역?5번출구      9
# 799947  SPB-12632  2019-06-23 19:31:48     1655      공릉1단지아파트      1
# 799948  SPB-10323  2019-06-23 18:57:37     1692      온곡초교 교차로      4
# 799949  SPB-09319  2019-06-23 19:53:33     1625     상계역(4번출구)      5
# 799950  SPB-02986  2019-06-23 20:17:40     1720  도봉구청 옆(중랑천변)      2
#
#                        반납일시  반납대여소번호    반납대여소명  반납거치대  이용시간     이용거리
# 0       2019-06-01 21:22:20      735    영도초등학교      9     6      0.0
# 1       2019-06-01 21:40:41      735    영도초등학교      9    11   2210.0
# 2       2019-06-01 21:40:51      735    영도초등학교      7    10   1870.0
# 3       2019-06-01 21:51:27      735    영도초등학교      9    12   1480.0
# 4       2019-06-01 21:55:53      735    영도초등학교      8    16   1500.0
# ...                     ...      ...       ...    ...   ...      ...
# 799946  2019-06-23 19:43:33     1692  온곡초교 교차로      7    11   1530.0
# 799947  2019-06-23 19:57:31     1692  온곡초교 교차로      3    23   4900.0
# 799948  2019-06-23 19:57:32     1692  온곡초교 교차로      5    57  12510.0
# 799949  2019-06-23 19:59:35     1692  온곡초교 교차로      1     6    880.0
# 799950  2019-06-23 20:31:11     1692  온곡초교 교차로      9    13   2640.0
#
# [799951 rows x 11 columns]

# %%
df3 = pd.read_csv('./data/서울특별시 공공자전거 대여정보_201906_3.csv', engine = 'python')
df3
# Out:
#             자전거번호                 대여일시  대여대여소번호               대여대여소명  대여거치대  \
# 0       SPB-15349  2019-06-23 20:52:11     1625            상계역(4번출구)      4
# 1       SPB-09319  2019-06-23 20:44:41     1692             온곡초교 교차로      1
# 2       SPB-13041  2019-06-23 20:51:23     1619  중계동 하나프라자빌딩 앞(중1-1)      6
# 3       SPB-18582  2019-06-23 21:43:26     1674            서울북부고용센터앞     15
# 4       SPB-00104  2019-06-23 21:45:17     1674            서울북부고용센터앞      5
# ...           ...                  ...      ...                  ...    ...
# 615716  SPB-22438  2019-06-24 07:40:39      240           문래역 4번출구 앞      8
# 615717  SPB-24455  2019-06-25 07:34:58      240           문래역 4번출구 앞      7
# 615718  SPB-24557  2019-06-26 08:19:57      240           문래역 4번출구 앞      4
# 615719  SPB-00649  2019-06-27 07:38:12      240           문래역 4번출구 앞      9
# 615720  SPB-14209  2019-06-28 07:37:07      240           문래역 4번출구 앞     10
#
#                        반납일시  반납대여소번호      반납대여소명  반납거치대  이용시간    이용거리
# 0       2019-06-23 20:58:08     1692    온곡초교 교차로      6     5   870.0
# 1       2019-06-23 20:58:34     1692    온곡초교 교차로      8    14  2420.0
# 2       2019-06-23 21:11:33     1692    온곡초교 교차로      5    18  2420.0
# 3       2019-06-23 22:13:20     1692    온곡초교 교차로      5    28  3110.0
# 4       2019-06-23 22:13:27     1692    온곡초교 교차로     10    27  3120.0
# ...                     ...      ...         ...    ...   ...     ...
# 615716  2019-06-24 07:54:16     9998  영남주차장 정비센터     10    13   900.0
# 615717  2019-06-25 07:42:14     9998  영남주차장 정비센터      4     6   880.0
# 615718  2019-06-26 08:27:49     9998  영남주차장 정비센터     10     7   930.0
# 615719  2019-06-27 07:49:52     9998  영남주차장 정비센터     10    11  1030.0
# 615720  2019-06-28 07:43:54     9998  영남주차장 정비센터     10     6  1010.0
#
# [615721 rows x 11 columns]

# %%
df = df1.append(df2, ignore_index = True)
df
# Out:
#              자전거번호                 대여일시  대여대여소번호             대여대여소명  대여거치대  \
# 0        SPB-22040  2019-06-03 08:49:27      646  장한평역 1번출구 (국민은행앞)      1
# 1        SPB-07446  2019-06-03 08:33:22      526           용답토속공원 앞      8
# 2        SPB-20387  2019-06-05 08:27:47      646  장한평역 1번출구 (국민은행앞)      1
# 3        SPB-16794  2019-06-05 08:46:29      646  장한평역 1번출구 (국민은행앞)      6
# 4        SPB-18266  2019-06-10 08:27:26      529       장한평역 8번 출구 앞     10
# ...            ...                  ...      ...                ...    ...
# 1599906  SPB-06091  2019-06-23 19:31:21     1673           노원역?5번출구      9
# 1599907  SPB-12632  2019-06-23 19:31:48     1655           공릉1단지아파트      1
# 1599908  SPB-10323  2019-06-23 18:57:37     1692           온곡초교 교차로      4
# 1599909  SPB-09319  2019-06-23 19:53:33     1625          상계역(4번출구)      5
# 1599910  SPB-02986  2019-06-23 20:17:40     1720       도봉구청 옆(중랑천변)      2
#
#                         반납일시  반납대여소번호    반납대여소명  반납거치대  이용시간     이용거리
# 0        2019-06-03 09:17:10        3      중랑센터     14    27   1330.0
# 1        2019-06-03 09:27:16        3      중랑센터     14    54   1180.0
# 2        2019-06-05 08:41:31        3      중랑센터      2    12   1930.0
# 3        2019-06-05 08:53:10        3      중랑센터     14     6   1340.0
# 4        2019-06-10 08:33:40        3      중랑센터      2     5   1230.0
# ...                      ...      ...       ...    ...   ...      ...
# 1599906  2019-06-23 19:43:33     1692  온곡초교 교차로      7    11   1530.0
# 1599907  2019-06-23 19:57:31     1692  온곡초교 교차로      3    23   4900.0
# 1599908  2019-06-23 19:57:32     1692  온곡초교 교차로      5    57  12510.0
# 1599909  2019-06-23 19:59:35     1692  온곡초교 교차로      1     6    880.0
# 1599910  2019-06-23 20:31:11     1692  온곡초교 교차로      9    13   2640.0
#
# [1599911 rows x 11 columns]

# %%
df = df.append(df3, ignore_index = True)
df
# Out:
#              자전거번호                 대여일시  대여대여소번호             대여대여소명  대여거치대  \
# 0        SPB-22040  2019-06-03 08:49:27      646  장한평역 1번출구 (국민은행앞)      1
# 1        SPB-07446  2019-06-03 08:33:22      526           용답토속공원 앞      8
# 2        SPB-20387  2019-06-05 08:27:47      646  장한평역 1번출구 (국민은행앞)      1
# 3        SPB-16794  2019-06-05 08:46:29      646  장한평역 1번출구 (국민은행앞)      6
# 4        SPB-18266  2019-06-10 08:27:26      529       장한평역 8번 출구 앞     10
# ...            ...                  ...      ...                ...    ...
# 2215627  SPB-22438  2019-06-24 07:40:39      240         문래역 4번출구 앞      8
# 2215628  SPB-24455  2019-06-25 07:34:58      240         문래역 4번출구 앞      7
# 2215629  SPB-24557  2019-06-26 08:19:57      240         문래역 4번출구 앞      4
# 2215630  SPB-00649  2019-06-27 07:38:12      240         문래역 4번출구 앞      9
# 2215631  SPB-14209  2019-06-28 07:37:07      240         문래역 4번출구 앞     10
#
#                         반납일시  반납대여소번호      반납대여소명  반납거치대  이용시간    이용거리
# 0        2019-06-03 09:17:10        3        중랑센터     14    27  1330.0
# 1        2019-06-03 09:27:16        3        중랑센터     14    54  1180.0
# 2        2019-06-05 08:41:31        3        중랑센터      2    12  1930.0
# 3        2019-06-05 08:53:10        3        중랑센터     14     6  1340.0
# 4        2019-06-10 08:33:40        3        중랑센터      2     5  1230.0
# ...                      ...      ...         ...    ...   ...     ...
# 2215627  2019-06-24 07:54:16     9998  영남주차장 정비센터     10    13   900.0
# 2215628  2019-06-25 07:42:14     9998  영남주차장 정비센터      4     6   880.0
# 2215629  2019-06-26 08:27:49     9998  영남주차장 정비센터     10     7   930.0
# 2215630  2019-06-27 07:49:52     9998  영남주차장 정비센터     10    11  1030.0
# 2215631  2019-06-28 07:43:54     9998  영남주차장 정비센터     10     6  1010.0
#
# [2215632 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# 자전거번호      0
# 대여일시       0
# 대여대여소번호    0
# 대여대여소명     0
# 대여거치대      0
# 반납일시       0
# 반납대여소번호    0
# 반납대여소명     0
# 반납거치대      0
# 이용시간       0
# 이용거리       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215632 entries, 0 to 2215631
# Data columns (total 11 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여일시     object
#  2   대여대여소번호  int64
#  3   대여대여소명   object
#  4   대여거치대    int64
#  5   반납일시     object
#  6   반납대여소번호  int64
#  7   반납대여소명   object
#  8   반납거치대    int64
#  9   이용시간     int64
#  10  이용거리     float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 185.9+ MB

# %%
df.describe()
# Out:
#             대여대여소번호         대여거치대       반납대여소번호         반납거치대          이용시간  \
# count  2.215632e+06  2.215632e+06  2.215632e+06  2.215632e+06  2.215632e+06
# mean   1.226154e+03  7.014750e+00  1.228354e+03  6.967391e+00  2.716998e+01
# std    8.499197e+02  5.244626e+00  8.462296e+02  5.238154e+00  2.908119e+01
# min    3.000000e+00  1.000000e+00  3.000000e+00  1.000000e+00  1.000000e+00
# 25%    5.050000e+02  3.000000e+00  5.120000e+02  3.000000e+00  8.000000e+00
# 50%    1.159000e+03  6.000000e+00  1.159000e+03  6.000000e+00  1.700000e+01
# 75%    1.846000e+03  1.000000e+01  1.839000e+03  1.000000e+01  3.700000e+01
# max    9.998000e+03  4.000000e+01  9.998000e+03  4.000000e+01  3.133000e+03
#
#                이용거리
# count  2.215632e+06
# mean   3.912916e+03
# std    5.145471e+03
# min    0.000000e+00
# 25%    1.220000e+03
# 50%    2.270000e+03
# 75%    4.670000e+03
# max    2.323100e+05

# %%
df = df.drop(['자전거번호', '대여대여소번호', '대여거치대', '반납대여소번호', '반납거치대', '이용시간', '이용거리'], axis = 1)
df
# Out:
#                         대여일시             대여대여소명                 반납일시  \
# 0        2019-06-03 08:49:27  장한평역 1번출구 (국민은행앞)  2019-06-03 09:17:10
# 1        2019-06-03 08:33:22           용답토속공원 앞  2019-06-03 09:27:16
# 2        2019-06-05 08:27:47  장한평역 1번출구 (국민은행앞)  2019-06-05 08:41:31
# 3        2019-06-05 08:46:29  장한평역 1번출구 (국민은행앞)  2019-06-05 08:53:10
# 4        2019-06-10 08:27:26       장한평역 8번 출구 앞  2019-06-10 08:33:40
# ...                      ...                ...                  ...
# 2215627  2019-06-24 07:40:39         문래역 4번출구 앞  2019-06-24 07:54:16
# 2215628  2019-06-25 07:34:58         문래역 4번출구 앞  2019-06-25 07:42:14
# 2215629  2019-06-26 08:19:57         문래역 4번출구 앞  2019-06-26 08:27:49
# 2215630  2019-06-27 07:38:12         문래역 4번출구 앞  2019-06-27 07:49:52
# 2215631  2019-06-28 07:37:07         문래역 4번출구 앞  2019-06-28 07:43:54
#
#              반납대여소명
# 0              중랑센터
# 1              중랑센터
# 2              중랑센터
# 3              중랑센터
# 4              중랑센터
# ...             ...
# 2215627  영남주차장 정비센터
# 2215628  영남주차장 정비센터
# 2215629  영남주차장 정비센터
# 2215630  영남주차장 정비센터
# 2215631  영남주차장 정비센터
#
# [2215632 rows x 4 columns]

# %%
df['대여일시'] = pd.to_datetime(df['대여일시'])
df['반납일시'] = pd.to_datetime(df['반납일시'])

# %%
df['대여월'] = df['대여일시'].dt.month
df['대여일'] = df['대여일시'].dt.day
df['대여요일'] = df['대여일시'].dt.dayofweek
df['대여시간'] = df['대여일시'].dt.hour
df['대여시간_분'] = df['대여일시'].dt.minute

df['반납월'] = df['반납일시'].dt.month
df['반납일'] = df['반납일시'].dt.day
df['반납요일'] = df['반납일시'].dt.dayofweek
df['반납시간'] = df['반납일시'].dt.hour
df['반납시간_분'] = df['반납일시'].dt.minute

# %%
df = df.sort_values('대여일시', ignore_index = True)
df
# Out:
#                        대여일시                   대여대여소명                반납일시  \
# 0       2019-06-01 00:00:02  신도림4차 e편한세상 아파트 1109동 앞 2019-06-01 00:41:19
# 1       2019-06-01 00:00:08             국민은행 종암동지점 앞 2019-06-01 00:15:36
# 2       2019-06-01 00:00:09                     증산2교 2019-06-01 00:36:49
# 3       2019-06-01 00:00:09                  봉림교 교통섬 2019-06-01 00:22:39
# 4       2019-06-01 00:00:09               쌍문역4번출구 주변 2019-06-01 00:20:11
# ...                     ...                      ...                 ...
# 2215627 2019-06-30 23:59:51             국민은행 종암동지점 앞 2019-07-01 00:09:38
# 2215628 2019-06-30 23:59:54                   커먼그라운드 2019-07-01 00:26:47
# 2215629 2019-06-30 23:59:55                 송파구청 교차로 2019-07-01 00:12:15
# 2215630 2019-06-30 23:59:56                    중랑세무서 2019-07-01 00:23:52
# 2215631 2019-06-30 23:59:56                다이소 삼양시장점 2019-07-01 00:13:42
#
#                    반납대여소명  대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  반납시간  \
# 0                    동방1교    6    1     5     0       0    6    1     5     0
# 1               보문역6번출구 앞    6    1     5     0       0    6    1     5     0
# 2        연신내역 5번출구150M 아래    6    1     5     0       0    6    1     5     0
# 3                 도림천 신화교    6    1     5     0       0    6    1     5     0
# 4                미아동 복합청사    6    1     5     0       0    6    1     5     0
# ...                   ...  ...  ...   ...   ...     ...  ...  ...   ...   ...
# 2215627         KEB은행 고대점    6   30     6    23      59    7    1     0     0
# 2215628         하나은행 면목지점    6   30     6    23      59    7    1     0     0
# 2215629           삼표레미콘 앞    6   30     6    23      59    7    1     0     0
# 2215630          코스트코 상봉점    6   30     6    23      59    7    1     0     0
# 2215631          효성인텔리안 앞    6   30     6    23      59    7    1     0     0
#
#          반납시간_분
# 0            41
# 1            15
# 2            36
# 3            22
# 4            20
# ...         ...
# 2215627       9
# 2215628      26
# 2215629      12
# 2215630      23
# 2215631      13
#
# [2215632 rows x 14 columns]

# %%
df = df[df['대여월'] != 5]
df = df[df['반납월'] != 7]
df
# Out:
#                        대여일시                   대여대여소명                반납일시  \
# 0       2019-06-01 00:00:02  신도림4차 e편한세상 아파트 1109동 앞 2019-06-01 00:41:19
# 1       2019-06-01 00:00:08             국민은행 종암동지점 앞 2019-06-01 00:15:36
# 2       2019-06-01 00:00:09                     증산2교 2019-06-01 00:36:49
# 3       2019-06-01 00:00:09                  봉림교 교통섬 2019-06-01 00:22:39
# 4       2019-06-01 00:00:09               쌍문역4번출구 주변 2019-06-01 00:20:11
# ...                     ...                      ...                 ...
# 2215306 2019-06-30 23:53:26                   삼양사거리역 2019-06-30 23:59:16
# 2215351 2019-06-30 23:54:31              당산역 10번출구 앞 2019-06-30 23:58:02
# 2215354 2019-06-30 23:54:33              당산역 10번출구 앞 2019-06-30 23:58:02
# 2215413 2019-06-30 23:55:58                 세종사이버대학교 2019-06-30 23:58:58
# 2215478 2019-06-30 23:57:15                방학동학마을도서관 2019-06-30 23:59:51
#
#                    반납대여소명  대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  반납시간  \
# 0                    동방1교    6    1     5     0       0    6    1     5     0
# 1               보문역6번출구 앞    6    1     5     0       0    6    1     5     0
# 2        연신내역 5번출구150M 아래    6    1     5     0       0    6    1     5     0
# 3                 도림천 신화교    6    1     5     0       0    6    1     5     0
# 4                미아동 복합청사    6    1     5     0       0    6    1     5     0
# ...                   ...  ...  ...   ...   ...     ...  ...  ...   ...   ...
# 2215306         수유1동 주민센터    6   30     6    23      53    6   30     6    23
# 2215351        영등포삼환아파트 앞    6   30     6    23      54    6   30     6    23
# 2215354        영등포삼환아파트 앞    6   30     6    23      54    6   30     6    23
# 2215413         군자역 7번출구뒤    6   30     6    23      55    6   30     6    23
# 2215478         방학동학마을도서관    6   30     6    23      57    6   30     6    23
#
#          반납시간_분
# 0            41
# 1            15
# 2            36
# 3            22
# 4            20
# ...         ...
# 2215306      59
# 2215351      58
# 2215354      58
# 2215413      58
# 2215478      59
#
# [2214148 rows x 14 columns]

# %%
df['대여대여소명'] = df['대여대여소명'].astype('category')
df['반납대여소명'] = df['반납대여소명'].astype('category')

# %% [markdown]
# ### 평균서비스율(10분당 자전거 대여수의 평균) = $\mu$
# - $\mu$ = 10이면 10분동안 평균 10대의 자전거 대여

# %%
df_rental = df[['대여일시', '대여대여소명', '대여월', '대여일', '대여요일', '대여시간', '대여시간_분']]
df_rental.reset_index(drop = True, inplace = True)
df_rental
# Out:
#                        대여일시                   대여대여소명  대여월  대여일  대여요일  대여시간  \
# 0       2019-06-01 00:00:02  신도림4차 e편한세상 아파트 1109동 앞    6    1     5     0
# 1       2019-06-01 00:00:08             국민은행 종암동지점 앞    6    1     5     0
# 2       2019-06-01 00:00:09                     증산2교    6    1     5     0
# 3       2019-06-01 00:00:09                  봉림교 교통섬    6    1     5     0
# 4       2019-06-01 00:00:09               쌍문역4번출구 주변    6    1     5     0
# ...                     ...                      ...  ...  ...   ...   ...
# 2214143 2019-06-30 23:53:26                   삼양사거리역    6   30     6    23
# 2214144 2019-06-30 23:54:31              당산역 10번출구 앞    6   30     6    23
# 2214145 2019-06-30 23:54:33              당산역 10번출구 앞    6   30     6    23
# 2214146 2019-06-30 23:55:58                 세종사이버대학교    6   30     6    23
# 2214147 2019-06-30 23:57:15                방학동학마을도서관    6   30     6    23
#
#          대여시간_분
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2214143      53
# 2214144      54
# 2214145      54
# 2214146      55
# 2214147      57
#
# [2214148 rows x 7 columns]

# %%
df_rental = df_rental[df_rental['대여대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
df_rental.reset_index(drop = True, inplace = True)
df_rental
# Out:
#                     대여일시             대여대여소명  대여월  대여일  대여요일  대여시간  대여시간_분
# 0    2019-06-01 00:02:35  롯데월드타워(잠실역2번출구 쪽)    6    1     5     0       2
# 1    2019-06-01 00:09:05  롯데월드타워(잠실역2번출구 쪽)    6    1     5     0       9
# 2    2019-06-01 01:19:52  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      19
# 3    2019-06-01 01:25:47  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      25
# 4    2019-06-01 01:43:05  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      43
# ...                  ...                ...  ...  ...   ...   ...     ...
# 8606 2019-06-30 23:08:28  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23       8
# 8607 2019-06-30 23:14:02  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      14
# 8608 2019-06-30 23:14:51  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      14
# 8609 2019-06-30 23:28:27  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      28
# 8610 2019-06-30 23:40:21  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      40
#
# [8611 rows x 7 columns]

# %% [markdown]
# #### 0시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 0]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     24
# 1         10     15
# 2         20     21
# 3         30     16
# 4         40      9
# 5         50     27

# %%
# 10분당 평균 대여율 = 평균서비스율

mu0 = df_rental_hour_group['count'].sum() / 6
mu0
# Out:
# 18.666666666666668

# %% [markdown]
# #### 1시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 1]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      7
# 1         10      9
# 2         20     11
# 3         30     12
# 4         40     10
# 5         50     11

# %%
# 1시 10분당 평균 대여율 = 평균서비스율

mu1 = df_rental_hour_group['count'].sum() / 6
mu1
# Out:
# 10.0

# %% [markdown]
# #### 2시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 2]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      5
# 1         10      3
# 2         20      5
# 3         30      8
# 4         40      4
# 5         50      2

# %%
# 2시 10분당 평균 대여율 = 평균서비스율

mu2 = df_rental_hour_group['count'].sum() / 6
mu2
# Out:
# 4.5

# %% [markdown]
# #### 3시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 3]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      4
# 1         10      3
# 2         20      3
# 3         30      4
# 4         40      6
# 5         50      4

# %%
# 10분당 평균 대여율 = 평균서비스율

mu3 = df_rental_hour_group['count'].sum() / 6
mu3
# Out:
# 4.0

# %% [markdown]
# #### 4시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 4]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      6
# 1         10      2
# 2         20      3
# 3         30      6
# 4         40      4

# %%
# 10분당 평균 대여율 = 평균서비스율

mu4 = df_rental_hour_group['count'].sum() / 6
mu4
# Out:
# 3.5

# %% [markdown]
# #### 5시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 5]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      2
# 1         10      4
# 2         20      5
# 3         30      5
# 4         40      4
# 5         50      7

# %%
# 10분당 평균 대여율 = 평균서비스율

mu5 = df_rental_hour_group['count'].sum() / 6
mu5
# Out:
# 4.5

# %% [markdown]
# #### 6시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 6]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      4
# 1         10      6
# 2         20     12
# 3         30     10
# 4         40      3
# 5         50      8

# %%
# 10분당 평균 대여율 = 평균서비스율

mu6 = df_rental_hour_group['count'].sum() / 6
mu6
# Out:
# 7.166666666666667

# %% [markdown]
# #### 7시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 7]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0      4
# 1         10     16
# 2         20     25
# 3         30     16
# 4         40     29
# 5         50     40

# %%
# 10분당 평균 대여율 = 평균서비스율

mu7 = df_rental_hour_group['count'].sum() / 6
mu7
# Out:
# 21.666666666666668

# %% [markdown]
# #### 8시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 8]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     50
# 1         10     31
# 2         20     31
# 3         30     43
# 4         40     73
# 5         50     58

# %%
# 10분당 평균 대여율 = 평균서비스율

mu8 = df_rental_hour_group['count'].sum() / 6
mu8
# Out:
# 47.666666666666664

# %% [markdown]
# #### 9시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 9]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     32
# 1         10     27
# 2         20     20
# 3         30     31
# 4         40     52
# 5         50     39

# %%
# 10분당 평균 대여율 = 평균서비스율

mu9 = df_rental_hour_group['count'].sum() / 6
mu9
# Out:
# 33.5

# %% [markdown]
# #### 10시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 10]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     17
# 1         10      9
# 2         20     16
# 3         30     27
# 4         40     31
# 5         50     25

# %%
# 10분당 평균 대여율 = 평균서비스율

mu10 = df_rental_hour_group['count'].sum() / 6
mu10
# Out:
# 20.833333333333332

# %% [markdown]
# #### 11시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 11]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     28
# 1         10     35
# 2         20     25
# 3         30     50
# 4         40     50
# 5         50     42

# %%
# 10분당 평균 대여율 = 평균서비스율

mu11 = df_rental_hour_group['count'].sum() / 6
mu11
# Out:
# 38.333333333333336

# %% [markdown]
# #### 12시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 12]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     37
# 1         10     39
# 2         20     49
# 3         30     46
# 4         40     59
# 5         50     61

# %%
# 10분당 평균 대여율 = 평균서비스율

mu12 = df_rental_hour_group['count'].sum() / 6
mu12
# Out:
# 48.5

# %% [markdown]
# #### 13시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 13]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     66
# 1         10     60
# 2         20     53
# 3         30     77
# 4         40     88
# 5         50     66

# %%
# 10분당 평균 대여율 = 평균서비스율

mu13 = df_rental_hour_group['count'].sum() / 6
mu13
# Out:
# 68.33333333333333

# %% [markdown]
# #### 14시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 14]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     81
# 1         10     79
# 2         20     83
# 3         30     80
# 4         40     87
# 5         50    113

# %%
# 10분당 평균 대여율 = 평균서비스율

mu14 = df_rental_hour_group['count'].sum() / 6
mu14
# Out:
# 87.16666666666667

# %% [markdown]
# #### 15시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 15]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     92
# 1         10    114
# 2         20    101
# 3         30    124
# 4         40    113
# 5         50     83

# %%
# 10분당 평균 대여율 = 평균서비스율

mu15 = df_rental_hour_group['count'].sum() / 6
mu15
# Out:
# 104.5

# %% [markdown]
# #### 16시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 16]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    131
# 1         10    115
# 2         20    121
# 3         30    114
# 4         40    113
# 5         50    126

# %%
# 10분당 평균 대여율 = 평균서비스율

mu16 = df_rental_hour_group['count'].sum() / 6
mu16
# Out:
# 120.0

# %% [markdown]
# #### 17시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 17]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    114
# 1         10    122
# 2         20    132
# 3         30    178
# 4         40    135
# 5         50    164

# %%
# 10분당 평균 대여율 = 평균서비스율

mu17 = df_rental_hour_group['count'].sum() / 6
mu17
# Out:
# 140.83333333333334

# %% [markdown]
# #### 18시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 18]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    207
# 1         10    334
# 2         20    282
# 3         30    241
# 4         40    204
# 5         50    193

# %%
# 10분당 평균 대여율 = 평균서비스율

mu18 = df_rental_hour_group['count'].sum() / 6
mu18
# Out:
# 243.5

# %% [markdown]
# #### 19시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 19]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    221
# 1         10    120
# 2         20    122
# 3         30    142
# 4         40    118
# 5         50    100

# %%
# 10분당 평균 대여율 = 평균서비스율

mu19 = df_rental_hour_group['count'].sum() / 6
mu19
# Out:
# 137.16666666666666

# %% [markdown]
# #### 20시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 20]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0    112
# 1         10     93
# 2         20    101
# 3         30    100
# 4         40     91
# 5         50    102

# %%
# 10분당 평균 대여율 = 평균서비스율

mu20 = df_rental_hour_group['count'].sum() / 6
mu20
# Out:
# 99.83333333333333

# %% [markdown]
# #### 21시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 21]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     78
# 1         10     78
# 2         20     67
# 3         30     64
# 4         40     58
# 5         50     65

# %%
# 10분당 평균 대여율 = 평균서비스율

mu21 = df_rental_hour_group['count'].sum() / 6
mu21
# Out:
# 68.33333333333333

# %% [markdown]
# #### 22시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 22]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     75
# 1         10     69
# 2         20     52
# 3         30     61
# 4         40     52
# 5         50     57

# %%
# 10분당 평균 대여율 = 평균서비스율

mu22 = df_rental_hour_group['count'].sum() / 6
mu22
# Out:
# 61.0

# %% [markdown]
# #### 23시

# %%
df_rental_hour = df_rental[df_rental['대여시간'] == 23]
df_rental_hour.reset_index(drop = True, inplace = True)
df_rental_hour['대여시간_분_그룹'] = -1
for i in range(len(df_rental_hour)):
    if df_rental_hour['대여시간_분'][i] >= 50:
        df_rental_hour['대여시간_분_그룹'][i] = 50
    elif df_rental_hour['대여시간_분'][i] >= 40:
        df_rental_hour['대여시간_분_그룹'][i] = 40
    elif df_rental_hour['대여시간_분'][i] >= 30:
        df_rental_hour['대여시간_분_그룹'][i] = 30
    elif df_rental_hour['대여시간_분'][i] >= 20:
        df_rental_hour['대여시간_분_그룹'][i] = 20
    elif df_rental_hour['대여시간_분'][i] >= 10:
        df_rental_hour['대여시간_분_그룹'][i] = 10
    else:
        df_rental_hour['대여시간_분_그룹'][i] = 0
df_rental_hour_group = df_rental_hour.groupby('대여시간_분_그룹')[['대여시간_분']].count().reset_index()
df_rental_hour_group.rename(columns = {'대여시간_분' : 'count'}, inplace = True)
df_rental_hour_group
# Out:
#    대여시간_분_그룹  count
# 0          0     49
# 1         10     41
# 2         20     54
# 3         30     37
# 4         40     43
# 5         50     26

# %%
# 10분당 평균 대여율 = 평균서비스율

mu23 = df_rental_hour_group['count'].sum() / 6
mu23
# Out:
# 41.666666666666664

# %% [markdown]
# - 2019년 6월 한달동안의 롯데월드타워(잠실역2번출구 쪽) 대여소의 평균서비스율 뮤(10분당 평균 대여수)는

# %%
a = [mu0, mu1, mu2, mu3, mu4, mu5, mu6, mu7, mu8, mu9, mu10, mu11, mu12, mu13, mu14, mu15, mu16, mu17, mu18, mu19, mu20, mu21, mu22, mu23]
time = ['0시', '1시', '2시', '3시', '4시', '5시', '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시',
       '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시']

result = pd.DataFrame(time)
result.columns = ['time']
result['mu'] = a
result
# Out:
#    time          mu
# 0    0시   18.666667
# 1    1시   10.000000
# 2    2시    4.500000
# 3    3시    4.000000
# 4    4시    3.500000
# 5    5시    4.500000
# 6    6시    7.166667
# 7    7시   21.666667
# 8    8시   47.666667
# 9    9시   33.500000
# 10  10시   20.833333
# 11  11시   38.333333
# 12  12시   48.500000
# 13  13시   68.333333
# 14  14시   87.166667
# 15  15시  104.500000
# 16  16시  120.000000
# 17  17시  140.833333
# 18  18시  243.500000
# 19  19시  137.166667
# 20  20시   99.833333
# 21  21시   68.333333
# 22  22시   61.000000
# 23  23시   41.666667

# %% [markdown]
# ### 평균도착률(10분당 자전거 반납수의 평균) = $\lambda$
# - $\lambda$ = 10이면 10분동안 평균 10대의 자전거를 반납

# %%
df_return = df[['반납일시', '반납대여소명', '반납월', '반납일', '반납요일', '반납시간', '반납시간_분']]
df_return
# Out:
#                        반납일시            반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분
# 0       2019-06-01 00:41:19              동방1교    6    1     5     0      41
# 1       2019-06-01 00:15:36         보문역6번출구 앞    6    1     5     0      15
# 2       2019-06-01 00:36:49  연신내역 5번출구150M 아래    6    1     5     0      36
# 3       2019-06-01 00:22:39           도림천 신화교    6    1     5     0      22
# 4       2019-06-01 00:20:11          미아동 복합청사    6    1     5     0      20
# ...                     ...               ...  ...  ...   ...   ...     ...
# 2215306 2019-06-30 23:59:16         수유1동 주민센터    6   30     6    23      59
# 2215351 2019-06-30 23:58:02        영등포삼환아파트 앞    6   30     6    23      58
# 2215354 2019-06-30 23:58:02        영등포삼환아파트 앞    6   30     6    23      58
# 2215413 2019-06-30 23:58:58         군자역 7번출구뒤    6   30     6    23      58
# 2215478 2019-06-30 23:59:51         방학동학마을도서관    6   30     6    23      59
#
# [2214148 rows x 7 columns]

# %%
df_return = df_return[df_return['반납대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
df_return
# Out:
#                        반납일시             반납대여소명  반납월  반납일  반납요일  반납시간  반납시간_분
# 2107    2019-06-01 01:15:46  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      15
# 2865    2019-06-01 01:13:23  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      13
# 3968    2019-06-01 01:56:56  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      56
# 4167    2019-06-01 01:37:53  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      37
# 4333    2019-06-01 01:41:29  롯데월드타워(잠실역2번출구 쪽)    6    1     5     1      41
# ...                     ...                ...  ...  ...   ...   ...     ...
# 2211608 2019-06-30 23:06:54  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23       6
# 2213327 2019-06-30 23:25:24  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      25
# 2213515 2019-06-30 23:49:48  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      49
# 2213596 2019-06-30 23:49:41  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      49
# 2214061 2019-06-30 23:37:40  롯데월드타워(잠실역2번출구 쪽)    6   30     6    23      37
#
# [8636 rows x 7 columns]

# %% [markdown]
# #### 0시

# %%
df_return_hour = df_return[df_return['반납시간'] == 0]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     23
# 1         10     18
# 2         20     18
# 3         30     18
# 4         40     21
# 5         50     15

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda0 = df_return_hour_group['count'].sum() / 6
lda0
# Out:
# 18.833333333333332

# %% [markdown]
# #### 1시

# %%
df_return_hour = df_return[df_return['반납시간'] == 1]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      7
# 1         10     15
# 2         20     17
# 3         30      3
# 4         40      9
# 5         50      5

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda1 = df_return_hour_group['count'].sum() / 6
lda1
# Out:
# 9.333333333333334

# %% [markdown]
# #### 2시

# %%
df_return_hour = df_return[df_return['반납시간'] == 2]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      3
# 1         10      4
# 2         20      2
# 3         30      3
# 4         40      2

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda2 = df_return_hour_group['count'].sum() / 6
lda2
# Out:
# 2.3333333333333335

# %% [markdown]
# #### 3시

# %%
df_return_hour = df_return[df_return['반납시간'] == 3]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      3
# 1         10      2
# 2         20      2
# 3         30      4
# 4         40      3
# 5         50      2

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda3 = df_return_hour_group['count'].sum() / 6
lda3
# Out:
# 2.6666666666666665

# %% [markdown]
# #### 4시

# %%
df_return_hour = df_return[df_return['반납시간'] == 4]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0         10      5
# 1         20     20
# 2         30      3
# 3         40      5
# 4         50      1

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda4 = df_return_hour_group['count'].sum() / 6
lda4
# Out:
# 5.666666666666667

# %% [markdown]
# #### 5시

# %%
df_return_hour = df_return[df_return['반납시간'] == 5]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      6
# 1         10     17
# 2         20      5
# 3         30      5
# 4         40      3
# 5         50     10

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda5 = df_return_hour_group['count'].sum() / 6
lda5
# Out:
# 7.666666666666667

# %% [markdown]
# #### 6시

# %%
df_return_hour = df_return[df_return['반납시간'] == 6]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0      5
# 1         10      3
# 2         20      8
# 3         30     11
# 4         40     21
# 5         50     15

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda6 = df_return_hour_group['count'].sum() / 6
lda6
# Out:
# 10.5

# %% [markdown]
# #### 7시

# %%
df_return_hour = df_return[df_return['반납시간'] == 7]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     21
# 1         10     53
# 2         20     34
# 3         30     40
# 4         40     90
# 5         50    120

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda7 = df_return_hour_group['count'].sum() / 6
lda7
# Out:
# 59.666666666666664

# %% [markdown]
# #### 8시

# %%
df_return_hour = df_return[df_return['반납시간'] == 8]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     85
# 1         10     81
# 2         20    106
# 3         30    108
# 4         40    157
# 5         50     95

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda8 = df_return_hour_group['count'].sum() / 6
lda8
# Out:
# 105.33333333333333

# %% [markdown]
# #### 9시

# %%
df_return_hour = df_return[df_return['반납시간'] == 9]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     52
# 1         10     80
# 2         20     95
# 3         30     48
# 4         40     76
# 5         50     48

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda9 = df_return_hour_group['count'].sum() / 6
lda9
# Out:
# 66.5

# %% [markdown]
# #### 10시

# %%
df_return_hour = df_return[df_return['반납시간'] == 10]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     37
# 1         10     48
# 2         20     47
# 3         30     55
# 4         40     56
# 5         50     54

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda10 = df_return_hour_group['count'].sum() / 6
lda10
# Out:
# 49.5

# %% [markdown]
# #### 11시

# %%
df_return_hour = df_return[df_return['반납시간'] == 11]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     65
# 1         10     65
# 2         20     59
# 3         30     54
# 4         40     60
# 5         50     65

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda11 = df_return_hour_group['count'].sum() / 6
lda11
# Out:
# 61.333333333333336

# %% [markdown]
# #### 12시

# %%
df_return_hour = df_return[df_return['반납시간'] == 12]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     55
# 1         10     57
# 2         20     66
# 3         30     58
# 4         40     82
# 5         50     56

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda12 = df_return_hour_group['count'].sum() / 6
lda12
# Out:
# 62.333333333333336

# %% [markdown]
# #### 13시

# %%
df_return_hour = df_return[df_return['반납시간'] == 13]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     66
# 1         10     75
# 2         20     94
# 3         30     77
# 4         40     59
# 5         50     83

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda13 = df_return_hour_group['count'].sum() / 6
lda13
# Out:
# 75.66666666666667

# %% [markdown]
# #### 14시

# %%
df_return_hour = df_return[df_return['반납시간'] == 14]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     69
# 1         10     87
# 2         20     96
# 3         30     76
# 4         40     82
# 5         50     67

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda14 = df_return_hour_group['count'].sum() / 6
lda14
# Out:
# 79.5

# %% [markdown]
# #### 15시

# %%
df_return_hour = df_return[df_return['반납시간'] == 15]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     73
# 1         10     68
# 2         20    111
# 3         30     74
# 4         40     86
# 5         50     70

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda15 = df_return_hour_group['count'].sum() / 6
lda15
# Out:
# 80.33333333333333

# %% [markdown]
# #### 16시

# %%
df_return_hour = df_return[df_return['반납시간'] == 16]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     93
# 1         10     80
# 2         20    113
# 3         30     74
# 4         40     87
# 5         50    103

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda16 = df_return_hour_group['count'].sum() / 6
lda16
# Out:
# 91.66666666666667

# %% [markdown]
# #### 17시

# %%
df_return_hour = df_return[df_return['반납시간'] == 17]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    105
# 1         10    118
# 2         20    101
# 3         30    111
# 4         40    139
# 5         50    112

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda17 = df_return_hour_group['count'].sum() / 6
lda17
# Out:
# 114.33333333333333

# %% [markdown]
# #### 18시

# %%
df_return_hour = df_return[df_return['반납시간'] == 18]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    110
# 1         10    146
# 2         20    168
# 3         30    136
# 4         40    148
# 5         50    174

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda18 = df_return_hour_group['count'].sum() / 6
lda18
# Out:
# 147.0

# %% [markdown]
# #### 19시

# %%
df_return_hour = df_return[df_return['반납시간'] == 19]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    161
# 1         10    101
# 2         20    136
# 3         30    124
# 4         40    122
# 5         50    105

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda19 = df_return_hour_group['count'].sum() / 6
lda19
# Out:
# 124.83333333333333

# %% [markdown]
# #### 20시

# %%
df_return_hour = df_return[df_return['반납시간'] == 20]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0    105
# 1         10     91
# 2         20    106
# 3         30     89
# 4         40     92
# 5         50    103

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda20 = df_return_hour_group['count'].sum() / 6
lda20
# Out:
# 97.66666666666667

# %% [markdown]
# #### 21시

# %%
df_return_hour = df_return[df_return['반납시간'] == 21]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     69
# 1         10     72
# 2         20     73
# 3         30     69
# 4         40     52
# 5         50     69

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda21 = df_return_hour_group['count'].sum() / 6
lda21
# Out:
# 67.33333333333333

# %% [markdown]
# #### 22시

# %%
df_return_hour = df_return[df_return['반납시간'] == 22]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     79
# 1         10     59
# 2         20     65
# 3         30     48
# 4         40     64
# 5         50     48

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda22 = df_return_hour_group['count'].sum() / 6
lda22
# Out:
# 60.5

# %% [markdown]
# #### 23시

# %%
df_return_hour = df_return[df_return['반납시간'] == 23]
df_return_hour.reset_index(drop = True, inplace = True)
df_return_hour['반납시간_분_그룹'] = -1
for i in range(len(df_return_hour)):
    if df_return_hour['반납시간_분'][i] >= 50:
        df_return_hour['반납시간_분_그룹'][i] = 50
    elif df_return_hour['반납시간_분'][i] >= 40:
        df_return_hour['반납시간_분_그룹'][i] = 40
    elif df_return_hour['반납시간_분'][i] >= 30:
        df_return_hour['반납시간_분_그룹'][i] = 30
    elif df_return_hour['반납시간_분'][i] >= 20:
        df_return_hour['반납시간_분_그룹'][i] = 20
    elif df_return_hour['반납시간_분'][i] >= 10:
        df_return_hour['반납시간_분_그룹'][i] = 10
    else:
        df_return_hour['반납시간_분_그룹'][i] = 0
df_return_hour_group = df_return_hour.groupby('반납시간_분_그룹')[['반납시간_분']].count().reset_index()
df_return_hour_group.rename(columns = {'반납시간_분' : 'count'}, inplace = True)
df_return_hour_group
# Out:
#    반납시간_분_그룹  count
# 0          0     39
# 1         10     42
# 2         20     55
# 3         30     34
# 4         40     42
# 5         50     21

# %%
# 10분당 평균도착률(10분당 자전거 반납수의 평균) = lambda
# lambda = 10이면 10분동안 평균 10대의 자전거를 반납

lda23 = df_return_hour_group['count'].sum() / 6
lda23
# Out:
# 38.833333333333336

# %% [markdown]
# - 2019년 6월 한달동안의 롯데월드타워(잠실역2번출구 쪽) 대여소의 평균도착률 람다(10분당 평균 반납수)는

# %%
b = [lda0, lda1, lda2, lda3, lda4, lda5, lda6, lda7, lda8, lda9, lda10, lda11, lda12, lda13, lda14, lda15, lda16, lda17, lda18, lda19, lda20, lda21, lda22, lda23]

result['lambda'] = b
result
# Out:
#    time          mu      lambda
# 0    0시   18.666667   18.833333
# 1    1시   10.000000    9.333333
# 2    2시    4.500000    2.333333
# 3    3시    4.000000    2.666667
# 4    4시    3.500000    5.666667
# 5    5시    4.500000    7.666667
# 6    6시    7.166667   10.500000
# 7    7시   21.666667   59.666667
# 8    8시   47.666667  105.333333
# 9    9시   33.500000   66.500000
# 10  10시   20.833333   49.500000
# 11  11시   38.333333   61.333333
# 12  12시   48.500000   62.333333
# 13  13시   68.333333   75.666667
# 14  14시   87.166667   79.500000
# 15  15시  104.500000   80.333333
# 16  16시  120.000000   91.666667
# 17  17시  140.833333  114.333333
# 18  18시  243.500000  147.000000
# 19  19시  137.166667  124.833333
# 20  20시   99.833333   97.666667
# 21  21시   68.333333   67.333333
# 22  22시   61.000000   60.500000
# 23  23시   41.666667   38.833333

# %% [markdown]
# ### 가용도(고객이 station에 도착했을 때 자전거가 station에 있을 확률)
# $1 - (1 - \frac{\lambda}{\mu})(\frac{\lambda}{\mu})^0$ = $\frac{\lambda}{\mu}$

# %%
result['가용도'] = result['lambda'] / result['mu']
result = result[['time', 'lambda', 'mu', '가용도']]
result
# Out:
#    time      lambda          mu       가용도
# 0    0시   18.833333   18.666667  1.008929
# 1    1시    9.333333   10.000000  0.933333
# 2    2시    2.333333    4.500000  0.518519
# 3    3시    2.666667    4.000000  0.666667
# 4    4시    5.666667    3.500000  1.619048
# 5    5시    7.666667    4.500000  1.703704
# 6    6시   10.500000    7.166667  1.465116
# 7    7시   59.666667   21.666667  2.753846
# 8    8시  105.333333   47.666667  2.209790
# 9    9시   66.500000   33.500000  1.985075
# 10  10시   49.500000   20.833333  2.376000
# 11  11시   61.333333   38.333333  1.600000
# 12  12시   62.333333   48.500000  1.285223
# 13  13시   75.666667   68.333333  1.107317
# 14  14시   79.500000   87.166667  0.912046
# 15  15시   80.333333  104.500000  0.768740
# 16  16시   91.666667  120.000000  0.763889
# 17  17시  114.333333  140.833333  0.811834
# 18  18시  147.000000  243.500000  0.603696
# 19  19시  124.833333  137.166667  0.910085
# 20  20시   97.666667   99.833333  0.978297
# 21  21시   67.333333   68.333333  0.985366
# 22  22시   60.500000   61.000000  0.991803
# 23  23시   38.833333   41.666667  0.932000

# %%
plt.style.use('bmh')

# %%
result.plot(kind = 'bar', x = 'time', y = 'lambda', figsize = (24, 10), 
            title = '2019년 6월 롯데월드타워(잠실역2번출구 쪽) 대여소 평균도착률(단위시간: 10분)')
plt.show()

# %%
result.plot(kind = 'bar', x = 'time', y = 'mu', figsize = (24, 10), 
            title = '2019년 6월 롯데월드타워(잠실역2번출구 쪽) 대여소 평균서비스율(단위시간: 10분)')
plt.show()

# %%
result.plot(kind = 'bar', x = 'time', y = '가용도', figsize = (24, 10), 
            title = '2019년 6월 롯데월드타워(잠실역2번출구 쪽) 대여소 가용도')
plt.show()

# %% [markdown]
# - 가용도가 1이하인 시간대는 반납보다 대여가 많아서 자전거 빌리기 어려움
# - 1시, 2시, 3시, 14시 ~ 23시일때 가용도가 1이하
# - 7시에 가용도가 높아지므로 이때 자전거 재배치가 이루어지는 것 같음
# - 21년, 20년 동일 대여소에 비해 가용도가 좀 더 안 좋은 편
# - 이때는 출근시간에는 예상외로 가용도가 높은 편
# - 2019년에도 14시 이후로 계속 가용도가 1이하이므로 오후에 자전거 재배치 필요함
