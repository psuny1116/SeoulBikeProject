# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df_new1 = pd.read_csv('./data/공공자전거 대여이력_2020.06.csv', encoding='cp949')
df_new2 = pd.read_csv('./data/공공자전거 대여이력_2020.07.csv', encoding='cp949')
df_new3 = pd.read_csv('./data/공공자전거 대여이력_2020.08.csv', encoding='cp949')
df_new4 = pd.read_csv('./data/공공자전거 대여이력_2020.09.csv', encoding='cp949')
df_new5 = pd.read_csv('./data/공공자전거 대여이력_2020.10.csv', encoding='cp949')
df_new6 = pd.read_csv('./data/공공자전거 대여이력_2020.11.csv', encoding='cp949')
df_new7 = pd.read_csv('./data/공공자전거 대여이력_2020.12.csv', encoding='cp949')
df_new8 = pd.read_csv('./data/공공자전거 대여이력_2021.01.csv', encoding='cp949')
df_new9 = pd.read_csv('./data/공공자전거 대여이력_2021.02.csv', encoding='cp949')
df_new10 = pd.read_csv('./data/공공자전거 대여이력_2021.03.csv', encoding='cp949')
df_new11 = pd.read_csv('./data/공공자전거 대여이력_2021.04.csv', encoding='cp949')
df_new12 = pd.read_csv('./data/공공자전거 대여이력_2021.05.csv', encoding='cp949')

# %%
df_new = pd.merge(df_new1, df_new2, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new3, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new4, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new5, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new6, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new7, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new8, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new9, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new10, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new11, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new = pd.merge(df_new, df_new12, 
                  on = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명', '대여거치대', 
                        '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],how='outer')
df_new
# Out:
#               자전거번호                 대여일시  대여대여소번호           대여대여소명  대여거치대  \
# 0         SPB-36260  2020-06-01 00:00:35     1681         현대6차 아파트      0
# 1         SPB-36146  2020-06-01 00:01:47      816      신용산역 6번출구 앞      0
# 2         SPB-33273  2020-06-01 00:03:05     1050       둔촌역 3번 출입구      0
# 3         SPB-35969  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)      0
# 4         SPB-30703  2020-06-01 00:00:46     1132         등촌역 7번출구      0
# ...             ...                  ...      ...              ...    ...
# 25968004  SPB-31282  2021-05-31 23:48:22     2190             도원맨션      0
# 25968005  SPB-50316  2021-05-31 23:55:04     1106           신방화사거리      0
# 25968006  SPB-44035  2021-05-31 23:51:12     1627        수락산역 4번출구      0
# 25968007  SPB-50409  2021-05-31 23:31:37     1008  암사역 3번출구(국민은행앞)      0
# 25968008  SPB-55881  2021-05-31 23:51:36     2377       수서역 5번출구 뒤      0
#
#                          반납일시  반납대여소번호           반납대여소명  반납거치대  이용시간     이용거리
# 0         2020-06-01 00:05:24     1665          양지근린공원앞      0     5     0.00
# 1         2020-06-01 00:05:54      829            베르가모앞      0     4     0.00
# 2         2020-06-01 00:05:59     1078            둔촌사거리      0     3     0.00
# 3         2020-06-01 00:06:10     1209  잠실나루역 (2번 출구 쪽)      0     2     0.00
# 4         2020-06-01 00:06:53     1169        염창역 1번 출구      0     6     0.00
# ...                       ...      ...              ...    ...   ...      ...
# 25968004  2021-05-31 23:59:57     2102          봉림교 교통섬      0    11  1145.32
# 25968005  2021-05-31 23:59:57     1103        방화역 4번출구앞      0     4   639.19
# 25968006  2021-05-31 23:59:58     1727       서울도봉초등학교인근      0     8  1383.25
# 25968007  2021-05-31 23:59:58      544            광남중학교      0    28  3234.21
# 25968008  2021-05-31 23:59:58     1257      가락시장역 롯데마트앞      0     8  1430.00
#
# [25968009 rows x 11 columns]

# %%
df_new['대여대여소명'].unique()
# Out:
# array(['현대6차 아파트', '신용산역 6번출구 앞', '둔촌역 3번 출입구', ..., '?첩꽁훈컵㈔?맞은편',
#        'LIG강?潔팎컷? 103동앞', '탐앤탐??을지로3가점'], dtype=object)

# %%
df = df_new[~df_new['대여대여소명'].str.contains('\?')]
df
# Out:
#               자전거번호                 대여일시  대여대여소번호           대여대여소명  대여거치대  \
# 0         SPB-36260  2020-06-01 00:00:35     1681         현대6차 아파트      0
# 1         SPB-36146  2020-06-01 00:01:47      816      신용산역 6번출구 앞      0
# 2         SPB-33273  2020-06-01 00:03:05     1050       둔촌역 3번 출입구      0
# 3         SPB-35969  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)      0
# 4         SPB-30703  2020-06-01 00:00:46     1132         등촌역 7번출구      0
# ...             ...                  ...      ...              ...    ...
# 25968004  SPB-31282  2021-05-31 23:48:22     2190             도원맨션      0
# 25968005  SPB-50316  2021-05-31 23:55:04     1106           신방화사거리      0
# 25968006  SPB-44035  2021-05-31 23:51:12     1627        수락산역 4번출구      0
# 25968007  SPB-50409  2021-05-31 23:31:37     1008  암사역 3번출구(국민은행앞)      0
# 25968008  SPB-55881  2021-05-31 23:51:36     2377       수서역 5번출구 뒤      0
#
#                          반납일시  반납대여소번호           반납대여소명  반납거치대  이용시간     이용거리
# 0         2020-06-01 00:05:24     1665          양지근린공원앞      0     5     0.00
# 1         2020-06-01 00:05:54      829            베르가모앞      0     4     0.00
# 2         2020-06-01 00:05:59     1078            둔촌사거리      0     3     0.00
# 3         2020-06-01 00:06:10     1209  잠실나루역 (2번 출구 쪽)      0     2     0.00
# 4         2020-06-01 00:06:53     1169        염창역 1번 출구      0     6     0.00
# ...                       ...      ...              ...    ...   ...      ...
# 25968004  2021-05-31 23:59:57     2102          봉림교 교통섬      0    11  1145.32
# 25968005  2021-05-31 23:59:57     1103        방화역 4번출구앞      0     4   639.19
# 25968006  2021-05-31 23:59:58     1727       서울도봉초등학교인근      0     8  1383.25
# 25968007  2021-05-31 23:59:58      544            광남중학교      0    28  3234.21
# 25968008  2021-05-31 23:59:58     1257      가락시장역 롯데마트앞      0     8  1430.00
#
# [25945623 rows x 11 columns]

# %%
df['대여대여소명'].unique()
# Out:
# array(['현대6차 아파트', '신용산역 6번출구 앞', '둔촌역 3번 출입구', ..., 'kt 행당빌딩 앞',
#        '중랑데시앙플렉스 앞', '이랜드글로벌R&D센터'], dtype=object)

# %%
df['반납대여소명'].unique()
# Out:
# array(['양지근린공원앞', '베르가모앞', '둔촌사거리', ..., '서울방?絹?고분군', '?도였諭?북단',
#        '신방화??8번출구'], dtype=object)

# %%
df_new = df[~df['반납대여소명'].str.contains('\?')]
df_new
# Out:
#               자전거번호                 대여일시  대여대여소번호           대여대여소명  대여거치대  \
# 0         SPB-36260  2020-06-01 00:00:35     1681         현대6차 아파트      0
# 1         SPB-36146  2020-06-01 00:01:47      816      신용산역 6번출구 앞      0
# 2         SPB-33273  2020-06-01 00:03:05     1050       둔촌역 3번 출입구      0
# 3         SPB-35969  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)      0
# 4         SPB-30703  2020-06-01 00:00:46     1132         등촌역 7번출구      0
# ...             ...                  ...      ...              ...    ...
# 25968004  SPB-31282  2021-05-31 23:48:22     2190             도원맨션      0
# 25968005  SPB-50316  2021-05-31 23:55:04     1106           신방화사거리      0
# 25968006  SPB-44035  2021-05-31 23:51:12     1627        수락산역 4번출구      0
# 25968007  SPB-50409  2021-05-31 23:31:37     1008  암사역 3번출구(국민은행앞)      0
# 25968008  SPB-55881  2021-05-31 23:51:36     2377       수서역 5번출구 뒤      0
#
#                          반납일시  반납대여소번호           반납대여소명  반납거치대  이용시간     이용거리
# 0         2020-06-01 00:05:24     1665          양지근린공원앞      0     5     0.00
# 1         2020-06-01 00:05:54      829            베르가모앞      0     4     0.00
# 2         2020-06-01 00:05:59     1078            둔촌사거리      0     3     0.00
# 3         2020-06-01 00:06:10     1209  잠실나루역 (2번 출구 쪽)      0     2     0.00
# 4         2020-06-01 00:06:53     1169        염창역 1번 출구      0     6     0.00
# ...                       ...      ...              ...    ...   ...      ...
# 25968004  2021-05-31 23:59:57     2102          봉림교 교통섬      0    11  1145.32
# 25968005  2021-05-31 23:59:57     1103        방화역 4번출구앞      0     4   639.19
# 25968006  2021-05-31 23:59:58     1727       서울도봉초등학교인근      0     8  1383.25
# 25968007  2021-05-31 23:59:58      544            광남중학교      0    28  3234.21
# 25968008  2021-05-31 23:59:58     1257      가락시장역 롯데마트앞      0     8  1430.00
#
# [25924501 rows x 11 columns]

# %%
df_new['반납대여소명'].unique()
# Out:
# array(['양지근린공원앞', '베르가모앞', '둔촌사거리', ..., '돌곶이역 앞', '중랑데시앙플렉스 앞',
#        '이랜드글로벌R&D센터'], dtype=object)

# %%
df_new = df_new.drop(['자전거번호', '대여거치대', '반납거치대', '이용거리'], axis = 1)
df_new.head()
# Out:
#                   대여일시  대여대여소번호           대여대여소명                 반납일시  \
# 0  2020-06-01 00:00:35     1681         현대6차 아파트  2020-06-01 00:05:24
# 1  2020-06-01 00:01:47      816      신용산역 6번출구 앞  2020-06-01 00:05:54
# 2  2020-06-01 00:03:05     1050       둔촌역 3번 출입구  2020-06-01 00:05:59
# 3  2020-06-01 00:04:31     1209  잠실나루역 (2번 출구 쪽)  2020-06-01 00:06:10
# 4  2020-06-01 00:00:46     1132         등촌역 7번출구  2020-06-01 00:06:53
#
#    반납대여소번호           반납대여소명  이용시간
# 0     1665          양지근린공원앞     5
# 1      829            베르가모앞     4
# 2     1078            둔촌사거리     3
# 3     1209  잠실나루역 (2번 출구 쪽)     2
# 4     1169        염창역 1번 출구     6

# %%
df_new['대여일시'] = pd.to_datetime(df_new['대여일시'])
df_new['반납일시'] = pd.to_datetime(df_new['반납일시'])

df_new['대여월'] = df_new['대여일시'].dt.month
df_new['대여일'] = df_new['대여일시'].dt.day
df_new['대여요일'] = df_new['대여일시'].dt.dayofweek
df_new['대여시간'] = df_new['대여일시'].dt.hour
df_new['대여시간_분'] = df_new['대여일시'].dt.minute

df_new['반납월'] = df_new['반납일시'].dt.month
df_new['반납일'] = df_new['반납일시'].dt.day
df_new['반납요일'] = df_new['반납일시'].dt.dayofweek
df_new['반납시간'] = df_new['반납일시'].dt.hour
df_new['반납시간_분'] = df_new['반납일시'].dt.minute

# %%
df_new = df_new.sort_values('대여일시', ignore_index = True)
df_new.head()
# Out:
#                  대여일시  대여대여소번호              대여대여소명                반납일시  \
# 0 2020-06-01 00:00:00      106          합정역 7번출구 앞 2020-06-01 00:41:00
# 1 2020-06-01 00:00:16      956             응암시장교차로 2020-06-01 00:08:25
# 2 2020-06-01 00:00:24     2340  삼호물산버스정류장(23370) 옆 2020-06-01 00:14:50
# 3 2020-06-01 00:00:26     1057              능골근린공원 2020-06-01 00:07:13
# 4 2020-06-01 00:00:32     3511            응봉역 1번출구 2020-06-01 00:21:38
#
#    반납대여소번호     반납대여소명  이용시간  대여월  대여일  대여요일  대여시간  대여시간_분  반납월  반납일  반납요일  \
# 0      830   청암자이아파트앞    40    6    1     0     0       0    6    1     0
# 1      939   은평구청 교차로     7    6    1     0     0       0    6    1     0
# 2     2263  바우뫼문화복지회관    13    6    1     0     0       0    6    1     0
# 3     1057     능골근린공원     7    6    1     0     0       0    6    1     0
# 4      362   청계8가 사거리    21    6    1     0     0       0    6    1     0
#
#    반납시간  반납시간_분
# 0     0      41
# 1     0       8
# 2     0      14
# 3     0       7
# 4     0      21

# %%
df_rental = df_new[['대여일시', '대여대여소명','대여대여소번호', '대여월', '대여일', '대여요일', '대여시간', '대여시간_분']]
df_rental.reset_index(drop = True, inplace = True)
df_rental.head()
# Out:
#                  대여일시              대여대여소명  대여대여소번호  대여월  대여일  대여요일  대여시간  \
# 0 2020-06-01 00:00:00          합정역 7번출구 앞      106    6    1     0     0
# 1 2020-06-01 00:00:16             응암시장교차로      956    6    1     0     0
# 2 2020-06-01 00:00:24  삼호물산버스정류장(23370) 옆     2340    6    1     0     0
# 3 2020-06-01 00:00:26              능골근린공원     1057    6    1     0     0
# 4 2020-06-01 00:00:32            응봉역 1번출구     3511    6    1     0     0
#
#    대여시간_분
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_rental2 = df_rental.groupby(['대여대여소명','대여대여소번호', '대여월', '대여일', '대여시간']).size().reset_index().rename(columns = {0 : 'rent_count'})
df_rental2
# Out:
#                 대여대여소명  대여대여소번호  대여월  대여일  대여시간  rent_count
# 0        (구)신한은행 중랑교지점     1442    1    1     1           1
# 1        (구)신한은행 중랑교지점     1442    1    1     5           1
# 2        (구)신한은행 중랑교지점     1442    1    1    10           1
# 3        (구)신한은행 중랑교지점     1442    1    1    11           1
# 4        (구)신한은행 중랑교지점     1442    1    1    13           1
# ...                ...      ...  ...  ...   ...         ...
# 8908123        힐스테이트에코     2720   12   31    18           4
# 8908124        힐스테이트에코     2720   12   31    19           2
# 8908125        힐스테이트에코     2720   12   31    21           3
# 8908126        힐스테이트에코     2720   12   31    22           1
# 8908127        힐스테이트에코     2720   12   31    23           2
#
# [8908128 rows x 6 columns]

# %%
df_rental2['mu_15'] = df_rental2['rent_count'] / 4
df_rental2
# Out:
#                 대여대여소명  대여대여소번호  대여월  대여일  대여시간  rent_count  mu_15
# 0        (구)신한은행 중랑교지점     1442    1    1     1           1   0.25
# 1        (구)신한은행 중랑교지점     1442    1    1     5           1   0.25
# 2        (구)신한은행 중랑교지점     1442    1    1    10           1   0.25
# 3        (구)신한은행 중랑교지점     1442    1    1    11           1   0.25
# 4        (구)신한은행 중랑교지점     1442    1    1    13           1   0.25
# ...                ...      ...  ...  ...   ...         ...    ...
# 8908123        힐스테이트에코     2720   12   31    18           4   1.00
# 8908124        힐스테이트에코     2720   12   31    19           2   0.50
# 8908125        힐스테이트에코     2720   12   31    21           3   0.75
# 8908126        힐스테이트에코     2720   12   31    22           1   0.25
# 8908127        힐스테이트에코     2720   12   31    23           2   0.50
#
# [8908128 rows x 7 columns]

# %%
df_return = df_new[['반납일시', '반납대여소명', '반납대여소번호','반납월', '반납일', '반납요일', '반납시간', '반납시간_분']]
df_return.reset_index(drop = True, inplace = True)
df_return
# Out:
#                         반납일시           반납대여소명  반납대여소번호  반납월  반납일  반납요일  반납시간  \
# 0        2020-06-01 00:41:00         청암자이아파트앞      830    6    1     0     0
# 1        2020-06-01 00:08:25         은평구청 교차로      939    6    1     0     0
# 2        2020-06-01 00:14:50        바우뫼문화복지회관     2263    6    1     0     0
# 3        2020-06-01 00:07:13           능골근린공원     1057    6    1     0     0
# 4        2020-06-01 00:21:38         청계8가 사거리      362    6    1     0     0
# ...                      ...              ...      ...  ...  ...   ...   ...
# 25924496 2021-05-31 23:59:57        방화역 4번출구앞     1103    5   31     0    23
# 25924497 2021-05-31 23:59:27  석촌호교차로 (스타벅스 앞)     1293    5   31     0    23
# 25924498 2021-05-31 23:59:27          도봉세무서 앞     1560    5   31     0    23
# 25924499 2021-05-31 23:58:12     동대문롯데캐슬아파트 앞      657    5   31     0    23
# 25924500 2021-05-31 23:59:45    당고개입구오거리 당현천변     4004    5   31     0    23
#
#           반납시간_분
# 0             41
# 1              8
# 2             14
# 3              7
# 4             21
# ...          ...
# 25924496      59
# 25924497      59
# 25924498      59
# 25924499      58
# 25924500      59
#
# [25924501 rows x 8 columns]

# %%
df_c = pd.DataFrame(df_return[['반납대여소명','반납대여소번호','반납월','반납일', '반납시간']].value_counts()).rename(columns = {0 : 'return_count'}).reset_index()
df_c.reset_index(drop=True, inplace = True)
df_c['lambda15'] = df_c['return_count']/4
df_c.columns = ['대여소명','대여소번호','월','일','시간','return_count','lambda15']
df_c
# Out:
#                     대여소명  대여소번호   월   일  시간  return_count  lambda15
# 0          뚝섬유원지역 1번출구 앞    502   5   2  17           262     65.50
# 1          뚝섬유원지역 1번출구 앞    502   5   5  18           248     62.00
# 2          뚝섬유원지역 1번출구 앞    502   5   2  16           246     61.50
# 3          뚝섬유원지역 1번출구 앞    502   5   5  17           235     58.75
# 4          뚝섬유원지역 1번출구 앞    502   5   5  16           230     57.50
# ...                  ...    ...  ..  ..  ..           ...       ...
# 8796837  상암월드컵파크 1단지 교차로    416  10  24  19             1      0.25
# 8796838  상암월드컵파크 1단지 교차로    416  10  24  18             1      0.25
# 8796839  상암월드컵파크 1단지 교차로    416  10  24  17             1      0.25
# 8796840  상암월드컵파크 1단지 교차로    416  10  24   4             1      0.25
# 8796841          힐스테이트에코   2720  12  31  23             1      0.25
#
# [8796842 rows x 7 columns]

# %%
return_ubound = pd.DataFrame(df_c.groupby(['대여소명','대여소번호'])['return_count'].agg(lambda x : np.floor(np.percentile(x,75)+(np.percentile(x,75)-np.percentile(x,25))*1.5))).reset_index().rename(columns = {'return_count' : 'upperbound'})
return_ubound.head()
# Out:
#             대여소명  대여소번호  upperbound
# 0  (구)신한은행 중랑교지점   1442         8.0
# 1    (구)합정동 주민센터    101         3.0
# 2    (시립)고덕평생학습관   1070         3.0
# 3   (재)FITI시험연구원   2724         8.0
# 4  3호선 매봉역 3번출구앞   2335         6.0

# %%
df_rental2.columns = ['대여소명','대여소번호','월','일','시간', 'rent_count','mu_15']
df = pd.merge(df_c, df_rental2, on=['대여소명','대여소번호','월','일','시간'], how='outer')
df.tail(20)
# Out:
#              대여소명  대여소번호   월   일  시간  return_count  lambda15  rent_count  \
# 11224140  힐스테이트에코   2720  12  25  18           NaN       NaN         3.0
# 11224141  힐스테이트에코   2720  12  25  21           NaN       NaN         2.0
# 11224142  힐스테이트에코   2720  12  25  22           NaN       NaN         2.0
# 11224143  힐스테이트에코   2720  12  26   8           NaN       NaN         1.0
# 11224144  힐스테이트에코   2720  12  26  22           NaN       NaN         2.0
# 11224145  힐스테이트에코   2720  12  27   8           NaN       NaN         1.0
# 11224146  힐스테이트에코   2720  12  27  12           NaN       NaN         4.0
# 11224147  힐스테이트에코   2720  12  27  16           NaN       NaN         4.0
# 11224148  힐스테이트에코   2720  12  27  21           NaN       NaN         2.0
# 11224149  힐스테이트에코   2720  12  27  23           NaN       NaN         1.0
# 11224150  힐스테이트에코   2720  12  28   1           NaN       NaN         1.0
# 11224151  힐스테이트에코   2720  12  28   6           NaN       NaN         1.0
# 11224152  힐스테이트에코   2720  12  28  10           NaN       NaN         2.0
# 11224153  힐스테이트에코   2720  12  28  23           NaN       NaN         1.0
# 11224154  힐스테이트에코   2720  12  30   1           NaN       NaN         1.0
# 11224155  힐스테이트에코   2720  12  30   6           NaN       NaN         1.0
# 11224156  힐스테이트에코   2720  12  30  21           NaN       NaN         1.0
# 11224157  힐스테이트에코   2720  12  31   1           NaN       NaN         1.0
# 11224158  힐스테이트에코   2720  12  31  13           NaN       NaN         2.0
# 11224159  힐스테이트에코   2720  12  31  22           NaN       NaN         1.0
#
#           mu_15
# 11224140   0.75
# 11224141   0.50
# 11224142   0.50
# 11224143   0.25
# 11224144   0.50
# 11224145   0.25
# 11224146   1.00
# 11224147   1.00
# 11224148   0.50
# 11224149   0.25
# 11224150   0.25
# 11224151   0.25
# 11224152   0.50
# 11224153   0.25
# 11224154   0.25
# 11224155   0.25
# 11224156   0.25
# 11224157   0.25
# 11224158   0.50
# 11224159   0.25

# %%
df1 = df[df['월'] == 1].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(1, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame1 = pd.concat([stops2,Dayhour],axis=1)

# %%
df2 = df[df['월'] == 2].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(2, 24*28*len(stops)),'일':np.repeat(np.arange(1,29), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),28)})
stops2 = pd.concat([stops] * 24*28).reset_index(drop=True)
Dayhour_frame2= pd.concat([stops2,Dayhour],axis=1)

# %%
df3 = df[df['월'] == 3].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(3, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame3 = pd.concat([stops2,Dayhour],axis=1)

# %%
df4 = df[df['월'] == 4].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(4, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame4 = pd.concat([stops2,Dayhour],axis=1)

# %%
df5 = df[df['월'] == 5].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(5, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame5 = pd.concat([stops2,Dayhour],axis=1)

# %%
df6 = df[df['월'] == 6].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(6, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame6 = pd.concat([stops2,Dayhour],axis=1)

# %%
df7 = df[df['월'] == 7].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(7, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame7 = pd.concat([stops2,Dayhour],axis=1)

# %%
df8 = df[df['월'] == 8].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(8, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame8 = pd.concat([stops2,Dayhour],axis=1)

# %%
df9 = df[df['월'] == 9].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(9, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame9 = pd.concat([stops2,Dayhour],axis=1)

# %%
df10 = df[df['월'] == 10].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(10, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame10 = pd.concat([stops2,Dayhour],axis=1)

# %%
df11 = df[df['월'] == 11].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(11, 24*30*len(stops)),'일':np.repeat(np.arange(1,31), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),30)})
stops2 = pd.concat([stops] * 24*30).reset_index(drop=True)
Dayhour_frame11 = pd.concat([stops2,Dayhour],axis=1)

# %%
df12 = df[df['월'] == 12].reset_index(drop = True)
stops = df[['대여소명','대여소번호']].drop_duplicates().reset_index(drop=True)
Dayhour = pd.DataFrame({'월':np.repeat(12, 24*31*len(stops)),'일':np.repeat(np.arange(1,32), 24*len(stops)), '시간':np.tile(np.repeat(np.arange(24), len(stops)),31)})
stops2 = pd.concat([stops] * 24*31).reset_index(drop=True)
Dayhour_frame12 = pd.concat([stops2,Dayhour],axis=1)

# %%
df = pd.merge(df,Dayhour_frame1, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame2, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame3, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame4, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame5, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame6, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame7, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame8, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame9, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame10, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame11, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df = pd.merge(df,Dayhour_frame12, on = ['대여소명','대여소번호','월','일', '시간'],how='outer')
df
# Out:
#                    대여소명  대여소번호   월   일  시간  return_count  lambda15  \
# 0         뚝섬유원지역 1번출구 앞    502   5   2  17         262.0     65.50
# 1         뚝섬유원지역 1번출구 앞    502   5   5  18         248.0     62.00
# 2         뚝섬유원지역 1번출구 앞    502   5   2  16         246.0     61.50
# 3         뚝섬유원지역 1번출구 앞    502   5   5  17         235.0     58.75
# 4         뚝섬유원지역 1번출구 앞    502   5   5  16         230.0     57.50
# ...                 ...    ...  ..  ..  ..           ...       ...
# 21698515       골마을 근린공원   2918  12  31  23           NaN       NaN
# 21698516     소피아 관광호텔 앞   1766  12  31  23           NaN       NaN
# 21698517        신림동주민센터   2180  12  31  23           NaN       NaN
# 21698518  서남물재생센터 버스정류장   1114  12  31  23           NaN       NaN
# 21698519         상암단말정비  99998  12  31  23           NaN       NaN
#
#           rent_count  mu_15
# 0              119.0  29.75
# 1              145.0  36.25
# 2              194.0  48.50
# 3              182.0  45.50
# 4              179.0  44.75
# ...              ...    ...
# 21698515         NaN    NaN
# 21698516         NaN    NaN
# 21698517         NaN    NaN
# 21698518         NaN    NaN
# 21698519         NaN    NaN
#
# [21698520 rows x 9 columns]

# %%
df = pd.merge(df, return_ubound, on=['대여소명','대여소번호'], how='outer')
df.fillna(0, inplace=True)
df
# Out:
#                    대여소명  대여소번호   월   일  시간  return_count  lambda15  \
# 0         뚝섬유원지역 1번출구 앞    502   5   2  17         262.0     65.50
# 1         뚝섬유원지역 1번출구 앞    502   5   5  18         248.0     62.00
# 2         뚝섬유원지역 1번출구 앞    502   5   2  16         246.0     61.50
# 3         뚝섬유원지역 1번출구 앞    502   5   5  17         235.0     58.75
# 4         뚝섬유원지역 1번출구 앞    502   5   5  16         230.0     57.50
# ...                 ...    ...  ..  ..  ..           ...       ...
# 21698515         상암단말정비  99998  12  31  19           0.0      0.00
# 21698516         상암단말정비  99998  12  31  20           0.0      0.00
# 21698517         상암단말정비  99998  12  31  21           0.0      0.00
# 21698518         상암단말정비  99998  12  31  22           0.0      0.00
# 21698519         상암단말정비  99998  12  31  23           0.0      0.00
#
#           rent_count  mu_15  upperbound
# 0              119.0  29.75        49.0
# 1              145.0  36.25        49.0
# 2              194.0  48.50        49.0
# 3              182.0  45.50        49.0
# 4              179.0  44.75        49.0
# ...              ...    ...         ...
# 21698515         0.0   0.00         1.0
# 21698516         0.0   0.00         1.0
# 21698517         0.0   0.00         1.0
# 21698518         0.0   0.00         1.0
# 21698519         0.0   0.00         1.0
#
# [21698520 rows x 10 columns]

# %%
df = df.sort_values(['대여소명', '대여소번호', '월', '일', '시간'], ignore_index = True)
df
# Out:
#                    대여소명  대여소번호   월   일  시간  return_count  lambda15  \
# 0         (구)신한은행 중랑교지점   1442   1   1   0           0.0      0.00
# 1         (구)신한은행 중랑교지점   1442   1   1   1           0.0      0.00
# 2         (구)신한은행 중랑교지점   1442   1   1   2           1.0      0.25
# 3         (구)신한은행 중랑교지점   1442   1   1   3           0.0      0.00
# 4         (구)신한은행 중랑교지점   1442   1   1   4           0.0      0.00
# ...                 ...    ...  ..  ..  ..           ...       ...
# 21698515        힐스테이트에코   2720  12  31  19           1.0      0.25
# 21698516        힐스테이트에코   2720  12  31  20           2.0      0.50
# 21698517        힐스테이트에코   2720  12  31  21           1.0      0.25
# 21698518        힐스테이트에코   2720  12  31  22           0.0      0.00
# 21698519        힐스테이트에코   2720  12  31  23           1.0      0.25
#
#           rent_count  mu_15  upperbound
# 0                0.0   0.00         8.0
# 1                1.0   0.25         8.0
# 2                0.0   0.00         8.0
# 3                0.0   0.00         8.0
# 4                0.0   0.00         8.0
# ...              ...    ...         ...
# 21698515         2.0   0.50         9.0
# 21698516         0.0   0.00         9.0
# 21698517         3.0   0.75         9.0
# 21698518         1.0   0.25         9.0
# 21698519         2.0   0.50         9.0
#
# [21698520 rows x 10 columns]

# %%
df = df.drop(['return_count', 'rent_count'], axis = 1)
df = df.rename(columns = {'lambda15' : 'lambda_15', 'upperbound' : 'c'})
df
# Out:
#                    대여소명  대여소번호   월   일  시간  lambda_15  mu_15    c
# 0         (구)신한은행 중랑교지점   1442   1   1   0       0.00   0.00  8.0
# 1         (구)신한은행 중랑교지점   1442   1   1   1       0.00   0.25  8.0
# 2         (구)신한은행 중랑교지점   1442   1   1   2       0.25   0.00  8.0
# 3         (구)신한은행 중랑교지점   1442   1   1   3       0.00   0.00  8.0
# 4         (구)신한은행 중랑교지점   1442   1   1   4       0.00   0.00  8.0
# ...                 ...    ...  ..  ..  ..        ...    ...  ...
# 21698515        힐스테이트에코   2720  12  31  19       0.25   0.50  9.0
# 21698516        힐스테이트에코   2720  12  31  20       0.50   0.00  9.0
# 21698517        힐스테이트에코   2720  12  31  21       0.25   0.75  9.0
# 21698518        힐스테이트에코   2720  12  31  22       0.00   0.25  9.0
# 21698519        힐스테이트에코   2720  12  31  23       0.25   0.50  9.0
#
# [21698520 rows x 8 columns]

# %%
df['rho'] = float(-1)

for i in range(len(df)):
    if df['mu_15'][i] == 0:
        df['rho'][i] = 0
    else:
        df['rho'][i] = df['lambda_15'][i] / df['mu_15'][i]
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-a0fd241f4f27> in <module>
#       3 for i in range(len(df)):
#       4     if df['mu_15'][i] == 0:
# ----> 5         df['rho'][i] = 0
#       6     else:
#       7         df['rho'][i] = df['lambda_15'][i] / df['mu_15'][i]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1089
#    1090         if cacher_needs_updating:
# -> 1091             self._maybe_update_cacher()
#    1092
#    1093     def _set_with_engine(self, key, value) -> None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    1233                 # to ensure column still in dataframe
#    1234                 # otherwise, either self or ref has swapped in new arrays
# -> 1235                 ref._maybe_cache_changed(cacher[0], self)
#    1236             else:
#    1237                 # GH#33675 we have swapped in a new array, so parent
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in _maybe_cache_changed(self, item, value)
#    3903         loc = self._info_axis.get_loc(item)
#    3904         arraylike = value._values
# -> 3905         self._mgr.iset(loc, arraylike)
#    3906
#    3907     # ----------------------------------------------------------------------
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in iset(self, loc, value)
#    1076             blk_locs = blklocs[val_locs.indexer]
#    1077             if blk.should_store(value):
# -> 1078                 blk.set_inplace(blk_locs, value_getitem(val_locs))
#    1079             else:
#    1080                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\blocks.py in set_inplace(self, locs, values)
#     358         create a new array and always creates a new Block.
#     359         """
# --> 360         self.values[locs] = values
#     361
#     362     def delete(self, loc) -> None:
#
# KeyboardInterrupt:

# %%
# p_c: 대여소에 자전거가 c개(최대거치용량) 있을 확률

df['p_c'] = float(-1)

for i in range(len(df)):
    if df['rho'][i] == 1:
        df['p_c'][i] = 1 / (1 + df['c'][i]) 
    else:
        df['p_c'][i] = (df['rho'][i]**df['c'][i]) * ((1 - df['rho'][i]) / (1 - (df['rho'][i]**(df['c'][i] + 1))))
df

# %%
# L_s : 대여소 내 평균 자전거 수

df['L_s'] = float(-1)

for i in range(len(df)):
    rho = df['rho'][i]
    c = df['c'][i]
    if df['rho'][i] == 1:
        df['L_s'][i] = c / 2
    else:
        df['L_s'][i] = (rho / (1 - rho)) * ((1 - ((c + 1) * rho**c) + (c * rho**(c + 1))) / (1 - (rho**(c + 1))))
df

# %%
# L_q : 대기행렬 내 평균 자전거 수

df['L_q'] = float(-1)

for i in range(len(df)):
    df['L_q'][i] = df['L_s'][i] - (df['rho'][i] * (1 - df['p_c'][i]))
df

# %%
# W_s : 대여소 내 평균 대기시간(자전거 반납 후 재대여 될 때까지의 시간)

df['W_s'] = float(-1)

for i in range(len(df)):
    if df['p_c'][i] == 0:
        df['W_s'][i] = 0
    elif df['p_c'][i] == 1:
        df['W_s'][i] = 0
    else:
        df['W_s'][i] = df['L_s'][i] / (df['lambda_15'][i] * (1 - df['p_c'][i]))
df

# %%
# W_q : 대기행렬 내 평균대기시간

df['W_q'] = float(-1)

for i in range(len(df)):
    if df['p_c'][i] == 0:
        df['W_q'][i] = 0
    elif df['p_c'][i] == 1:
        df['W_s'][i] = 0
    else:
        df['W_q'][i] = df['L_q'][i] / (df['lambda_15'][i] * (1 - df['p_c'][i]))
df

# %%
df.info()

# %%
# 일부 칼럼 타입 카테고리로 변환

df = df.astype({'대여소명' : 'category', '대여소번호' : 'category'})

# %%
df.info()

# %%
station = pd.read_csv('./대학원/데이터/정리 데이터/공공자전거 대여소 정보(21.06월 기준).csv')
station.head()

# %%
station.info()

# %%
station = station.astype({'자치구' : 'category', '대여소 번호' : 'category'})

# %%
station.info()

# %%
station = station.rename(columns = {'대여소 번호' : '대여소번호'})
station

# %%
before_merged = len(df)

df = pd.merge(df, station[['자치구', '대여소번호']], on = '대여소번호')
df.head()

# %%
df = df.drop(['대여소번호', 'c'], axis = 1)
df = df[['자치구', '대여소명', '월', '일', '시간','L_s', 'W_s']]
df.head()

# %%
df.to_excel('./1년 365일 24시 대여소별 Ls, Lq, Ws, Wq.xlsx', index = False)

# %% [markdown]
# - mu_15: 15분당 평균 대여 자전거 수
# - lambda_15: 15분당 평균 반납 자전거 수
# - L_s : 대여소 내 평균 자전거 수
# - W_s : 대여소 내 평균 대기시간(자전거 반납 후 재대여 될 때까지의 시간)

# %%
df = df.drop(['p_c', 'L_q', 'W_q'], axis = 1)
df.head()
# Out:
#    자치구           대여소명  월  일  lambda_15     mu_15       rho       L_s  \
# 0  중랑구  (구)신한은행 중랑교지점  1  1   0.156250  0.156250  1.000000  2.500000
# 1  중랑구  (구)신한은행 중랑교지점  1  2   0.218750  0.104167  2.100000  4.161692
# 2  중랑구  (구)신한은행 중랑교지점  1  3   0.260417  0.239583  1.086957  2.742160
# 3  중랑구  (구)신한은행 중랑교지점  1  4   0.250000  0.270833  0.923077  2.267459
# 4  중랑구  (구)신한은행 중랑교지점  1  5   0.270833  0.208333  1.300000  3.234553
#
#          W_s
# 0  19.200000
# 1  40.477516
# 2  13.215706
# 3  10.487473
# 4  16.846524

# %%
dft_pivot_lambda = df.pivot_table(index = ['자치구'], values = ['lambda_15']).T
dft_pivot_lambda.head()
# Out:
# 자치구             강남구       강동구       강북구       강서구       관악구       광진구  \
# lambda_15  0.155776  0.277013  0.240537  0.418886  0.358419  0.430687
#
# 자치구             구로구       금천구       노원구      도봉구      동대문구       동작구  \
# lambda_15  0.331259  0.209766  0.351259  0.24813  0.331544  0.264123
#
# 자치구             마포구      서대문구       서초구       성동구       성북구       송파구  \
# lambda_15  0.419654  0.242433  0.201778  0.390237  0.302326  0.315286
#
# 자치구             양천구      영등포구       용산구       은평구       종로구        중구  \
# lambda_15  0.366686  0.497315  0.211838  0.250003  0.238632  0.168339
#
# 자치구             중랑구
# lambda_15  0.271155

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_lambda, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 lambda_15')
plt.tight_layout()
plt.show()

# %%
dft_pivot_lambda_std = df.pivot_table(index = ['자치구'], values = ['lambda_15'], aggfunc = 'std').T
dft_pivot_lambda_std.head()
# Out:
# 자치구             강남구      강동구       강북구       강서구       관악구       광진구  \
# lambda_15  0.211311  0.37471  0.246694  0.553172  0.583618  0.710542
#
# 자치구             구로구       금천구       노원구       도봉구     동대문구       동작구  \
# lambda_15  0.468687  0.326199  0.416954  0.279937  0.35906  0.363863
#
# 자치구             마포구      서대문구       서초구      성동구       성북구       송파구  \
# lambda_15  0.566553  0.291579  0.339634  0.56699  0.350759  0.427764
#
# 자치구             양천구      영등포구       용산구       은평구       종로구        중구  \
# lambda_15  0.451571  0.725851  0.318466  0.386823  0.276422  0.219406
#
# 자치구             중랑구
# lambda_15  0.306014

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_lambda_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 lambda_15 표준편차')
plt.tight_layout()
plt.show()

# %%
dft_pivot_mu = df.pivot_table(index = ['자치구'], values = ['mu_15']).T
dft_pivot_mu.head()
# Out:
# 자치구         강남구       강동구       강북구      강서구       관악구       광진구       구로구  \
# mu_15  0.163257  0.270771  0.241074  0.41553  0.361987  0.427378  0.328256
#
# 자치구         금천구       노원구      도봉구      동대문구       동작구       마포구      서대문구  \
# mu_15  0.212265  0.349763  0.24447  0.327948  0.262129  0.417038  0.250378
#
# 자치구         서초구       성동구       성북구       송파구       양천구      영등포구       용산구  \
# mu_15  0.205171  0.385355  0.303189  0.312907  0.362869  0.497745  0.211135
#
# 자치구         은평구       종로구        중구      중랑구
# mu_15  0.243377  0.253484  0.179348  0.26448

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_mu, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 mu_15')
plt.tight_layout()
plt.show()

# %%
dft_pivot_mu_std = df.pivot_table(index = ['자치구'], values = ['mu_15'], aggfunc = 'std').T
dft_pivot_mu_std.head()
# Out:
# 자치구         강남구       강동구       강북구       강서구       관악구       광진구       구로구  \
# mu_15  0.213843  0.347602  0.244187  0.535067  0.548826  0.638656  0.458046
#
# 자치구         금천구       노원구       도봉구      동대문구       동작구       마포구     서대문구  \
# mu_15  0.310297  0.407656  0.261324  0.342594  0.316996  0.527567  0.26415
#
# 자치구         서초구       성동구       성북구       송파구       양천구      영등포구       용산구  \
# mu_15  0.318371  0.529805  0.316462  0.423882  0.425589  0.701537  0.302483
#
# 자치구         은평구       종로구        중구       중랑구
# mu_15  0.335561  0.288875  0.229758  0.275006

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_mu_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 mu_15 표준편차')
plt.tight_layout()
plt.show()

# %%
dft_pivot_rho = df.pivot_table(index = ['자치구'], values = ['rho']).T
dft_pivot_rho.head()
# Out:
# 자치구       강남구       강동구       강북구       강서구       관악구       광진구       구로구  \
# rho  1.091854  1.258779  1.122443  1.233028  1.017057  1.121604  1.209382
#
# 자치구      금천구       노원구       도봉구      동대문구       동작구       마포구      서대문구  \
# rho  1.43432  1.126774  1.181043  1.141098  1.060103  1.191057  1.033117
#
# 자치구       서초구       성동구       성북구       송파구       양천구      영등포구       용산구  \
# rho  1.092166  1.199038  1.071098  1.175492  1.132853  1.215512  1.179685
#
# 자치구       은평구       종로구        중구       중랑구
# rho  1.119781  1.083737  1.128906  1.097198

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_rho, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 rho')
plt.tight_layout()
plt.show()

# %%
dft_pivot_L_s = df.pivot_table(index = ['자치구'], values = ['L_s']).T
dft_pivot_L_s.head()
# Out:
# 자치구       강남구      강동구       강북구       강서구       관악구       광진구       구로구  \
# L_s  0.650323  1.36966  1.039649  2.223104  1.827448  2.486049  1.646003
#
# 자치구       금천구      노원구       도봉구      동대문구       동작구       마포구      서대문구  \
# L_s  0.849961  1.80434  1.250441  1.623945  1.396572  2.435663  1.102806
#
# 자치구       서초구       성동구       성북구       송파구       양천구     영등포구       용산구  \
# L_s  1.066824  2.188301  1.541487  1.643186  2.003317  2.91715  1.175485
#
# 자치구       은평구       종로구        중구       중랑구
# L_s  1.311835  1.212681  0.758916  1.368817

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_L_s, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 L_s')
plt.tight_layout()
plt.show()

# %%
dft_pivot_L_s_std = df.pivot_table(index = ['자치구'], values = ['L_s'], aggfunc = 'std').T
dft_pivot_L_s_std.head()
# Out:
# 자치구       강남구       강동구      강북구       강서구      관악구       광진구       구로구  \
# L_s  1.051821  1.768319  1.06315  2.603803  3.27965  5.917682  2.061873
#
# 자치구       금천구       노원구       도봉구      동대문구       동작구       마포구      서대문구  \
# L_s  1.385593  2.097095  1.513377  1.603601  2.035446  3.748191  1.409497
#
# 자치구       서초구       성동구       성북구       송파구       양천구      영등포구       용산구  \
# L_s  2.155335  3.194561  1.801106  2.348723  2.291064  4.758599  1.912227
#
# 자치구       은평구       종로구        중구       중랑구
# L_s  2.307781  1.207707  0.915588  1.516566

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_L_s_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 L_s 표준편차')
plt.tight_layout()
plt.show()

# %%
dft_pivot_W_s = df.pivot_table(index = ['자치구'], values = ['W_s']).T
dft_pivot_W_s.head()
# Out:
# 자치구        강남구        강동구     강북구        강서구      관악구        광진구        구로구  \
# W_s  10.187722  14.224855  9.9159  21.573819  9.44569  15.232942  18.665552
#
# 자치구        금천구       노원구        도봉구       동대문구        동작구        마포구  \
# W_s  16.566422  11.26661  12.283387  14.178489  12.162859  22.218389
#
# 자치구       서대문구        서초구        성동구        성북구        송파구        양천구  \
# W_s  11.525425  15.226306  19.027163  10.898285  16.669299  16.300556
#
# 자치구       영등포구        용산구        은평구        종로구        중구        중랑구
# W_s  23.241736  15.377731  12.491654  23.859252  21.89835  10.192001

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_W_s, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 W_s')
plt.tight_layout()
plt.show()

# %%
dft_pivot_W_s_std = df.pivot_table(index = ['자치구'], values = ['W_s'], aggfunc = 'std').T
dft_pivot_W_s_std.head()
# Out:
# 자치구        강남구        강동구        강북구        강서구        관악구        광진구  \
# W_s  26.612212  34.740838  16.839476  71.878375  15.864643  46.929808
#
# 자치구        구로구        금천구        노원구        도봉구       동대문구        동작구  \
# W_s  75.435691  52.741769  26.120527  25.048871  29.860096  37.794911
#
# 자치구        마포구      서대문구        서초구        성동구        성북구        송파구  \
# W_s  59.147273  23.19049  59.066087  48.886268  17.524005  54.959175
#
# 자치구        양천구      영등포구        용산구        은평구        종로구         중구       중랑구
# W_s  41.053799  93.78703  50.752981  36.551593  68.794102  72.009022  21.24639

# %%
plt.figure(figsize = (10, 14))
sns.heatmap(dft_pivot_W_s_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 자치구별 W_s 표준편차')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 학교/ 아파트/ 지하철역/공원 근처 대여소 분석

# %%
s = pd.DataFrame(df['대여소명'].unique()).rename(columns = {0 : 'station'})
s

# %%
school = []
subway = []
apart = []
park = []

for i in range(len(s)):
    if '출구' in s['station'][i]:
        subway.append(s['station'][i])
        
    elif '학교' in s['station'][i]:
        school.append(s['station'][i])
        
    elif '아파트' in s['station'][i]:
        apart.append(s['station'][i]) 
    elif '힐스테이트' in s['station'][i]:
        apart.append(s['station'][i])
    elif '자이' in s['station'][i]:
        apart.append(s['station'][i])
    elif '롯데캐슬' in s['station'][i]:
        apart.append(s['station'][i])
    elif 'LH' in s['station'][i]:
        apart.append(s['station'][i])
    elif '푸르지오' in s['station'][i]:
        apart.append(s['station'][i])
    elif '래미안' in s['station'][i]:
        apart.append(s['station'][i])
    elif '아이파크' in s['station'][i]:
        apart.append(s['station'][i])
    elif '더샾' in s['station'][i]:
        apart.append(s['station'][i])
    elif '편한세상' in s['station'][i]:
        apart.append(s['station'][i])
        
    elif '공원' in s['station'][i]:
        park.append(s['station'][i])

# %%
school_data = []
for i in range(len(df)):
    if df['대여소명'][i] in school:
        school_data.append(df.loc[i])
school_data = pd.DataFrame(school_data)
school_data['특성'] = '학교'
school_data

# %%
subway_data = []
for i in range(len(df)):
    if df['대여소명'][i] in subway:
        subway_data.append(df.loc[i])
subway_data = pd.DataFrame(subway_data)
subway_data['특성'] = '지하철'
subway_data

# %%
apart_data = []
for i in range(len(df)):
    if df['대여소명'][i] in apart:
        apart_data.append(df.loc[i])
apart_data = pd.DataFrame(apart_data)
apart_data['특성'] = '아파트'
apart_data

# %%
park_data = []
for i in range(len(df)):
    if df['대여소명'][i] in park:
        park_data.append(df.loc[i])
park_data = pd.DataFrame(park_data)
park_data['특성'] = '공원'
park_data

# %%
data = pd.merge(school_data, subway_data, on=['특성', '자치구', '대여소명', '월', '일', '시간', 'L_s', 'W_s'], how = 'outer')
data = pd.merge(data, apart_data, on=['특성', '자치구', '대여소명', '월', '일', '시간', 'L_s', 'W_s'], how = 'outer')
data = pd.merge(data, park_data, on=['특성', '자치구', '대여소명', '월', '일', '시간', 'L_s', 'W_s'], how = 'outer')
data

# %%
data.to_excel('./1년 365일 24시 특성별 Ls, Lq, Ws, Wq.xlsx', index = False)

# %%
data_pivot_lambda = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['lambda_15'])
data_pivot_lambda.head()
# Out:
#     lambda_15                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   0.190926  0.130256  0.086816  0.056091  0.041277  0.039834  0.072540
# 아파트  0.184778  0.125167  0.082436  0.051970  0.035520  0.030264  0.038248
# 지하철  0.267186  0.202555  0.141992  0.093623  0.065721  0.078813  0.153811
# 학교   0.169954  0.120707  0.078323  0.051084  0.035335  0.025982  0.038792
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   0.144826  0.304908  0.198347  0.175575  0.205881  0.271154  0.292115
# 아파트  0.107329  0.213626  0.135834  0.127059  0.158373  0.208898  0.222929
# 지하철  0.343872  0.574587  0.375474  0.308049  0.365397  0.449022  0.486210
# 학교   0.110678  0.237390  0.159734  0.138030  0.153171  0.207022  0.222290
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   0.320242  0.378575  0.453702  0.550368  0.703176  0.585984  0.486624
# 아파트  0.235800  0.273629  0.333909  0.430695  0.603929  0.506572  0.399834
# 지하철  0.517842  0.585019  0.692920  0.897153  1.118904  0.849485  0.675914
# 학교   0.231266  0.263485  0.309589  0.377511  0.509925  0.427012  0.346680
#
#
# 시간         21        22        23
# 특성
# 공원   0.485718  0.439890  0.292562
# 아파트  0.407033  0.395278  0.265065
# 지하철  0.638607  0.566402  0.377633
# 학교   0.350417  0.337308  0.240279

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_lambda, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 lambda_15')
plt.tight_layout()
plt.show()

# %%
data_pivot_lambda_std = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['lambda_15'], aggfunc = 'std')
data_pivot_lambda_std.head()
# Out:
#     lambda_15                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   0.200741  0.138438  0.096231  0.060702  0.044554  0.058421  0.087958
# 아파트  0.171882  0.119079  0.080317  0.053657  0.037771  0.035187  0.047382
# 지하철  0.278112  0.199877  0.136979  0.090355  0.062613  0.084828  0.175696
# 학교   0.169313  0.124339  0.087299  0.058493  0.037554  0.027498  0.046914
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   0.224534  0.382692  0.228673  0.178782  0.197244  0.254276  0.283889
# 아파트  0.192168  0.430461  0.155041  0.128681  0.148923  0.205560  0.213260
# 지하철  0.406494  0.634649  0.360087  0.276817  0.324786  0.400387  0.440454
# 학교   0.111892  0.280363  0.184802  0.145319  0.142447  0.194643  0.209711
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   0.327612  0.401652  0.478546  0.533668  0.644553  0.554665  0.478744
# 아파트  0.225635  0.265847  0.324641  0.396066  0.544618  0.452830  0.368361
# 지하철  0.492657  0.604246  0.755757  0.963552  1.129521  0.912925  0.815502
# 학교   0.230920  0.285008  0.345473  0.414283  0.527520  0.443062  0.357443
#
#
# 시간         21        22        23
# 특성
# 공원   0.487702  0.446713  0.299507
# 아파트  0.377660  0.357280  0.238228
# 지하철  0.792713  0.683336  0.441854
# 학교   0.352985  0.332675  0.239341

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_lambda_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 lambda_15 표준편차')
plt.tight_layout()
plt.show()

# %%
data_pivot_mu = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['mu_15'])
data_pivot_mu.head()
# Out:
#         mu_15                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   0.147826  0.103849  0.066048  0.041294  0.033001  0.056798  0.112997
# 아파트  0.137916  0.098479  0.064356  0.043274  0.033628  0.054143  0.122859
# 지하철  0.254038  0.177886  0.127192  0.087206  0.059199  0.055869  0.110873
# 학교   0.122825  0.088048  0.057194  0.036977  0.028939  0.044638  0.099016
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   0.291305  0.379695  0.241464  0.214893  0.260127  0.306136  0.326424
# 아파트  0.292369  0.369809  0.216206  0.188652  0.209330  0.243344  0.256179
# 지하철  0.295189  0.581209  0.360170  0.303094  0.370444  0.449014  0.498520
# 학교   0.230858  0.326726  0.200113  0.178295  0.198952  0.233666  0.251610
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   0.358604  0.413931  0.480573  0.564265  0.653555  0.485650  0.441724
# 아파트  0.275167  0.301077  0.349400  0.415415  0.493489  0.390782  0.349065
# 지하철  0.548268  0.620138  0.707883  0.903302  1.143116  0.847165  0.706209
# 학교   0.273201  0.311476  0.365164  0.406500  0.430468  0.341173  0.303016
#
#
# 시간         21        22        23
# 특성
# 공원   0.402994  0.326933  0.204953
# 아파트  0.324440  0.269821  0.169733
# 지하철  0.660740  0.539546  0.347494
# 학교   0.285077  0.243958  0.161812

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_mu, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 mu_15')
plt.tight_layout()
plt.show()

# %%
data_pivot_mu_std = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['mu_15'], aggfunc = 'std')
data_pivot_mu_std.head()
# Out:
#         mu_15                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   0.144996  0.102514  0.066471  0.043396  0.040235  0.063084  0.123769
# 아파트  0.127001  0.091068  0.059777  0.043549  0.038475  0.059244  0.117394
# 지하철  0.263877  0.177351  0.126031  0.088232  0.058745  0.054572  0.106606
# 학교   0.126547  0.090443  0.060727  0.038527  0.036506  0.055749  0.107638
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   0.290011  0.368817  0.209350  0.178344  0.215594  0.263921  0.295894
# 아파트  0.271648  0.349581  0.181971  0.153830  0.196938  0.204078  0.206507
# 지하철  0.313161  0.611819  0.309572  0.241976  0.300631  0.369216  0.432513
# 학교   0.238334  0.310410  0.168503  0.139706  0.156421  0.187925  0.207929
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   0.343832  0.409268  0.454306  0.531288  0.608041  0.457138  0.425881
# 아파트  0.230160  0.268035  0.313278  0.415181  0.473238  0.359329  0.325808
# 지하철  0.514011  0.619362  0.728513  0.897852  1.107444  0.871862  0.776747
# 학교   0.228384  0.286791  0.330028  0.391296  0.438483  0.351219  0.313392
#
#
# 시간         21        22        23
# 특성
# 공원   0.395049  0.309591  0.198322
# 아파트  0.312243  0.256619  0.159687
# 지하철  0.750454  0.617802  0.406116
# 학교   0.308638  0.268317  0.172862

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_mu_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 mu_15 표준편차')
plt.tight_layout()
plt.show()

# %%
data_pivot_rho = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['rho'])
data_pivot_rho.head()
# Out:
#           rho                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   1.317682  1.338392  1.379792  1.455314  1.709412  1.689626  1.492119
# 아파트  1.481122  1.431917  1.434786  1.350708  1.313087  0.814679  0.455284
# 지하철  1.037016  1.184037  1.233493  1.154039  1.409979  1.929091  1.772021
# 학교   1.437554  1.401160  1.410224  1.476383  1.826576  1.306713  0.762596
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   0.840483  1.142410  0.929071  0.831183  0.768350  0.862617  0.863385
# 아파트  0.528735  0.709710  0.606460  0.641751  0.718725  0.801688  0.801088
# 지하철  1.359833  1.075783  1.074940  1.010147  0.960566  0.977890  0.960330
# 학교   1.433296  1.205128  1.061740  0.852080  0.759147  0.851683  0.874441
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   0.853509  0.875793  0.887033  0.953395  1.111693  1.186515  1.092989
# 아파트  0.789046  0.858966  0.904870  1.037762  1.266316  1.330625  1.187656
# 지하철  0.917909  0.924844  0.952766  0.977470  0.990072  1.008758  0.939145
# 학교   0.819900  0.798751  0.796377  0.915023  1.195955  1.259066  1.126255
#
#
# 시간         21        22        23
# 특성
# 공원   1.222838  1.350964  1.472449
# 아파트  1.317823  1.604212  1.713311
# 지하철  0.974543  1.060310  1.099567
# 학교   1.298974  1.485566  1.547324

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_rho, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 rho')
plt.tight_layout()
plt.show()

# %%
data_pivot_L_s = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['L_s'])
data_pivot_L_s.head()
# Out:
#           L_s                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   1.981644  2.015227  2.014508  1.993607  2.029850  1.170966  1.150926
# 아파트  1.567741  1.534832  1.531007  1.488511  1.348242  0.718342  0.420431
# 지하철  2.339143  2.688384  2.653562  2.650550  2.679644  3.200936  2.856066
# 학교   1.293765  1.285016  1.267006  1.255023  1.187352  0.701733  0.543710
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   0.932680  1.339327  1.219405  1.196435  1.163766  1.352754  1.375423
# 아파트  0.471711  0.656340  0.728236  0.785584  0.906134  1.061929  1.073754
# 지하철  2.631963  2.396997  2.472709  2.389681  2.376752  2.503798  2.244053
# 학교   0.644955  0.830925  0.790395  0.780598  0.819396  0.975283  0.935772
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   1.375399  1.474062  1.596473  1.676312  1.817625  1.920591  1.772754
# 아파트  1.059566  1.121899  1.197256  1.311573  1.461048  1.516974  1.377417
# 지하철  2.093206  2.190111  2.450486  2.496490  2.442127  2.448790  2.286646
# 학교   0.928898  0.939315  0.972931  1.048914  1.216594  1.252785  1.175218
#
#
# 시간         21        22        23
# 특성
# 공원   1.909524  2.049888  2.069948
# 아파트  1.481520  1.628865  1.688271
# 지하철  2.274008  2.484684  2.496816
# 학교   1.210506  1.306258  1.355446

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_L_s, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 L_s')
plt.tight_layout()
plt.show()

# %%
data_pivot_L_s_std = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['L_s'], aggfunc = 'std')
data_pivot_L_s_std.head()
# Out:
#           L_s                                                              \
# 시간         0         1         2         3         4         5         6
# 특성
# 공원   2.441679  2.555645  2.525812  2.415254  2.855867  2.092940  1.925282
# 아파트  1.960040  1.933925  1.962453  1.939505  1.873689  1.024095  0.769886
# 지하철  2.896193  3.582755  3.971486  4.392571  4.160303  5.513126  4.450735
# 학교   1.654154  1.681464  1.654784  1.690589  1.820808  1.259162  1.084982
#
#                                                                            \
# 시간         7         8         9         10        11        12        13
# 특성
# 공원   1.920018  2.451525  1.796531  1.567129  1.359164  1.501968  1.522330
# 아파트  1.019374  1.201616  1.015925  0.981191  1.039526  1.354335  1.309861
# 지하철  4.526129  4.183306  4.264945  3.637142  3.463219  4.472304  2.711831
# 학교   1.337264  1.670666  1.391532  1.269374  1.172729  1.477950  1.290761
#
#                                                                            \
# 시간         14        15        16        17        18        19        20
# 특성
# 공원   1.470583  1.655286  1.919077  2.006638  2.257367  2.231093  2.069088
# 아파트  1.270625  1.311946  1.450880  1.597557  1.746046  1.773656  1.636147
# 지하철  2.185492  3.084046  4.177060  4.261767  4.497076  4.514518  4.441989
# 학교   1.288242  1.323158  1.438859  1.549759  1.700187  1.762946  1.597461
#
#
# 시간         21        22        23
# 특성
# 공원   2.279863  2.475509  2.502984
# 아파트  1.767626  1.947660  2.025742
# 지하철  4.442884  4.574439  4.010446
# 학교   1.545982  1.686911  1.761995

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_L_s_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 L_s 표준편차')
plt.tight_layout()
plt.show()

# %%
data_pivot_W_s = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['W_s'])
data_pivot_W_s.head()
# Out:
#            W_s                                                         \
# 시간          0          1          2          3          4          5
# 특성
# 공원   14.171284  24.194751  40.365331  69.779696  99.154829  65.839908
# 아파트  11.843269  17.909468  27.522221  46.504424  61.397939  29.751434
# 지하철  11.927892  20.275134  29.460826  46.998964  78.862946  85.761648
# 학교   12.362834  18.063012  29.178485  46.242491  64.332021  48.314671
#
#                                                                              \
# 시간          6          7         8         9         10        11        12
# 특성
# 공원   25.465498   7.693951  5.921852  7.307271  7.160965  5.856362  5.218515
# 아파트   9.905678   4.094765  3.223826  4.998691  5.631632  5.398451  4.812705
# 지하철  36.590480  12.048514  5.588205  7.655074  8.166786  6.734929  5.570748
# 학교   25.110050  20.479593  5.497024  6.163619  6.039512  5.283225  4.647090
#
#                                                                            \
# 시간         13        14        15        16        17        18        19
# 특성
# 공원   4.873109  4.530623  4.111702  3.644426  3.244199  3.015982  3.910440
# 아파트  4.480882  4.212182  3.993218  3.569154  3.233553  2.909137  3.492888
# 지하철  4.912319  4.442942  4.005524  3.644658  2.934663  2.330553  3.136452
# 학교   4.350021  4.006582  3.616472  3.115615  2.931079  2.897221  3.646403
#
#
# 시간         20        21        22        23
# 특성
# 공원   4.173120  4.870771  6.159133  9.906716
# 아파트  3.788437  4.343954  5.597211  9.281401
# 지하철  3.749292  4.076771  5.388719  8.770275
# 학교   4.028823  4.630419  5.784189  8.941453

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_W_s, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 W_s')
plt.tight_layout()
plt.show()

# %%
data_pivot_W_s_std = data.pivot_table(index = ['특성'], columns = ['시간'], values = ['W_s'], aggfunc = 'std')
data_pivot_W_s_std.head()
# Out:
#            W_s                                                           \
# 시간          0          1          2          3           4           5
# 특성
# 공원   10.586463  25.488658  44.704692  91.431482  127.595474  126.812651
# 아파트  12.404478  21.317673  32.178098  62.199032   82.295130   40.593656
# 지하철  10.617055  21.081311  35.429913  60.134764  137.541747  124.367279
# 학교   12.496842  19.513171  34.147940  60.868512   81.618135   78.350185
#
#                                                                               \
# 시간          6           7         8         9         10        11        12
# 특성
# 공원   38.430800   10.312718  7.368335  7.007970  5.610847  4.041668  3.511004
# 아파트  12.895404    6.249104  4.057241  4.337974  4.710609  4.191923  3.773131
# 지하철  42.196861   11.549867  5.229717  5.986521  4.933169  3.870466  3.154946
# 학교   58.890050  121.951725  9.424749  7.622994  5.339926  4.152038  3.485617
#
#                                                                            \
# 시간         13        14        15        16        17        18        19
# 특성
# 공원   3.076667  2.889443  2.729075  2.442304  2.232700  2.256595  2.493215
# 아파트  3.412774  3.217029  3.049516  2.763432  2.521083  2.334537  2.675299
# 지하철  2.452564  2.191787  2.001901  1.858024  1.631954  1.383077  1.669912
# 학교   3.236358  2.933289  2.686172  2.324242  2.243357  2.245927  2.725195
#
#
# 시간         20        21        22        23
# 특성
# 공원   2.701674  3.390059  4.257412  6.864034
# 아파트  2.948268  3.571637  4.861902  8.810179
# 지하철  2.091378  2.464683  3.690550  7.034332
# 학교   3.089871  3.939385  5.021875  8.254127

# %%
plt.figure(figsize = (10, 20))
sns.heatmap(data_pivot_W_s_std, square = True, annot = True, cmap = 'Blues', linewidth = 0.5, cbar = False)
plt.title('2020년 6월 ~ 2021년 5월 특성별 W_s 표준편차')
plt.tight_layout()
plt.show()
