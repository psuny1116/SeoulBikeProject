# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df1 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2018.07 Ls, Ws.xlsx')
df2 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2018.08 Ls, Ws.xlsx')
df3 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2018.09 Ls, Ws.xlsx')
df4 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2018.10 Ls, Ws.xlsx')
df5 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2018.11 Ls, Ws.xlsx')
df6 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2018.12 Ls, Ws.xlsx')
df7 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.01 Ls, Ws.xlsx')
df8 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.02 Ls, Ws.xlsx')
df9 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.03 Ls, Ws.xlsx')
df10 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.04 Ls, Ws.xlsx')
df11 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.05 Ls, Ws.xlsx')
df12 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.06 Ls, Ws.xlsx')
df13 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.07 Ls, Ws.xlsx')
df14 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.08 Ls, Ws.xlsx')
df15 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.09 Ls, Ws.xlsx')
df16 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.10 Ls, Ws.xlsx')
df17 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.11 Ls, Ws.xlsx')
df18 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2019.12 Ls, Ws.xlsx')
df19 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.01 Ls, Ws.xlsx')
df20 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.02 Ls, Ws.xlsx')
df21 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.03 Ls, Ws.xlsx')
df22 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.04 Ls, Ws.xlsx')
df23 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.05 Ls, Ws.xlsx')
df24 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.06 Ls, Ws.xlsx')
df25 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.07 Ls, Ws.xlsx')
df26 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.08 Ls, Ws.xlsx')
df27 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.09 Ls, Ws.xlsx')
df28 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.10 Ls, Ws.xlsx')
df29 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.11 Ls, Ws.xlsx')
df30 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2020.12 Ls, Ws.xlsx')
df31 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2021.01 Ls, Ws.xlsx')
df32 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2021.02 Ls, Ws.xlsx')
df33 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2021.03 Ls, Ws.xlsx')
df34 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2021.04 Ls, Ws.xlsx')
df35 = pd.read_excel('./data/2018.07~2021.05 ls, ws/2021.05 Ls, Ws.xlsx')

# %%
df1
# Out:
#        자치구           대여소명     년  월  시간       L_s         W_s
# 0      중랑구  (구)신한은행 중랑교지점  2018  7   0  0.923892    4.931274
# 1      중랑구  (구)신한은행 중랑교지점  2018  7   1  1.170009   11.408748
# 2      중랑구  (구)신한은행 중랑교지점  2018  7   2  1.000000   11.625000
# 3      중랑구  (구)신한은행 중랑교지점  2018  7   3  1.952663  242.608696
# 4      중랑구  (구)신한은행 중랑교지점  2018  7   4  1.587629   43.073684
# ...    ...            ...   ... ..  ..       ...         ...
# 30080  노원구          희성오피앙  2018  7  19  0.607143    5.636364
# 30081  노원구          희성오피앙  2018  7  20  0.542373    4.592593
# 30082  노원구          희성오피앙  2018  7  21  0.553571    4.960000
# 30083  노원구          희성오피앙  2018  7  22  0.595238    7.294118
# 30084  노원구          희성오피앙  2018  7  23  0.485714    6.888889
#
# [30085 rows x 7 columns]

# %%
df = pd.merge(df1, df2, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df3, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df4, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df5, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df6, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df7, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df8, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df9, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df10, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df11, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df12, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df13, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df14, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df15, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df16, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df17, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df18, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df19, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df20, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df21, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df22, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df23, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df24, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df25, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df26, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df27, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df28, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df29, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df30, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df31, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df32, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df33, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df34, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df = pd.merge(df, df35, on = ['자치구', '대여소명', '년', '월', '시간', 'L_s', 'W_s'],how='outer')
df
# Out:
#          자치구           대여소명     년  월  시간       L_s         W_s
# 0        중랑구  (구)신한은행 중랑교지점  2018  7   0  0.923892    4.931274
# 1        중랑구  (구)신한은행 중랑교지점  2018  7   1  1.170009   11.408748
# 2        중랑구  (구)신한은행 중랑교지점  2018  7   2  1.000000   11.625000
# 3        중랑구  (구)신한은행 중랑교지점  2018  7   3  1.952663  242.608696
# 4        중랑구  (구)신한은행 중랑교지점  2018  7   4  1.587629   43.073684
# ...      ...            ...   ... ..  ..       ...         ...
# 1448433  강서구        힐스테이트에코  2021  5  19  5.766845    3.228877
# 1448434  강서구        힐스테이트에코  2021  5  20  1.900294    1.523923
# 1448435  강서구        힐스테이트에코  2021  5  21  0.961031    1.168428
# 1448436  강서구        힐스테이트에코  2021  5  22  1.482999    3.408376
# 1448437  강서구        힐스테이트에코  2021  5  23  6.771255   25.357353
#
# [1448438 rows x 7 columns]

# %% [markdown]
# # 현대고등학교 건너편 W_s

# %%
a = df[df['대여소명'] == '현대고등학교 건너편']
a = a[a['시간'] == 8]
a.reset_index(drop = True)
a.head()
# Out:
#         자치구        대여소명     년   월  시간       L_s        W_s
# 29095   강남구  현대고등학교 건너편  2018   7   8  1.491643   8.884197
# 59533   강남구  현대고등학교 건너편  2018   8   8  4.523378  28.818334
# 90777   강남구  현대고등학교 건너편  2018   9   8  7.411556  20.277054
# 124411  강남구  현대고등학교 건너편  2018  10   8  2.791732   6.945552
# 159156  강남구  현대고등학교 건너편  2018  11   8  1.996520  10.269094

# %%
a = a.astype({'년' : str, '월' : str})
a['date'] = a['년'] + '-' +  a['월']
a.head()
# Out:
#         자치구        대여소명     년   월  시간       L_s        W_s     date
# 29095   강남구  현대고등학교 건너편  2018   7   8  1.491643   8.884197   2018-7
# 59533   강남구  현대고등학교 건너편  2018   8   8  4.523378  28.818334   2018-8
# 90777   강남구  현대고등학교 건너편  2018   9   8  7.411556  20.277054   2018-9
# 124411  강남구  현대고등학교 건너편  2018  10   8  2.791732   6.945552  2018-10
# 159156  강남구  현대고등학교 건너편  2018  11   8  1.996520  10.269094  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(a['date'], a['W_s'])
plt.show()

# %% [markdown]
# # 롯데월드타워(잠실역2번출구 쪽)

# %%
b = df[df['대여소명'] == '롯데월드타워(잠실역2번출구 쪽)']
b = b[b['시간'] == 8]
b.reset_index(drop = True)
b.head()
# Out:
#         자치구               대여소명     년   월  시간        L_s        W_s
# 9247    송파구  롯데월드타워(잠실역2번출구 쪽)  2018   7   8  11.680494   6.965374
# 39418   송파구  롯데월드타워(잠실역2번출구 쪽)  2018   8   8  11.282778   6.700806
# 70032   송파구  롯데월드타워(잠실역2번출구 쪽)  2018   9   8  29.725000  13.988236
# 102107  송파구  롯데월드타워(잠실역2번출구 쪽)  2018  10   8  25.955932  10.449791
# 136197  송파구  롯데월드타워(잠실역2번출구 쪽)  2018  11   8  18.070597   9.149674

# %%
b = b.astype({'년' : str, '월' : str})
b['date'] = b['년'] + '-' +  b['월']
b.head()
# Out:
#         자치구               대여소명     년   월  시간        L_s        W_s     date
# 9247    송파구  롯데월드타워(잠실역2번출구 쪽)  2018   7   8  11.680494   6.965374   2018-7
# 39418   송파구  롯데월드타워(잠실역2번출구 쪽)  2018   8   8  11.282778   6.700806   2018-8
# 70032   송파구  롯데월드타워(잠실역2번출구 쪽)  2018   9   8  29.725000  13.988236   2018-9
# 102107  송파구  롯데월드타워(잠실역2번출구 쪽)  2018  10   8  25.955932  10.449791  2018-10
# 136197  송파구  롯데월드타워(잠실역2번출구 쪽)  2018  11   8  18.070597   9.149674  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(b['date'], b['W_s'])
plt.show()

# %% [markdown]
# # 마곡나루역 2번 출구

# %%
c = df[df['대여소명'] == '마곡나루역 2번 출구']
c = c[c['시간'] == 8]
c.reset_index(drop = True)
c.head()
# Out:
#          자치구         대여소명     년   월  시간        L_s       W_s
# 841058   강서구  마곡나루역 2번 출구  2020   6   8   3.639901  4.439578
# 889922   강서구  마곡나루역 2번 출구  2020   7   8   2.973592  2.155784
# 939391   강서구  마곡나루역 2번 출구  2020   8   8   7.398616  5.259668
# 989250   강서구  마곡나루역 2번 출구  2020   9   8   6.218237  2.347924
# 1039259  강서구  마곡나루역 2번 출구  2020  10   8  10.297603  2.745523

# %%
c = c.astype({'년' : str, '월' : str})
c['date'] = c['년'] + '-' +  c['월']
c.head()
# Out:
#          자치구         대여소명     년   월  시간        L_s       W_s     date
# 841058   강서구  마곡나루역 2번 출구  2020   6   8   3.639901  4.439578   2020-6
# 889922   강서구  마곡나루역 2번 출구  2020   7   8   2.973592  2.155784   2020-7
# 939391   강서구  마곡나루역 2번 출구  2020   8   8   7.398616  5.259668   2020-8
# 989250   강서구  마곡나루역 2번 출구  2020   9   8   6.218237  2.347924   2020-9
# 1039259  강서구  마곡나루역 2번 출구  2020  10   8  10.297603  2.745523  2020-10

# %%
plt.figure(figsize = (20, 5))
plt.plot(c['date'], c['W_s'])
plt.show()

# %% [markdown]
# # 고속터미널역 8-1번, 8-2번 출구 사이

# %%
d = df[df['대여소명'] == '고속터미널역 8-1번, 8-2번 출구 사이']
d = d[d['시간'] == 8]
d.reset_index(drop = True)
d.head()
# Out:
#         자치구                     대여소명     년   월  시간        L_s        W_s
# 2931    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018   7   8  10.420526  25.336441
# 33072   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018   8   8  14.094448  36.410930
# 63619   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018   9   8  40.078652  58.651685
# 95173   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018  10   8  25.134831  40.476872
# 129021  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018  11   8  10.286043  27.430499

# %%
d = d.astype({'년' : str, '월' : str})
d['date'] = d['년'] + '-' +  d['월']
d.head()
# Out:
#         자치구                     대여소명     년   월  시간        L_s        W_s  \
# 2931    서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018   7   8  10.420526  25.336441
# 33072   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018   8   8  14.094448  36.410930
# 63619   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018   9   8  40.078652  58.651685
# 95173   서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018  10   8  25.134831  40.476872
# 129021  서초구  고속터미널역 8-1번, 8-2번 출구 사이  2018  11   8  10.286043  27.430499
#
#            date
# 2931     2018-7
# 33072    2018-8
# 63619    2018-9
# 95173   2018-10
# 129021  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(d['date'], d['W_s'])
plt.show()

# %% [markdown]
# # IFC몰

# %%
e = df[df['대여소명'] == 'IFC몰']
e = e[e['시간'] == 8]
e.reset_index(drop = True)
e.head()
# Out:
#          자치구  대여소명     년   월  시간        L_s        W_s
# 347     영등포구  IFC몰  2018   7   8  12.243887   9.988533
# 30435   영등포구  IFC몰  2018   8   8  13.151642  11.648713
# 60881   영등포구  IFC몰  2018   9   8  25.609428  26.492511
# 92105   영등포구  IFC몰  2018  10   8  19.652997  22.154287
# 125795  영등포구  IFC몰  2018  11   8  11.596414  15.461889

# %%
e = e.astype({'년' : str, '월' : str})
e['date'] = e['년'] + '-' +  e['월']
e.head()
# Out:
#          자치구  대여소명     년   월  시간        L_s        W_s     date
# 347     영등포구  IFC몰  2018   7   8  12.243887   9.988533   2018-7
# 30435   영등포구  IFC몰  2018   8   8  13.151642  11.648713   2018-8
# 60881   영등포구  IFC몰  2018   9   8  25.609428  26.492511   2018-9
# 92105   영등포구  IFC몰  2018  10   8  19.652997  22.154287  2018-10
# 125795  영등포구  IFC몰  2018  11   8  11.596414  15.461889  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(e['date'], e['W_s'])
plt.show()

# %% [markdown]
# # 한신16차아파트 119동 앞

# %%
f = df[df['대여소명'] == '한신16차아파트 119동 앞']
f = f[f['시간'] == 8]
f.reset_index(drop = True)
f.head()
# Out:
#         자치구             대여소명     년   월  시간       L_s        W_s
# 28554   서초구  한신16차아파트 119동 앞  2018   7   8  2.898272  15.036338
# 58992   서초구  한신16차아파트 119동 앞  2018   8   8  1.714199   6.702399
# 90245   서초구  한신16차아파트 119동 앞  2018   9   8  1.189014   3.242791
# 123854  서초구  한신16차아파트 119동 앞  2018  10   8  0.697620   2.883510
# 158600  서초구  한신16차아파트 119동 앞  2018  11   8  0.724183   3.294286

# %%
f = f.astype({'년' : str, '월' : str})
f['date'] = f['년'] + '-' +  f['월']
f.head()
# Out:
#         자치구             대여소명     년   월  시간       L_s        W_s     date
# 28554   서초구  한신16차아파트 119동 앞  2018   7   8  2.898272  15.036338   2018-7
# 58992   서초구  한신16차아파트 119동 앞  2018   8   8  1.714199   6.702399   2018-8
# 90245   서초구  한신16차아파트 119동 앞  2018   9   8  1.189014   3.242791   2018-9
# 123854  서초구  한신16차아파트 119동 앞  2018  10   8  0.697620   2.883510  2018-10
# 158600  서초구  한신16차아파트 119동 앞  2018  11   8  0.724183   3.294286  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(f['date'], f['W_s'])
plt.show()

# %% [markdown]
# # 노들나루공원 입구

# %%
g = df[df['대여소명'] == '노들나루공원 입구']
g = g[g['시간'] == 8]
g.reset_index(drop = True)
g.head()
# Out:
#          자치구       대여소명     년   월  시간       L_s        W_s
# 835259   동작구  노들나루공원 입구  2020   6   8  1.275950   3.864046
# 884057   동작구  노들나루공원 입구  2020   7   8  0.767026   3.402708
# 933481   동작구  노들나루공원 입구  2020   8   8  1.734979  18.087906
# 983319   동작구  노들나루공원 입구  2020   9   8  0.905653   2.264135
# 1033314  동작구  노들나루공원 입구  2020  10   8  6.188200  12.032697

# %%
g = g.astype({'년' : str, '월' : str})
g['date'] = g['년'] + '-' +  g['월']
g.head()
# Out:
#          자치구       대여소명     년   월  시간       L_s        W_s     date
# 835259   동작구  노들나루공원 입구  2020   6   8  1.275950   3.864046   2020-6
# 884057   동작구  노들나루공원 입구  2020   7   8  0.767026   3.402708   2020-7
# 933481   동작구  노들나루공원 입구  2020   8   8  1.734979  18.087906   2020-8
# 983319   동작구  노들나루공원 입구  2020   9   8  0.905653   2.264135   2020-9
# 1033314  동작구  노들나루공원 입구  2020  10   8  6.188200  12.032697  2020-10

# %%
plt.figure(figsize = (20, 5))
plt.plot(g['date'], g['W_s'])
plt.show()

# %% [markdown]
# # 위례중앙푸르지오 1단지 앞

# %%
h = df[df['대여소명'] == '위례중앙푸르지오 1단지 앞']
h = h[h['시간'] == 8]
h.reset_index(drop = True)
h.head()
# Out:
#         자치구            대여소명     년   월  시간       L_s       W_s
# 23132   송파구  위례중앙푸르지오 1단지 앞  2018   7   8  0.264275  3.669559
# 53471   송파구  위례중앙푸르지오 1단지 앞  2018   8   8  0.258481  6.680135
# 84641   송파구  위례중앙푸르지오 1단지 앞  2018   9   8  0.381858  4.587775
# 117875  송파구  위례중앙푸르지오 1단지 앞  2018  10   8  0.247755  2.209133
# 152570  송파구  위례중앙푸르지오 1단지 앞  2018  11   8  0.285714  5.142857

# %%
h = h.astype({'년' : str, '월' : str})
h['date'] = h['년'] + '-' +  h['월']
h.head()
# Out:
#         자치구            대여소명     년   월  시간       L_s       W_s     date
# 23132   송파구  위례중앙푸르지오 1단지 앞  2018   7   8  0.264275  3.669559   2018-7
# 53471   송파구  위례중앙푸르지오 1단지 앞  2018   8   8  0.258481  6.680135   2018-8
# 84641   송파구  위례중앙푸르지오 1단지 앞  2018   9   8  0.381858  4.587775   2018-9
# 117875  송파구  위례중앙푸르지오 1단지 앞  2018  10   8  0.247755  2.209133  2018-10
# 152570  송파구  위례중앙푸르지오 1단지 앞  2018  11   8  0.285714  5.142857  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(h['date'], h['W_s'])
plt.show()

# %% [markdown]
# # 건국대학교 (행정관)

# %%
i = df[df['대여소명'] == '건국대학교 (행정관)']
i = i[i['시간'] == 8]
i.reset_index(drop = True)
i.head()
# Out:
#         자치구         대여소명     년   월  시간       L_s        W_s
# 2471    광진구  건국대학교 (행정관)  2018   7   8  2.505832  35.606158
# 32588   광진구  건국대학교 (행정관)  2018   8   8  3.816776  52.612469
# 63087   광진구  건국대학교 (행정관)  2018   9   8  4.843787  58.127704
# 94595   광진구  건국대학교 (행정관)  2018  10   8  6.738345  29.841633
# 128420  광진구  건국대학교 (행정관)  2018  11   8  3.603831  16.716026

# %%
i = i.astype({'년' : str, '월' : str})
i['date'] = i['년'] + '-' +  i['월']
i.head()
# Out:
#         자치구         대여소명     년   월  시간       L_s        W_s     date
# 2471    광진구  건국대학교 (행정관)  2018   7   8  2.505832  35.606158   2018-7
# 32588   광진구  건국대학교 (행정관)  2018   8   8  3.816776  52.612469   2018-8
# 63087   광진구  건국대학교 (행정관)  2018   9   8  4.843787  58.127704   2018-9
# 94595   광진구  건국대학교 (행정관)  2018  10   8  6.738345  29.841633  2018-10
# 128420  광진구  건국대학교 (행정관)  2018  11   8  3.603831  16.716026  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(i['date'], i['W_s'])
plt.show()

# %% [markdown]
# # 교보생명보험 앞

# %%
j = df[df['대여소명'] == '교보생명보험 앞']
j = j[j['시간'] == 8]
j.reset_index(drop = True)
j.head()
# Out:
#          자치구      대여소명     년   월  시간       L_s       W_s
# 4035    영등포구  교보생명보험 앞  2018   7   8  1.164240  4.210352
# 34173   영등포구  교보생명보험 앞  2018   8   8  0.614246  2.746425
# 64739   영등포구  교보생명보험 앞  2018   9   8  1.476192  4.499552
# 96336   영등포구  교보생명보험 앞  2018  10   8  1.087593  2.677168
# 130209  영등포구  교보생명보험 앞  2018  11   8  1.008492  2.312592

# %%
j = j.astype({'년' : str, '월' : str})
j['date'] = j['년'] + '-' +  j['월']
j.head()
# Out:
#          자치구      대여소명     년   월  시간       L_s       W_s     date
# 4035    영등포구  교보생명보험 앞  2018   7   8  1.164240  4.210352   2018-7
# 34173   영등포구  교보생명보험 앞  2018   8   8  0.614246  2.746425   2018-8
# 64739   영등포구  교보생명보험 앞  2018   9   8  1.476192  4.499552   2018-9
# 96336   영등포구  교보생명보험 앞  2018  10   8  1.087593  2.677168  2018-10
# 130209  영등포구  교보생명보험 앞  2018  11   8  1.008492  2.312592  2018-11

# %%
plt.figure(figsize = (20, 5))
plt.plot(j['date'], j['W_s'])
plt.show()

# %% [markdown]
# # 한번에

# %%
plt.figure(figsize = (20, 5))
plt.plot(a['date'], a['W_s'])
plt.plot(b['date'], b['W_s'])
plt.plot(c['date'], c['W_s'])
plt.plot(d['date'], d['W_s'])
plt.plot(e['date'], e['W_s'])
plt.plot(f['date'], f['W_s'])
plt.plot(g['date'], g['W_s'])
plt.plot(h['date'], h['W_s'])
plt.plot(i['date'], i['W_s'])
plt.plot(j['date'], j['W_s'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-189d2b822848> in <module>
#       8 plt.plot(g['date'], g['W_s'])
#       9 plt.plot(h['date'], h['W_s'])
# ---> 10 plt.plot(i['date'], i['W_s'])
#      11 plt.plot(j['date'], j['W_s'])
#      12 plt.show()
#
# TypeError: 'int' object is not subscriptable
